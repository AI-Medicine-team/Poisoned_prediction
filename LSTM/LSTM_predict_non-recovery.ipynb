# %% [markdown]
# ## 1.1 Data Cleaning

# %%
import pandas as pd 
import numpy as np
import torch
from torch.nn.utils.rnn import pad_sequence
from sklearn.preprocessing import StandardScaler, LabelEncoder

df_series_filled = pd.read_csv('/home/mailiyi/Poisoning_Prediction/LSTM/clean_data/poisoning_data_sequence_filled_onehot.csv')

df_unique = df_series_filled.drop_duplicates(subset=['Hospital ID']).reset_index(drop=True)

# Statistics Distribution of Outcome_other and Outcome
print(df_unique["Outcome_other"].value_counts(dropna=False))

print(df_unique["Outcome"].value_counts(dropna=False))

df_series_filled['检验时间'] = pd.to_datetime(df_series_filled['检验时间'], errors='coerce')

static_cols = [
    'Age',
    'Length of Stay',
    'Weight',
    ] + [
    'Gender_Female',
    'Gender_Male',
    'Education Level_Illiterate',
    'Education Level_Junior High School',
    'Education Level_Primary School',
    'Education Level_Senior High School',
    'Education Level_University Degree',
    'Education Level_Unknown',
    'Type of Poisoning_Alcohol',
    'Type of Poisoning_Industrial',
    'Type of Poisoning_Pesticide',
    'Type of Poisoning_Pharmaceutical',
    'Hypertension_No',
    'Hypertension_Unknown',
    'Hypertension_Yes',
    'Hyperlipidemia_No',
    'Hyperlipidemia_Unknown',
    'Hyperlipidemia_Yes',
    'Diabetes Mellitus_No',
    'Diabetes Mellitus_Unknown',
    'Diabetes Mellitus_Yes',
    'Cerebrovascular Disease_No',
    'Cerebrovascular Disease_Unknown',
    'Cerebrovascular Disease_Yes',
    'Heart Disease_No',
    'Heart Disease_Unknown',
    'Heart Disease_Yes',
    'Allergy History_No',
    'Allergy History_Unknown',
    'Allergy History_Yes',
    'Cancer_No',
    'Cancer_Unknown',
    'Cancer_Yes',
    'Poisoning_No',
    'Poisoning_Unknown',
    'Poisoning_Yes',
    'degree of poisoning_High',
    'degree of poisoning_Low',
    'degree of poisoning_Moderate',
    'degree of poisoning_Undetermined',
    'Smoking Status_No',
    'Smoking Status_Yes',
    'Alcohol Consumption Status_No',
    'Alcohol Consumption Status_Yes',
    'Shortness of Breath_No',
    'Shortness of Breath_Yes',
    'Chest Pain_No',
    'Chest Pain_Yes',
    'Cough_No',
    'Cough_Yes',
    'Pre-syncope_No',
    'Pre-syncope_Yes',
    'Altered Consciousness or Syncope_No',
    'Altered Consciousness or Syncope_Yes',
    'Sore Throat_No',
    'Sore Throat_Yes',
    'Fever_No',
    'Fever_Yes',
    'Fatigue_No',
    'Fatigue_Yes',
    'Lower Limb Edema_No',
    'Lower Limb Edema_Yes',
    'Palpitations_No',
    'Palpitations_Yes',
    'Vomiting_No',
    'Vomiting_Yes',
    'Nausea_No',
    'Nausea_Yes',
    'Weakness_No',
    'Weakness_Yes',
    'Headache_No',
    'Headache_Yes',
    'Residence_Rural',
    'Residence_Unknown',
    'Residence_Urban',
    ]

dynamic_cols = [
    'Systolic Blood Pressure',
    'Diastolic Blood Pressure',
    'Heart Rate',
    'Respiratory Rate',
    'White Blood Cell Count',
    'Red Blood Cell Count',
    'Hemoglobin Concentration',
    'Mean Corpuscular Volume',
    'Mean Corpuscular Hemoglobin',
    'Mean Corpuscular Hemoglobin Concentration',
    'Platelet Count',
    'Mean Platelet Volume',
    'Albumin',
    'Alanine Aminotransferase',
    'Aspartate Aminotransferase',
    'Total Bilirubin',
    'Direct Bilirubin',
    'Lactate Dehydrogenase',
    'Urea',
    'Uric Acid',
    'Creatine Kinase',
    'Creatine Kinase-MB',
    'Troponin I',
    'High-Sensitivity C-Reactive Protein',
    'Homocysteine',
    'Number of Hemoperfusion Sessions',
    'Number of Blood Purification Sessions',
]


scaler = StandardScaler()
df_series_filled[['Age','Length of Stay','Weight',]] = scaler.fit_transform(df_series_filled[['Age','Length of Stay','Weight',]])

static_df = df_series_filled.groupby("Hospital ID")[static_cols].first().reset_index()

# 9. build sequence
scaler = StandardScaler()
scaler.fit(df_series_filled[dynamic_cols])  
all_sequences, all_statics, all_labels = [], [], []

for pid, group in df_series_filled.groupby("Hospital ID"):
    group_sorted = group.sort_values("检验时间")
    # X_dyn = group_sorted[dynamic_cols].values
    X_dyn = scaler.transform(group_sorted[dynamic_cols])  
    # y = group_sorted["Outcome_other"].iloc[-1]  
    y = group_sorted["Outcome"].iloc[-1]  

    # X_dyn = scaler.fit_transform(X_dyn)  
    static_values = static_df.loc[static_df["Hospital ID"] == pid, static_cols].values
    if len(static_values) == 0:
        continue

    all_sequences.append(torch.tensor(X_dyn, dtype=torch.float32))
    all_statics.append(torch.tensor(static_values.squeeze(), dtype=torch.float32))
    all_labels.append(y)

# 10. Padding
X_padded = pad_sequence(all_sequences, batch_first=True, padding_value=0.0)
X_static = torch.stack(all_statics)
y_tensor = torch.tensor(all_labels, dtype=torch.float32).unsqueeze(1)

print(f"number of patients: {len(all_sequences)}")
print(f"Dynamic Feature Input Shape: {X_padded.shape}")  
print(f"static feature input shape: {X_static.shape}")   
print(f"tag shape: {y_tensor.shape}")

print('dynamic feature dimension:',len(dynamic_cols))
# Out:
# Outcome_other 分布（是否死亡）：
# Outcome_other
# 0.0    889
# 1.0     82
# Name: count, dtype: int64
#
# Outcome 分布（是否未治愈）：
# Outcome
# 0.0    731
# 1.0    240
# Name: count, dtype: int64
# 患者数: 971
# 动态特征输入形状: torch.Size([971, 25, 27])
# 静态特征输入形状: torch.Size([971, 78])
# 标签形状: torch.Size([971, 1])

# %%
# Out:
# 动态特征维度: 27

# %% [markdown]
# ## 2.  5-fold cross validation: Divide 1/8 of the training set into validation sets (i.e. 70% training set, 10% validation set, 20% test set)

# %% [markdown]
# - 2.1 Any random seed.

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score, average_precision_score
import pandas as pd
import numpy as np
import os
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed(42)

save_path = '/home/mailiyi/Poisoning_Prediction/LSTM/predict_non-recovery_valid_test_5cv/'
os.makedirs(save_path, exist_ok=True)

class LSTMWithStatic(nn.Module):
    def __init__(self, input_dim, static_dim, hidden_dim=64, num_layers=2, dropout=0.5):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers,
                            batch_first=True, dropout=dropout)
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim + static_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1)
        )
    def forward(self, x_seq, x_static):
        _, (h_n, _) = self.lstm(x_seq)
        h_last = h_n[-1]
        combined = torch.cat([h_last, x_static], dim=1)
        out = self.fc(combined)
        return out

def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=2000, seed=42):
    rng = np.random.RandomState(seed)
    scores = []
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    for _ in range(n_bootstrap):
        idx = rng.randint(0, len(y_true), len(y_true))
        if len(np.unique(y_true[idx])) < 2:
            continue
        scores.append(metric_fn(y_true[idx], y_pred[idx]))
    return np.mean(scores), np.percentile(scores, 2.5), np.percentile(scores, 97.5)

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
all_results = []

max_epochs = 100
batch_size = 16
lr = 5e-4
weight_decay = 5e-4
patience = 12  

device = torch.device("cuda" if torch.cuda.is_available() else
                      "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")

for fold, (train_val_idx, test_idx) in enumerate(kf.split(X_padded)):
    print(f"\n===== Fold {fold+1}/{n_splits} =====")
    set_seed(42 + fold)
    X_train_val_seq, X_test_seq = X_padded[train_val_idx], X_padded[test_idx]
    X_train_val_static, X_test_static = X_static[train_val_idx], X_static[test_idx]
    y_train_val, y_test = y_tensor[train_val_idx], y_tensor[test_idx]

    X_train_seq, X_val_seq, X_train_static, X_val_static, y_train, y_val = train_test_split(
        X_train_val_seq, X_train_val_static, y_train_val,
        test_size=1/8, random_state=42, stratify=y_train_val
    )
    # pos_weight
    num_pos = (y_train == 1).sum().item()
    num_neg = (y_train == 0).sum().item()
    pos_weight = torch.tensor(num_neg / max(num_pos,1), dtype=torch.float32).to(device)
    print(f"pos_weight = {pos_weight:.2f}  (neg={num_neg}, pos={num_pos})")
    train_loader = DataLoader(TensorDataset(X_train_seq, X_train_static, y_train),
                              batch_size=batch_size, shuffle=True)
    model = LSTMWithStatic(
        input_dim=X_padded.shape[2],
        static_dim=X_static.shape[1],
        hidden_dim=64,  
        dropout=0.5
    ).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    best_auroc = 0
    wait = 0
    best_model_path = os.path.join(save_path, f"fold_{fold+1}_best_model.pt")
    for epoch in range(max_epochs):
        model.train()
        total_loss = 0.0
        for batch_seq, batch_static, batch_y in train_loader:
            batch_seq, batch_static, batch_y = batch_seq.to(device), batch_static.to(device), batch_y.to(device)
            optimizer.zero_grad()
            logits = model(batch_seq, batch_static)
            loss = criterion(logits, batch_y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(train_loader)
        model.eval()
        with torch.no_grad():
            logits = model(X_val_seq.to(device), X_val_static.to(device)).cpu().numpy().flatten()
            y_pred = 1 / (1 + np.exp(-logits))
            y_true = y_val.numpy().reshape(-1)
            auroc_val = roc_auc_score(y_true, y_pred)
        print(f"Epoch {epoch+1:03d} | Loss: {avg_loss:.4f} | Val AUROC: {auroc_val:.4f}")
        if auroc_val > best_auroc:
            best_auroc = auroc_val
            wait = 0
            torch.save(model.state_dict(), best_model_path)
        else:
            wait += 1
            if wait >= patience:
                print(f"Early stopping at epoch {epoch+1} (best Val AUROC={best_auroc:.4f})")
                break
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    with torch.no_grad():
        logits = model(X_test_seq.to(device), X_test_static.to(device)).cpu().numpy().flatten()
        y_pred = 1 / (1 + np.exp(-logits))
        y_true = y_test.numpy().reshape(-1)
        result_df = pd.DataFrame({"y_test": y_true, "y_pred": y_pred})
        result_df.to_csv(save_path + f"fold_{fold+1}_results.csv", index=False)
        all_results.append(result_df)

all_results_df = pd.concat(all_results, axis=0).reset_index(drop=True)
y_all_true = all_results_df["y_test"].values
y_all_pred = all_results_df["y_pred"].values

mean_auroc, auc_lower, auc_upper = bootstrap_metric_ci(y_all_true, y_all_pred, roc_auc_score)
mean_auprc, auprc_lower, auprc_upper = bootstrap_metric_ci(y_all_true, y_all_pred, average_precision_score)

print("\n===== 5-Fold Cross Validation Results (Bootstrap) =====")
print(f"AUROC: Mean = {mean_auroc:.4f}, 95% CI = ({auc_lower:.4f}–{auc_upper:.4f})")
print(f"AUPRC: Mean = {mean_auprc:.4f}, 95% CI = ({auprc_lower:.4f}–{auprc_upper:.4f})")

all_results_path = os.path.join(save_path, "all_folds_results.csv")
all_results_df.to_csv(all_results_path, index=False)
# Out:
# Using device: cuda
#
# ===== Fold 1/5 =====
# pos_weight = 2.95  (neg=507, pos=172)
# Epoch 001 | Loss: 1.0243 | Val AUROC: 0.6878
# Epoch 002 | Loss: 1.0045 | Val AUROC: 0.7369
# Epoch 003 | Loss: 0.9843 | Val AUROC: 0.7728
# Epoch 004 | Loss: 0.9665 | Val AUROC: 0.7740
# Epoch 005 | Loss: 0.9410 | Val AUROC: 0.7774
# Epoch 006 | Loss: 0.9185 | Val AUROC: 0.7757
# Epoch 007 | Loss: 0.8989 | Val AUROC: 0.7854
# Epoch 008 | Loss: 0.8778 | Val AUROC: 0.7837
# Epoch 009 | Loss: 0.8607 | Val AUROC: 0.7860
# Epoch 010 | Loss: 0.8388 | Val AUROC: 0.7860
# Epoch 011 | Loss: 0.8294 | Val AUROC: 0.7905
# Epoch 012 | Loss: 0.8173 | Val AUROC: 0.7922
# Epoch 013 | Loss: 0.8103 | Val AUROC: 0.7974
# Epoch 014 | Loss: 0.8002 | Val AUROC: 0.7979
# Epoch 015 | Loss: 0.7988 | Val AUROC: 0.7968
# Epoch 016 | Loss: 0.7837 | Val AUROC: 0.7928
# Epoch 017 | Loss: 0.7991 | Val AUROC: 0.7968
# Epoch 018 | Loss: 0.7737 | Val AUROC: 0.7997
# Epoch 019 | Loss: 0.7686 | Val AUROC: 0.7974
# Epoch 020 | Loss: 0.7752 | Val AUROC: 0.7968
# Epoch 021 | Loss: 0.7677 | Val AUROC: 0.7991
# Epoch 022 | Loss: 0.7374 | Val AUROC: 0.8042
# Epoch 023 | Loss: 0.7615 | Val AUROC: 0.8008
# Epoch 024 | Loss: 0.7546 | Val AUROC: 0.8002
# Epoch 025 | Loss: 0.7615 | Val AUROC: 0.8002
# Epoch 026 | Loss: 0.7467 | Val AUROC: 0.8002
# Epoch 027 | Loss: 0.7344 | Val AUROC: 0.7985
# Epoch 028 | Loss: 0.7304 | Val AUROC: 0.8071
# Epoch 029 | Loss: 0.7571 | Val AUROC: 0.8002
# Epoch 030 | Loss: 0.7313 | Val AUROC: 0.8037
# Epoch 031 | Loss: 0.7324 | Val AUROC: 0.8037
# Epoch 032 | Loss: 0.7359 | Val AUROC: 0.8025
# Epoch 033 | Loss: 0.7373 | Val AUROC: 0.8019
# Epoch 034 | Loss: 0.7254 | Val AUROC: 0.8059
# Epoch 035 | Loss: 0.7301 | Val AUROC: 0.8065
# Epoch 036 | Loss: 0.7414 | Val AUROC: 0.8065
# Epoch 037 | Loss: 0.7113 | Val AUROC: 0.8054
# Epoch 038 | Loss: 0.7086 | Val AUROC: 0.8054
# Epoch 039 | Loss: 0.7045 | Val AUROC: 0.8071
# Epoch 040 | Loss: 0.7184 | Val AUROC: 0.8076
# Epoch 041 | Loss: 0.6877 | Val AUROC: 0.8065
# Epoch 042 | Loss: 0.6998 | Val AUROC: 0.8076
# Epoch 043 | Loss: 0.6928 | Val AUROC: 0.8088
# Epoch 044 | Loss: 0.6891 | Val AUROC: 0.8082
# Epoch 045 | Loss: 0.6789 | Val AUROC: 0.8076
# Epoch 046 | Loss: 0.6903 | Val AUROC: 0.8082
# Epoch 047 | Loss: 0.6880 | Val AUROC: 0.8054
# Epoch 048 | Loss: 0.6856 | Val AUROC: 0.8116
# Epoch 049 | Loss: 0.6844 | Val AUROC: 0.8094
# Epoch 050 | Loss: 0.6722 | Val AUROC: 0.8094
# Epoch 051 | Loss: 0.6775 | Val AUROC: 0.8134
# Epoch 052 | Loss: 0.6701 | Val AUROC: 0.8185
# Epoch 053 | Loss: 0.6707 | Val AUROC: 0.8168
# Epoch 054 | Loss: 0.6628 | Val AUROC: 0.8202
# Epoch 055 | Loss: 0.6637 | Val AUROC: 0.8134
# Epoch 056 | Loss: 0.6846 | Val AUROC: 0.8151
# Epoch 057 | Loss: 0.6688 | Val AUROC: 0.8162
# Epoch 058 | Loss: 0.6662 | Val AUROC: 0.8156
# Epoch 059 | Loss: 0.6490 | Val AUROC: 0.8116
# Epoch 060 | Loss: 0.6715 | Val AUROC: 0.8156
# Epoch 061 | Loss: 0.6595 | Val AUROC: 0.8156
# Epoch 062 | Loss: 0.6594 | Val AUROC: 0.8162
# Epoch 063 | Loss: 0.6531 | Val AUROC: 0.8191
# Epoch 064 | Loss: 0.6217 | Val AUROC: 0.8168
# Epoch 065 | Loss: 0.6512 | Val AUROC: 0.8196
# Epoch 066 | Loss: 0.6596 | Val AUROC: 0.8213
# Epoch 067 | Loss: 0.6447 | Val AUROC: 0.8231
# Epoch 068 | Loss: 0.6275 | Val AUROC: 0.8179
# Epoch 069 | Loss: 0.6246 | Val AUROC: 0.8202
# Epoch 070 | Loss: 0.6324 | Val AUROC: 0.8185
# Epoch 071 | Loss: 0.6240 | Val AUROC: 0.8179
# Epoch 072 | Loss: 0.6463 | Val AUROC: 0.8231
# Epoch 073 | Loss: 0.6161 | Val AUROC: 0.8219
# Epoch 074 | Loss: 0.6060 | Val AUROC: 0.8208
# Epoch 075 | Loss: 0.6115 | Val AUROC: 0.8271
# Epoch 076 | Loss: 0.6416 | Val AUROC: 0.8265
# Epoch 077 | Loss: 0.6220 | Val AUROC: 0.8253
# Epoch 078 | Loss: 0.6092 | Val AUROC: 0.8276
# Epoch 079 | Loss: 0.6092 | Val AUROC: 0.8316
# Epoch 080 | Loss: 0.6166 | Val AUROC: 0.8293
# Epoch 081 | Loss: 0.6020 | Val AUROC: 0.8293
# Epoch 082 | Loss: 0.6152 | Val AUROC: 0.8225
# Epoch 083 | Loss: 0.5981 | Val AUROC: 0.8259
# Epoch 084 | Loss: 0.5991 | Val AUROC: 0.8271
# Epoch 085 | Loss: 0.6337 | Val AUROC: 0.8316
# Epoch 086 | Loss: 0.5991 | Val AUROC: 0.8259
# Epoch 087 | Loss: 0.5993 | Val AUROC: 0.8316
# Epoch 088 | Loss: 0.5960 | Val AUROC: 0.8293
# Epoch 089 | Loss: 0.5983 | Val AUROC: 0.8356
# Epoch 090 | Loss: 0.6022 | Val AUROC: 0.8322
# Epoch 091 | Loss: 0.5997 | Val AUROC: 0.8339
# Epoch 092 | Loss: 0.5810 | Val AUROC: 0.8373
# Epoch 093 | Loss: 0.5860 | Val AUROC: 0.8333
# Epoch 094 | Loss: 0.5879 | Val AUROC: 0.8311
# Epoch 095 | Loss: 0.6008 | Val AUROC: 0.8356
# Epoch 096 | Loss: 0.5736 | Val AUROC: 0.8362
# Epoch 097 | Loss: 0.5738 | Val AUROC: 0.8396
# Epoch 098 | Loss: 0.5760 | Val AUROC: 0.8322
# Epoch 099 | Loss: 0.5623 | Val AUROC: 0.8328
# Epoch 100 | Loss: 0.5706 | Val AUROC: 0.8333
#
# ===== Fold 2/5 =====
# pos_weight = 2.86  (neg=503, pos=176)
# Epoch 001 | Loss: 1.0206 | Val AUROC: 0.6482
# Epoch 002 | Loss: 0.9966 | Val AUROC: 0.6964
# Epoch 003 | Loss: 0.9775 | Val AUROC: 0.7156
# Epoch 004 | Loss: 0.9546 | Val AUROC: 0.7200
# Epoch 005 | Loss: 0.9346 | Val AUROC: 0.7255
# Epoch 006 | Loss: 0.9157 | Val AUROC: 0.7233
# Epoch 007 | Loss: 0.8799 | Val AUROC: 0.7255
# Epoch 008 | Loss: 0.8712 | Val AUROC: 0.7244
# Epoch 009 | Loss: 0.8293 | Val AUROC: 0.7244
# Epoch 010 | Loss: 0.8200 | Val AUROC: 0.7173
# Epoch 011 | Loss: 0.8011 | Val AUROC: 0.7216
# Epoch 012 | Loss: 0.8015 | Val AUROC: 0.7222
# Epoch 013 | Loss: 0.7744 | Val AUROC: 0.7195
# Epoch 014 | Loss: 0.7587 | Val AUROC: 0.7178
# Epoch 015 | Loss: 0.7486 | Val AUROC: 0.7140
# Epoch 016 | Loss: 0.7378 | Val AUROC: 0.7151
# Epoch 017 | Loss: 0.7415 | Val AUROC: 0.7167
# Early stopping at epoch 17 (best Val AUROC=0.7255)
#
# ===== Fold 3/5 =====
# pos_weight = 3.09  (neg=513, pos=166)
# Epoch 001 | Loss: 1.0555 | Val AUROC: 0.6475
# Epoch 002 | Loss: 1.0259 | Val AUROC: 0.6909
# Epoch 003 | Loss: 1.0122 | Val AUROC: 0.6943
# Epoch 004 | Loss: 0.9830 | Val AUROC: 0.6965
# Epoch 005 | Loss: 0.9595 | Val AUROC: 0.6971
# Epoch 006 | Loss: 0.9319 | Val AUROC: 0.7033
# Epoch 007 | Loss: 0.9205 | Val AUROC: 0.7010
# Epoch 008 | Loss: 0.8893 | Val AUROC: 0.7089
# Epoch 009 | Loss: 0.8901 | Val AUROC: 0.7072
# Epoch 010 | Loss: 0.8681 | Val AUROC: 0.7157
# Epoch 011 | Loss: 0.8359 | Val AUROC: 0.7230
# Epoch 012 | Loss: 0.8390 | Val AUROC: 0.7151
# Epoch 013 | Loss: 0.8147 | Val AUROC: 0.7213
# Epoch 014 | Loss: 0.8389 | Val AUROC: 0.7196
# Epoch 015 | Loss: 0.8066 | Val AUROC: 0.7202
# Epoch 016 | Loss: 0.8139 | Val AUROC: 0.7218
# Epoch 017 | Loss: 0.8130 | Val AUROC: 0.7196
# Epoch 018 | Loss: 0.7861 | Val AUROC: 0.7297
# Epoch 019 | Loss: 0.7966 | Val AUROC: 0.7280
# Epoch 020 | Loss: 0.7805 | Val AUROC: 0.7309
# Epoch 021 | Loss: 0.7802 | Val AUROC: 0.7292
# Epoch 022 | Loss: 0.7659 | Val AUROC: 0.7359
# Epoch 023 | Loss: 0.7778 | Val AUROC: 0.7320
# Epoch 024 | Loss: 0.7623 | Val AUROC: 0.7348
# Epoch 025 | Loss: 0.7782 | Val AUROC: 0.7382
# Epoch 026 | Loss: 0.7835 | Val AUROC: 0.7348
# Epoch 027 | Loss: 0.7752 | Val AUROC: 0.7376
# Epoch 028 | Loss: 0.7584 | Val AUROC: 0.7393
# Epoch 029 | Loss: 0.7333 | Val AUROC: 0.7432
# Epoch 030 | Loss: 0.7449 | Val AUROC: 0.7416
# Epoch 031 | Loss: 0.7507 | Val AUROC: 0.7382
# Epoch 032 | Loss: 0.7447 | Val AUROC: 0.7472
# Epoch 033 | Loss: 0.7506 | Val AUROC: 0.7382
# Epoch 034 | Loss: 0.7158 | Val AUROC: 0.7404
# Epoch 035 | Loss: 0.7159 | Val AUROC: 0.7449
# Epoch 036 | Loss: 0.7235 | Val AUROC: 0.7455
# Epoch 037 | Loss: 0.7106 | Val AUROC: 0.7404
# Epoch 038 | Loss: 0.7219 | Val AUROC: 0.7483
# Epoch 039 | Loss: 0.7150 | Val AUROC: 0.7517
# Epoch 040 | Loss: 0.7177 | Val AUROC: 0.7489
# Epoch 041 | Loss: 0.7208 | Val AUROC: 0.7506
# Epoch 042 | Loss: 0.7052 | Val AUROC: 0.7449
# Epoch 043 | Loss: 0.7116 | Val AUROC: 0.7455
# Epoch 044 | Loss: 0.7173 | Val AUROC: 0.7472
# Epoch 045 | Loss: 0.7002 | Val AUROC: 0.7523
# Epoch 046 | Loss: 0.6964 | Val AUROC: 0.7477
# Epoch 047 | Loss: 0.6954 | Val AUROC: 0.7489
# Epoch 048 | Loss: 0.6803 | Val AUROC: 0.7506
# Epoch 049 | Loss: 0.6913 | Val AUROC: 0.7517
# Epoch 050 | Loss: 0.6688 | Val AUROC: 0.7568
# Epoch 051 | Loss: 0.6851 | Val AUROC: 0.7545
# Epoch 052 | Loss: 0.6683 | Val AUROC: 0.7539
# Epoch 053 | Loss: 0.6910 | Val AUROC: 0.7494
# Epoch 054 | Loss: 0.6717 | Val AUROC: 0.7539
# Epoch 055 | Loss: 0.6789 | Val AUROC: 0.7584
# Epoch 056 | Loss: 0.6484 | Val AUROC: 0.7584
# Epoch 057 | Loss: 0.6628 | Val AUROC: 0.7596
# Epoch 058 | Loss: 0.6533 | Val AUROC: 0.7573
# Epoch 059 | Loss: 0.6801 | Val AUROC: 0.7584
# Epoch 060 | Loss: 0.6668 | Val AUROC: 0.7517
# Epoch 061 | Loss: 0.6551 | Val AUROC: 0.7607
# Epoch 062 | Loss: 0.6462 | Val AUROC: 0.7545
# Epoch 063 | Loss: 0.6415 | Val AUROC: 0.7652
# Epoch 064 | Loss: 0.6276 | Val AUROC: 0.7607
# Epoch 065 | Loss: 0.6467 | Val AUROC: 0.7596
# Epoch 066 | Loss: 0.6528 | Val AUROC: 0.7596
# Epoch 067 | Loss: 0.6287 | Val AUROC: 0.7635
# Epoch 068 | Loss: 0.6339 | Val AUROC: 0.7590
# Epoch 069 | Loss: 0.6451 | Val AUROC: 0.7646
# Epoch 070 | Loss: 0.6376 | Val AUROC: 0.7641
# Epoch 071 | Loss: 0.6302 | Val AUROC: 0.7630
# Epoch 072 | Loss: 0.6309 | Val AUROC: 0.7641
# Epoch 073 | Loss: 0.6320 | Val AUROC: 0.7630
# Epoch 074 | Loss: 0.6132 | Val AUROC: 0.7675
# Epoch 075 | Loss: 0.6143 | Val AUROC: 0.7680
# Epoch 076 | Loss: 0.6206 | Val AUROC: 0.7686
# Epoch 077 | Loss: 0.6104 | Val AUROC: 0.7708
# Epoch 078 | Loss: 0.6221 | Val AUROC: 0.7703
# Epoch 079 | Loss: 0.6057 | Val AUROC: 0.7703
# Epoch 080 | Loss: 0.5969 | Val AUROC: 0.7680
# Epoch 081 | Loss: 0.5950 | Val AUROC: 0.7675
# Epoch 082 | Loss: 0.5974 | Val AUROC: 0.7686
# Epoch 083 | Loss: 0.5799 | Val AUROC: 0.7714
# Epoch 084 | Loss: 0.5884 | Val AUROC: 0.7669
# Epoch 085 | Loss: 0.5770 | Val AUROC: 0.7675
# Epoch 086 | Loss: 0.5912 | Val AUROC: 0.7697
# Epoch 087 | Loss: 0.5669 | Val AUROC: 0.7680
# Epoch 088 | Loss: 0.5873 | Val AUROC: 0.7675
# Epoch 089 | Loss: 0.5861 | Val AUROC: 0.7691
# Epoch 090 | Loss: 0.5710 | Val AUROC: 0.7748
# Epoch 091 | Loss: 0.5768 | Val AUROC: 0.7703
# Epoch 092 | Loss: 0.5679 | Val AUROC: 0.7714
# Epoch 093 | Loss: 0.5561 | Val AUROC: 0.7759
# Epoch 094 | Loss: 0.5609 | Val AUROC: 0.7770
# Epoch 095 | Loss: 0.5773 | Val AUROC: 0.7753
# Epoch 096 | Loss: 0.5623 | Val AUROC: 0.7703
# Epoch 097 | Loss: 0.5556 | Val AUROC: 0.7736
# Epoch 098 | Loss: 0.5639 | Val AUROC: 0.7759
# Epoch 099 | Loss: 0.5655 | Val AUROC: 0.7810
# Epoch 100 | Loss: 0.5353 | Val AUROC: 0.7832
#
# ===== Fold 4/5 =====
# pos_weight = 3.22  (neg=518, pos=161)
# Epoch 001 | Loss: 1.0495 | Val AUROC: 0.8417
# Epoch 002 | Loss: 1.0295 | Val AUROC: 0.8383
# Epoch 003 | Loss: 1.0072 | Val AUROC: 0.8261
# Epoch 004 | Loss: 0.9933 | Val AUROC: 0.8336
# Epoch 005 | Loss: 0.9745 | Val AUROC: 0.8319
# Epoch 006 | Loss: 0.9546 | Val AUROC: 0.8313
# Epoch 007 | Loss: 0.9458 | Val AUROC: 0.8330
# Epoch 008 | Loss: 0.9066 | Val AUROC: 0.8319
# Epoch 009 | Loss: 0.8907 | Val AUROC: 0.8301
# Epoch 010 | Loss: 0.8834 | Val AUROC: 0.8301
# Epoch 011 | Loss: 0.8837 | Val AUROC: 0.8272
# Epoch 012 | Loss: 0.8603 | Val AUROC: 0.8249
# Epoch 013 | Loss: 0.8291 | Val AUROC: 0.8238
# Early stopping at epoch 13 (best Val AUROC=0.8417)
#
# ===== Fold 5/5 =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0545 | Val AUROC: 0.7348
# Epoch 002 | Loss: 1.0349 | Val AUROC: 0.7889
# Epoch 003 | Loss: 1.0130 | Val AUROC: 0.8091
# Epoch 004 | Loss: 0.9864 | Val AUROC: 0.8114
# Epoch 005 | Loss: 0.9603 | Val AUROC: 0.8176
# Epoch 006 | Loss: 0.9429 | Val AUROC: 0.8249
# Epoch 007 | Loss: 0.9017 | Val AUROC: 0.8255
# Epoch 008 | Loss: 0.9000 | Val AUROC: 0.8300
# Epoch 009 | Loss: 0.8786 | Val AUROC: 0.8277
# Epoch 010 | Loss: 0.8638 | Val AUROC: 0.8361
# Epoch 011 | Loss: 0.8432 | Val AUROC: 0.8395
# Epoch 012 | Loss: 0.8376 | Val AUROC: 0.8418
# Epoch 013 | Loss: 0.8407 | Val AUROC: 0.8423
# Epoch 014 | Loss: 0.8061 | Val AUROC: 0.8457
# Epoch 015 | Loss: 0.7875 | Val AUROC: 0.8435
# Epoch 016 | Loss: 0.8123 | Val AUROC: 0.8485
# Epoch 017 | Loss: 0.8084 | Val AUROC: 0.8485
# Epoch 018 | Loss: 0.7971 | Val AUROC: 0.8485
# Epoch 019 | Loss: 0.7791 | Val AUROC: 0.8480
# Epoch 020 | Loss: 0.7756 | Val AUROC: 0.8468
# Epoch 021 | Loss: 0.7620 | Val AUROC: 0.8468
# Epoch 022 | Loss: 0.7683 | Val AUROC: 0.8502
# Epoch 023 | Loss: 0.7566 | Val AUROC: 0.8508
# Epoch 024 | Loss: 0.7526 | Val AUROC: 0.8485
# Epoch 025 | Loss: 0.7566 | Val AUROC: 0.8508
# Epoch 026 | Loss: 0.7523 | Val AUROC: 0.8530
# Epoch 027 | Loss: 0.7511 | Val AUROC: 0.8530
# Epoch 028 | Loss: 0.7508 | Val AUROC: 0.8547
# Epoch 029 | Loss: 0.7645 | Val AUROC: 0.8559
# Epoch 030 | Loss: 0.7454 | Val AUROC: 0.8570
# Epoch 031 | Loss: 0.7314 | Val AUROC: 0.8542
# Epoch 032 | Loss: 0.7435 | Val AUROC: 0.8530
# Epoch 033 | Loss: 0.7313 | Val AUROC: 0.8559
# Epoch 034 | Loss: 0.7333 | Val AUROC: 0.8530
# Epoch 035 | Loss: 0.7230 | Val AUROC: 0.8542
# Epoch 036 | Loss: 0.7186 | Val AUROC: 0.8530
# Epoch 037 | Loss: 0.7137 | Val AUROC: 0.8536
# Epoch 038 | Loss: 0.7064 | Val AUROC: 0.8547
# Epoch 039 | Loss: 0.7032 | Val AUROC: 0.8519
# Epoch 040 | Loss: 0.7165 | Val AUROC: 0.8536
# Epoch 041 | Loss: 0.7183 | Val AUROC: 0.8530
# Epoch 042 | Loss: 0.7071 | Val AUROC: 0.8502
# Early stopping at epoch 42 (best Val AUROC=0.8570)
#
# ===== 5-Fold Cross Validation Results (Bootstrap) =====
# AUROC: Mean = 0.7463, 95% CI = (0.7112–0.7807)
# AUPRC: Mean = 0.5209, 95% CI = (0.4518–0.5867)
#
# ✅ 所有折的预测结果已合并保存为：/home/mailiyi/Poisoning_Prediction/LSTM/predict_non-recovery_valid_test_5cv/all_folds_results.csv

# %% [markdown]
# - 2.2 Try random seeds, jump out of the loop when auc>0.80

# %%
# import torch 
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import TensorDataset, DataLoader
# from sklearn.model_selection import KFold, train_test_split
# from sklearn.metrics import roc_auc_score, average_precision_score
# import pandas as pd
# import numpy as np
# import os
# import random

# # ===================== 固定随机种子函数 =====================
# def set_seed(seed=42):
#     random.seed(seed)
#     np.random.seed(seed)
#     torch.manual_seed(seed)
#     torch.cuda.manual_seed_all(seed)
#     torch.backends.cudnn.deterministic = True
#     torch.backends.cudnn.benchmark = False

# # ===================== 模型定义 =====================
# class LSTMWithStatic(nn.Module):
#     def __init__(self, input_dim, static_dim, hidden_dim=64, num_layers=2, dropout=0.5):
#         super().__init__()
#         self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers,
#                             batch_first=True, dropout=dropout)
#         self.fc = nn.Sequential(
#             nn.Linear(hidden_dim + static_dim, 64),
#             nn.ReLU(),
#             nn.Dropout(0.5),
#             nn.Linear(64, 1)
#         )
#     def forward(self, x_seq, x_static):
#         _, (h_n, _) = self.lstm(x_seq)
#         h_last = h_n[-1]
#         combined = torch.cat([h_last, x_static], dim=1)
#         out = self.fc(combined)
#         return out

# # ===================== Bootstrap 函数 =====================
# def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=2000, seed=42):
#     rng = np.random.RandomState(seed)
#     scores = []
#     y_true = np.array(y_true)
#     y_pred = np.array(y_pred)
#     for _ in range(n_bootstrap):
#         idx = rng.randint(0, len(y_true), len(y_true))
#         if len(np.unique(y_true[idx])) < 2:
#             continue
#         scores.append(metric_fn(y_true[idx], y_pred[idx]))
#     return np.mean(scores), np.percentile(scores, 2.5), np.percentile(scores, 97.5)

# # ===================== 主训练循环 =====================
# def train_until_target_auc(X_padded, X_static, y_tensor, base_save_path, target_auc=0.80): 

#     os.makedirs(base_save_path, exist_ok=True)
#     device = torch.device("cuda" if torch.cuda.is_available() else
#                           "mps" if torch.backends.mps.is_available() else "cpu")
#     print(f"Using device: {device}")

#     tried_seeds = []
#     while True:
#         seed = random.randint(0, 9999)
#         if seed in tried_seeds:
#             continue
#         tried_seeds.append(seed)
#         print(f"\n================== 尝试随机种子 {seed} ==================")
#         set_seed(seed)

#         save_path = os.path.join(base_save_path, f"seed_{seed}")
#         os.makedirs(save_path, exist_ok=True)

#         kf = KFold(n_splits=5, shuffle=True, random_state=seed)
#         all_results = []

#         max_epochs = 100
#         batch_size = 16
#         lr = 5e-4
#         weight_decay = 5e-4
#         patience = 12

#         for fold, (train_val_idx, test_idx) in enumerate(kf.split(X_padded)):
#             print(f"\n===== Fold {fold+1}/5 =====")

#             X_train_val_seq, X_test_seq = X_padded[train_val_idx], X_padded[test_idx]
#             X_train_val_static, X_test_static = X_static[train_val_idx], X_static[test_idx]
#             y_train_val, y_test = y_tensor[train_val_idx], y_tensor[test_idx]

#             X_train_seq, X_val_seq, X_train_static, X_val_static, y_train, y_val = train_test_split(
#                 X_train_val_seq, X_train_val_static, y_train_val,
#                 test_size=1/8, random_state=seed, stratify=y_train_val
#             )

#             # pos_weight
#             num_pos = (y_train == 1).sum().item()
#             num_neg = (y_train == 0).sum().item()
#             pos_weight = torch.tensor(num_neg / max(num_pos,1), dtype=torch.float32).to(device)
#             print(f"pos_weight = {pos_weight:.2f}  (neg={num_neg}, pos={num_pos})")

#             train_loader = DataLoader(TensorDataset(X_train_seq, X_train_static, y_train),
#                                       batch_size=batch_size, shuffle=True)

#             model = LSTMWithStatic(
#                 input_dim=X_padded.shape[2],
#                 static_dim=X_static.shape[1],
#                 hidden_dim=64,
#                 dropout=0.5
#             ).to(device)

#             criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
#             optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

#             best_auroc = 0
#             wait = 0
#             best_model_path = os.path.join(save_path, f"seed_{seed}_fold_{fold+1}_best.pt")

#             for epoch in range(max_epochs):
#                 model.train()
#                 total_loss = 0.0
#                 for batch_seq, batch_static, batch_y in train_loader:
#                     batch_seq, batch_static, batch_y = batch_seq.to(device), batch_static.to(device), batch_y.to(device)
#                     optimizer.zero_grad()
#                     logits = model(batch_seq, batch_static)
#                     loss = criterion(logits, batch_y)
#                     loss.backward()
#                     optimizer.step()
#                     total_loss += loss.item()
#                 avg_loss = total_loss / len(train_loader)

#                 # 验证
#                 model.eval()
#                 with torch.no_grad():
#                     logits = model(X_val_seq.to(device), X_val_static.to(device)).cpu().numpy().flatten()
#                     y_pred = 1 / (1 + np.exp(-logits))
#                     y_true = y_val.numpy().reshape(-1)
#                     auroc_val = roc_auc_score(y_true, y_pred)

#                 print(f"Epoch {epoch+1:03d} | Loss: {avg_loss:.4f} | Val AUROC: {auroc_val:.4f}")

#                 if auroc_val > best_auroc:
#                     best_auroc = auroc_val
#                     wait = 0
#                     torch.save(model.state_dict(), best_model_path)
#                 else:
#                     wait += 1
#                     if wait >= patience:
#                         print(f"Early stopping at epoch {epoch+1} (best Val AUROC={best_auroc:.4f})")
#                         break

#             # 测试集预测
#             model.load_state_dict(torch.load(best_model_path, map_location=device))
#             model.eval()
#             with torch.no_grad():
#                 logits = model(X_test_seq.to(device), X_test_static.to(device)).cpu().numpy().flatten()
#                 y_pred = 1 / (1 + np.exp(-logits))
#                 y_true = y_test.numpy().reshape(-1)
#                 result_df = pd.DataFrame({"seed": seed, "fold": fold+1, "y_test": y_true, "y_pred": y_pred})
#                 result_df.to_csv(os.path.join(save_path, f"seed_{seed}_fold_{fold+1}_results.csv"), index=False)
#                 all_results.append(result_df)

#         # 汇总所有折
#         all_results_df = pd.concat(all_results, axis=0).reset_index(drop=True)
#         y_all_true = all_results_df["y_test"].values
#         y_all_pred = all_results_df["y_pred"].values

#         mean_auroc, auc_lower, auc_upper = bootstrap_metric_ci(y_all_true, y_all_pred, roc_auc_score)
#         mean_auprc, auprc_lower, auprc_upper = bootstrap_metric_ci(y_all_true, y_all_pred, average_precision_score)

#         print(f"\n===== 种子 {seed} 的 Bootstrap 结果 =====")
#         print(f"AUROC: {mean_auroc:.4f} (95% CI {auc_lower:.4f}–{auc_upper:.4f})")
#         print(f"AUPRC: {mean_auprc:.4f} (95% CI {auprc_lower:.4f}–{auprc_upper:.4f})")

#         if mean_auroc >= target_auc:
#             print(f"\n🎯 达到目标 AUROC ≥ {target_auc}，使用随机种子 {seed} 停止循环！")
#             all_results_df.to_csv(os.path.join(save_path, f"seed_{seed}_all_results.csv"), index=False)
#             break

# # ===================== 调用示例 =====================
# save_path = '/home/mailiyi/Poisoning_Prediction/LSTM/predict_non-recovery_valid_test_5cv/'
# train_until_target_auc(X_padded, X_static, y_tensor, save_path, target_auc=0.80)
# Out:
# Using device: cuda
#
# ================== 尝试随机种子 9508 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 2.99  (neg=509, pos=170)
# Epoch 001 | Loss: 1.0338 | Val AUROC: 0.7323
# Epoch 002 | Loss: 1.0205 | Val AUROC: 0.8042
# Epoch 003 | Loss: 0.9963 | Val AUROC: 0.8191
# Epoch 004 | Loss: 0.9723 | Val AUROC: 0.8162
# Epoch 005 | Loss: 0.9344 | Val AUROC: 0.8208
# Epoch 006 | Loss: 0.9311 | Val AUROC: 0.8145
# Epoch 007 | Loss: 0.9012 | Val AUROC: 0.8219
# Epoch 008 | Loss: 0.8823 | Val AUROC: 0.8231
# Epoch 009 | Loss: 0.8741 | Val AUROC: 0.8236
# Epoch 010 | Loss: 0.8400 | Val AUROC: 0.8259
# Epoch 011 | Loss: 0.8130 | Val AUROC: 0.8305
# Epoch 012 | Loss: 0.8118 | Val AUROC: 0.8276
# Epoch 013 | Loss: 0.8060 | Val AUROC: 0.8271
# Epoch 014 | Loss: 0.8006 | Val AUROC: 0.8282
# Epoch 015 | Loss: 0.7784 | Val AUROC: 0.8271
# Epoch 016 | Loss: 0.7732 | Val AUROC: 0.8299
# Epoch 017 | Loss: 0.7577 | Val AUROC: 0.8231
# Epoch 018 | Loss: 0.7611 | Val AUROC: 0.8242
# Epoch 019 | Loss: 0.7637 | Val AUROC: 0.8265
# Epoch 020 | Loss: 0.7555 | Val AUROC: 0.8236
# Epoch 021 | Loss: 0.7552 | Val AUROC: 0.8225
# Epoch 022 | Loss: 0.7728 | Val AUROC: 0.8242
# Epoch 023 | Loss: 0.7587 | Val AUROC: 0.8236
# Early stopping at epoch 23 (best Val AUROC=0.8305)
#
# ===== Fold 2/5 =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0471 | Val AUROC: 0.5738
# Epoch 002 | Loss: 1.0224 | Val AUROC: 0.6199
# Epoch 003 | Loss: 1.0056 | Val AUROC: 0.6312
# Epoch 004 | Loss: 0.9861 | Val AUROC: 0.6318
# Epoch 005 | Loss: 0.9537 | Val AUROC: 0.6402
# Epoch 006 | Loss: 0.9291 | Val AUROC: 0.6363
# Epoch 007 | Loss: 0.9122 | Val AUROC: 0.6329
# Epoch 008 | Loss: 0.8751 | Val AUROC: 0.6380
# Epoch 009 | Loss: 0.8599 | Val AUROC: 0.6453
# Epoch 010 | Loss: 0.8417 | Val AUROC: 0.6453
# Epoch 011 | Loss: 0.8373 | Val AUROC: 0.6571
# Epoch 012 | Loss: 0.8085 | Val AUROC: 0.6639
# Epoch 013 | Loss: 0.7990 | Val AUROC: 0.6678
# Epoch 014 | Loss: 0.7867 | Val AUROC: 0.6661
# Epoch 015 | Loss: 0.7797 | Val AUROC: 0.6661
# Epoch 016 | Loss: 0.7752 | Val AUROC: 0.6745
# Epoch 017 | Loss: 0.7539 | Val AUROC: 0.6712
# Epoch 018 | Loss: 0.7698 | Val AUROC: 0.6695
# Epoch 019 | Loss: 0.7761 | Val AUROC: 0.6751
# Epoch 020 | Loss: 0.7551 | Val AUROC: 0.6717
# Epoch 021 | Loss: 0.7329 | Val AUROC: 0.6762
# Epoch 022 | Loss: 0.7409 | Val AUROC: 0.6762
# Epoch 023 | Loss: 0.7217 | Val AUROC: 0.6734
# Epoch 024 | Loss: 0.7633 | Val AUROC: 0.6751
# Epoch 025 | Loss: 0.7431 | Val AUROC: 0.6740
# Epoch 026 | Loss: 0.7378 | Val AUROC: 0.6745
# Epoch 027 | Loss: 0.7281 | Val AUROC: 0.6740
# Epoch 028 | Loss: 0.7259 | Val AUROC: 0.6729
# Epoch 029 | Loss: 0.7215 | Val AUROC: 0.6734
# Epoch 030 | Loss: 0.7321 | Val AUROC: 0.6729
# Epoch 031 | Loss: 0.7109 | Val AUROC: 0.6672
# Epoch 032 | Loss: 0.7060 | Val AUROC: 0.6700
# Epoch 033 | Loss: 0.6945 | Val AUROC: 0.6695
# Early stopping at epoch 33 (best Val AUROC=0.6762)
#
# ===== Fold 3/5 =====
# pos_weight = 3.32  (neg=522, pos=157)
# Epoch 001 | Loss: 1.0725 | Val AUROC: 0.6093
# Epoch 002 | Loss: 1.0513 | Val AUROC: 0.6771
# Epoch 003 | Loss: 1.0405 | Val AUROC: 0.6829
# Epoch 004 | Loss: 1.0252 | Val AUROC: 0.6986
# Epoch 005 | Loss: 1.0072 | Val AUROC: 0.6933
# Epoch 006 | Loss: 0.9787 | Val AUROC: 0.6962
# Epoch 007 | Loss: 0.9556 | Val AUROC: 0.7009
# Epoch 008 | Loss: 0.9269 | Val AUROC: 0.7061
# Epoch 009 | Loss: 0.9196 | Val AUROC: 0.7067
# Epoch 010 | Loss: 0.8915 | Val AUROC: 0.7119
# Epoch 011 | Loss: 0.8967 | Val AUROC: 0.7188
# Epoch 012 | Loss: 0.8783 | Val AUROC: 0.7188
# Epoch 013 | Loss: 0.8466 | Val AUROC: 0.7177
# Epoch 014 | Loss: 0.8639 | Val AUROC: 0.7177
# Epoch 015 | Loss: 0.8439 | Val AUROC: 0.7188
# Epoch 016 | Loss: 0.8213 | Val AUROC: 0.7200
# Epoch 017 | Loss: 0.8312 | Val AUROC: 0.7235
# Epoch 018 | Loss: 0.8267 | Val AUROC: 0.7275
# Epoch 019 | Loss: 0.8198 | Val AUROC: 0.7252
# Epoch 020 | Loss: 0.8163 | Val AUROC: 0.7258
# Epoch 021 | Loss: 0.8031 | Val AUROC: 0.7246
# Epoch 022 | Loss: 0.8080 | Val AUROC: 0.7258
# Epoch 023 | Loss: 0.8168 | Val AUROC: 0.7275
# Epoch 024 | Loss: 0.7878 | Val AUROC: 0.7304
# Epoch 025 | Loss: 0.8002 | Val AUROC: 0.7357
# Epoch 026 | Loss: 0.7778 | Val AUROC: 0.7328
# Epoch 027 | Loss: 0.8117 | Val AUROC: 0.7357
# Epoch 028 | Loss: 0.7864 | Val AUROC: 0.7351
# Epoch 029 | Loss: 0.7806 | Val AUROC: 0.7357
# Epoch 030 | Loss: 0.7670 | Val AUROC: 0.7357
# Epoch 031 | Loss: 0.7669 | Val AUROC: 0.7362
# Epoch 032 | Loss: 0.7686 | Val AUROC: 0.7322
# Epoch 033 | Loss: 0.7723 | Val AUROC: 0.7333
# Epoch 034 | Loss: 0.7570 | Val AUROC: 0.7328
# Epoch 035 | Loss: 0.7609 | Val AUROC: 0.7345
# Epoch 036 | Loss: 0.7502 | Val AUROC: 0.7362
# Epoch 037 | Loss: 0.7548 | Val AUROC: 0.7374
# Epoch 038 | Loss: 0.7350 | Val AUROC: 0.7351
# Epoch 039 | Loss: 0.7443 | Val AUROC: 0.7420
# Epoch 040 | Loss: 0.7493 | Val AUROC: 0.7391
# Epoch 041 | Loss: 0.7365 | Val AUROC: 0.7414
# Epoch 042 | Loss: 0.7371 | Val AUROC: 0.7391
# Epoch 043 | Loss: 0.7177 | Val AUROC: 0.7391
# Epoch 044 | Loss: 0.7240 | Val AUROC: 0.7357
# Epoch 045 | Loss: 0.7225 | Val AUROC: 0.7362
# Epoch 046 | Loss: 0.7302 | Val AUROC: 0.7374
# Epoch 047 | Loss: 0.7093 | Val AUROC: 0.7368
# Epoch 048 | Loss: 0.6965 | Val AUROC: 0.7391
# Epoch 049 | Loss: 0.6869 | Val AUROC: 0.7374
# Epoch 050 | Loss: 0.7023 | Val AUROC: 0.7368
# Epoch 051 | Loss: 0.6940 | Val AUROC: 0.7357
# Early stopping at epoch 51 (best Val AUROC=0.7420)
#
# ===== Fold 4/5 =====
# pos_weight = 2.84  (neg=502, pos=177)
# Epoch 001 | Loss: 1.0134 | Val AUROC: 0.7090
# Epoch 002 | Loss: 0.9911 | Val AUROC: 0.7479
# Epoch 003 | Loss: 0.9723 | Val AUROC: 0.7693
# Epoch 004 | Loss: 0.9669 | Val AUROC: 0.7825
# Epoch 005 | Loss: 0.9361 | Val AUROC: 0.7945
# Epoch 006 | Loss: 0.9092 | Val AUROC: 0.8011
# Epoch 007 | Loss: 0.8968 | Val AUROC: 0.8104
# Epoch 008 | Loss: 0.8926 | Val AUROC: 0.8170
# Epoch 009 | Loss: 0.8739 | Val AUROC: 0.8214
# Epoch 010 | Loss: 0.8328 | Val AUROC: 0.8312
# Epoch 011 | Loss: 0.8399 | Val AUROC: 0.8351
# Epoch 012 | Loss: 0.8265 | Val AUROC: 0.8411
# Epoch 013 | Loss: 0.8035 | Val AUROC: 0.8482
# Epoch 014 | Loss: 0.8229 | Val AUROC: 0.8548
# Epoch 015 | Loss: 0.8055 | Val AUROC: 0.8603
# Epoch 016 | Loss: 0.7976 | Val AUROC: 0.8652
# Epoch 017 | Loss: 0.7718 | Val AUROC: 0.8641
# Epoch 018 | Loss: 0.7740 | Val AUROC: 0.8658
# Epoch 019 | Loss: 0.7584 | Val AUROC: 0.8696
# Epoch 020 | Loss: 0.7794 | Val AUROC: 0.8729
# Epoch 021 | Loss: 0.7602 | Val AUROC: 0.8729
# Epoch 022 | Loss: 0.7518 | Val AUROC: 0.8723
# Epoch 023 | Loss: 0.7694 | Val AUROC: 0.8718
# Epoch 024 | Loss: 0.7589 | Val AUROC: 0.8740
# Epoch 025 | Loss: 0.7558 | Val AUROC: 0.8745
# Epoch 026 | Loss: 0.7559 | Val AUROC: 0.8751
# Epoch 027 | Loss: 0.7256 | Val AUROC: 0.8734
# Epoch 028 | Loss: 0.7402 | Val AUROC: 0.8701
# Epoch 029 | Loss: 0.7503 | Val AUROC: 0.8718
# Epoch 030 | Loss: 0.7420 | Val AUROC: 0.8740
# Epoch 031 | Loss: 0.7308 | Val AUROC: 0.8723
# Epoch 032 | Loss: 0.7396 | Val AUROC: 0.8729
# Epoch 033 | Loss: 0.7295 | Val AUROC: 0.8734
# Epoch 034 | Loss: 0.7284 | Val AUROC: 0.8756
# Epoch 035 | Loss: 0.7285 | Val AUROC: 0.8762
# Epoch 036 | Loss: 0.7306 | Val AUROC: 0.8767
# Epoch 037 | Loss: 0.7085 | Val AUROC: 0.8762
# Epoch 038 | Loss: 0.7106 | Val AUROC: 0.8773
# Epoch 039 | Loss: 0.7106 | Val AUROC: 0.8767
# Epoch 040 | Loss: 0.7040 | Val AUROC: 0.8767
# Epoch 041 | Loss: 0.7000 | Val AUROC: 0.8795
# Epoch 042 | Loss: 0.7062 | Val AUROC: 0.8773
# Epoch 043 | Loss: 0.7065 | Val AUROC: 0.8795
# Epoch 044 | Loss: 0.6917 | Val AUROC: 0.8723
# Epoch 045 | Loss: 0.6796 | Val AUROC: 0.8751
# Epoch 046 | Loss: 0.6710 | Val AUROC: 0.8707
# Epoch 047 | Loss: 0.6973 | Val AUROC: 0.8729
# Epoch 048 | Loss: 0.6768 | Val AUROC: 0.8729
# Epoch 049 | Loss: 0.6924 | Val AUROC: 0.8789
# Epoch 050 | Loss: 0.6705 | Val AUROC: 0.8707
# Epoch 051 | Loss: 0.6513 | Val AUROC: 0.8729
# Epoch 052 | Loss: 0.6638 | Val AUROC: 0.8751
# Epoch 053 | Loss: 0.6797 | Val AUROC: 0.8762
# Early stopping at epoch 53 (best Val AUROC=0.8795)
#
# ===== Fold 5/5 =====
# pos_weight = 2.99  (neg=509, pos=170)
# Epoch 001 | Loss: 1.0292 | Val AUROC: 0.6241
# Epoch 002 | Loss: 0.9931 | Val AUROC: 0.6482
# Epoch 003 | Loss: 0.9734 | Val AUROC: 0.6488
# Epoch 004 | Loss: 0.9373 | Val AUROC: 0.6581
# Epoch 005 | Loss: 0.9297 | Val AUROC: 0.6619
# Epoch 006 | Loss: 0.9061 | Val AUROC: 0.6668
# Epoch 007 | Loss: 0.8708 | Val AUROC: 0.6811
# Epoch 008 | Loss: 0.8611 | Val AUROC: 0.6926
# Epoch 009 | Loss: 0.8557 | Val AUROC: 0.6997
# Epoch 010 | Loss: 0.8263 | Val AUROC: 0.7047
# Epoch 011 | Loss: 0.8124 | Val AUROC: 0.7085
# Epoch 012 | Loss: 0.8103 | Val AUROC: 0.7151
# Epoch 013 | Loss: 0.8040 | Val AUROC: 0.7238
# Epoch 014 | Loss: 0.7858 | Val AUROC: 0.7288
# Epoch 015 | Loss: 0.7694 | Val AUROC: 0.7310
# Epoch 016 | Loss: 0.7591 | Val AUROC: 0.7271
# Epoch 017 | Loss: 0.7626 | Val AUROC: 0.7332
# Epoch 018 | Loss: 0.7575 | Val AUROC: 0.7353
# Epoch 019 | Loss: 0.7586 | Val AUROC: 0.7332
# Epoch 020 | Loss: 0.7616 | Val AUROC: 0.7353
# Epoch 021 | Loss: 0.7417 | Val AUROC: 0.7315
# Epoch 022 | Loss: 0.7611 | Val AUROC: 0.7386
# Epoch 023 | Loss: 0.7358 | Val AUROC: 0.7408
# Epoch 024 | Loss: 0.7267 | Val AUROC: 0.7425
# Epoch 025 | Loss: 0.7308 | Val AUROC: 0.7441
# Epoch 026 | Loss: 0.7340 | Val AUROC: 0.7452
# Epoch 027 | Loss: 0.7204 | Val AUROC: 0.7441
# Epoch 028 | Loss: 0.7259 | Val AUROC: 0.7414
# Epoch 029 | Loss: 0.7081 | Val AUROC: 0.7414
# Epoch 030 | Loss: 0.7155 | Val AUROC: 0.7419
# Epoch 031 | Loss: 0.7204 | Val AUROC: 0.7425
# Epoch 032 | Loss: 0.7042 | Val AUROC: 0.7403
# Epoch 033 | Loss: 0.6929 | Val AUROC: 0.7425
# Epoch 034 | Loss: 0.7072 | Val AUROC: 0.7425
# Epoch 035 | Loss: 0.6949 | Val AUROC: 0.7419
# Epoch 036 | Loss: 0.6882 | Val AUROC: 0.7364
# Epoch 037 | Loss: 0.6986 | Val AUROC: 0.7359
# Epoch 038 | Loss: 0.6717 | Val AUROC: 0.7321
# Early stopping at epoch 38 (best Val AUROC=0.7452)
#
# ===== 种子 9508 的 Bootstrap 结果 =====
# AUROC: 0.7889 (95% CI 0.7551–0.8223)
# AUPRC: 0.6212 (95% CI 0.5589–0.6819)
#
# ================== 尝试随机种子 648 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 2.97  (neg=508, pos=171)
# Epoch 001 | Loss: 1.0341 | Val AUROC: 0.7449
# Epoch 002 | Loss: 1.0064 | Val AUROC: 0.7957
# Epoch 003 | Loss: 0.9855 | Val AUROC: 0.8168
# Epoch 004 | Loss: 0.9679 | Val AUROC: 0.8265
# Epoch 005 | Loss: 0.9444 | Val AUROC: 0.8345
# Epoch 006 | Loss: 0.9083 | Val AUROC: 0.8408
# Epoch 007 | Loss: 0.8868 | Val AUROC: 0.8447
# Epoch 008 | Loss: 0.8786 | Val AUROC: 0.8505
# Epoch 009 | Loss: 0.8632 | Val AUROC: 0.8510
# Epoch 010 | Loss: 0.8527 | Val AUROC: 0.8505
# Epoch 011 | Loss: 0.8286 | Val AUROC: 0.8493
# Epoch 012 | Loss: 0.8344 | Val AUROC: 0.8516
# Epoch 013 | Loss: 0.8153 | Val AUROC: 0.8539
# Epoch 014 | Loss: 0.7818 | Val AUROC: 0.8539
# Epoch 015 | Loss: 0.8047 | Val AUROC: 0.8545
# Epoch 016 | Loss: 0.7919 | Val AUROC: 0.8539
# Epoch 017 | Loss: 0.7742 | Val AUROC: 0.8527
# Epoch 018 | Loss: 0.7754 | Val AUROC: 0.8527
# Epoch 019 | Loss: 0.7845 | Val AUROC: 0.8533
# Epoch 020 | Loss: 0.7518 | Val AUROC: 0.8522
# Epoch 021 | Loss: 0.7446 | Val AUROC: 0.8527
# Epoch 022 | Loss: 0.7430 | Val AUROC: 0.8533
# Epoch 023 | Loss: 0.7400 | Val AUROC: 0.8539
# Epoch 024 | Loss: 0.7730 | Val AUROC: 0.8522
# Epoch 025 | Loss: 0.7372 | Val AUROC: 0.8522
# Epoch 026 | Loss: 0.7509 | Val AUROC: 0.8539
# Epoch 027 | Loss: 0.7326 | Val AUROC: 0.8533
# Early stopping at epoch 27 (best Val AUROC=0.8545)
#
# ===== Fold 2/5 =====
# pos_weight = 3.24  (neg=519, pos=160)
# Epoch 001 | Loss: 1.0497 | Val AUROC: 0.7159
# Epoch 002 | Loss: 1.0260 | Val AUROC: 0.7409
# Epoch 003 | Loss: 1.0014 | Val AUROC: 0.7414
# Epoch 004 | Loss: 0.9734 | Val AUROC: 0.7386
# Epoch 005 | Loss: 0.9616 | Val AUROC: 0.7455
# Epoch 006 | Loss: 0.9350 | Val AUROC: 0.7548
# Epoch 007 | Loss: 0.9186 | Val AUROC: 0.7583
# Epoch 008 | Loss: 0.9112 | Val AUROC: 0.7635
# Epoch 009 | Loss: 0.8690 | Val AUROC: 0.7612
# Epoch 010 | Loss: 0.8946 | Val AUROC: 0.7635
# Epoch 011 | Loss: 0.8584 | Val AUROC: 0.7693
# Epoch 012 | Loss: 0.8576 | Val AUROC: 0.7699
# Epoch 013 | Loss: 0.8290 | Val AUROC: 0.7710
# Epoch 014 | Loss: 0.8224 | Val AUROC: 0.7786
# Epoch 015 | Loss: 0.8072 | Val AUROC: 0.7751
# Epoch 016 | Loss: 0.8146 | Val AUROC: 0.7797
# Epoch 017 | Loss: 0.8240 | Val AUROC: 0.7786
# Epoch 018 | Loss: 0.8309 | Val AUROC: 0.7838
# Epoch 019 | Loss: 0.8084 | Val AUROC: 0.7843
# Epoch 020 | Loss: 0.7773 | Val AUROC: 0.7843
# Epoch 021 | Loss: 0.7798 | Val AUROC: 0.7843
# Epoch 022 | Loss: 0.7813 | Val AUROC: 0.7861
# Epoch 023 | Loss: 0.7980 | Val AUROC: 0.7884
# Epoch 024 | Loss: 0.7704 | Val AUROC: 0.7925
# Epoch 025 | Loss: 0.8072 | Val AUROC: 0.7954
# Epoch 026 | Loss: 0.7686 | Val AUROC: 0.7942
# Epoch 027 | Loss: 0.7537 | Val AUROC: 0.7919
# Epoch 028 | Loss: 0.7609 | Val AUROC: 0.7907
# Epoch 029 | Loss: 0.7604 | Val AUROC: 0.7954
# Epoch 030 | Loss: 0.7388 | Val AUROC: 0.7954
# Epoch 031 | Loss: 0.7496 | Val AUROC: 0.7959
# Epoch 032 | Loss: 0.7370 | Val AUROC: 0.7936
# Epoch 033 | Loss: 0.7317 | Val AUROC: 0.7936
# Epoch 034 | Loss: 0.7474 | Val AUROC: 0.7907
# Epoch 035 | Loss: 0.7336 | Val AUROC: 0.7954
# Epoch 036 | Loss: 0.7232 | Val AUROC: 0.7919
# Epoch 037 | Loss: 0.7184 | Val AUROC: 0.7936
# Epoch 038 | Loss: 0.7203 | Val AUROC: 0.7942
# Epoch 039 | Loss: 0.7006 | Val AUROC: 0.7948
# Epoch 040 | Loss: 0.6991 | Val AUROC: 0.7901
# Epoch 041 | Loss: 0.6940 | Val AUROC: 0.7948
# Epoch 042 | Loss: 0.6931 | Val AUROC: 0.7907
# Epoch 043 | Loss: 0.6911 | Val AUROC: 0.7948
# Early stopping at epoch 43 (best Val AUROC=0.7959)
#
# ===== Fold 3/5 =====
# pos_weight = 2.97  (neg=508, pos=171)
# Epoch 001 | Loss: 1.0378 | Val AUROC: 0.6784
# Epoch 002 | Loss: 1.0227 | Val AUROC: 0.7441
# Epoch 003 | Loss: 0.9960 | Val AUROC: 0.7825
# Epoch 004 | Loss: 0.9719 | Val AUROC: 0.7803
# Epoch 005 | Loss: 0.9512 | Val AUROC: 0.7836
# Epoch 006 | Loss: 0.9254 | Val AUROC: 0.7951
# Epoch 007 | Loss: 0.9182 | Val AUROC: 0.8005
# Epoch 008 | Loss: 0.9016 | Val AUROC: 0.8121
# Epoch 009 | Loss: 0.8659 | Val AUROC: 0.8192
# Epoch 010 | Loss: 0.8754 | Val AUROC: 0.8241
# Epoch 011 | Loss: 0.8555 | Val AUROC: 0.8247
# Epoch 012 | Loss: 0.8293 | Val AUROC: 0.8247
# Epoch 013 | Loss: 0.8322 | Val AUROC: 0.8285
# Epoch 014 | Loss: 0.8417 | Val AUROC: 0.8290
# Epoch 015 | Loss: 0.8279 | Val AUROC: 0.8279
# Epoch 016 | Loss: 0.8096 | Val AUROC: 0.8279
# Epoch 017 | Loss: 0.8072 | Val AUROC: 0.8318
# Epoch 018 | Loss: 0.8031 | Val AUROC: 0.8356
# Epoch 019 | Loss: 0.7862 | Val AUROC: 0.8356
# Epoch 020 | Loss: 0.7840 | Val AUROC: 0.8422
# Epoch 021 | Loss: 0.7912 | Val AUROC: 0.8405
# Epoch 022 | Loss: 0.7990 | Val AUROC: 0.8405
# Epoch 023 | Loss: 0.7869 | Val AUROC: 0.8477
# Epoch 024 | Loss: 0.7763 | Val AUROC: 0.8433
# Epoch 025 | Loss: 0.7844 | Val AUROC: 0.8438
# Epoch 026 | Loss: 0.7633 | Val AUROC: 0.8444
# Epoch 027 | Loss: 0.7666 | Val AUROC: 0.8477
# Epoch 028 | Loss: 0.7749 | Val AUROC: 0.8477
# Epoch 029 | Loss: 0.7590 | Val AUROC: 0.8499
# Epoch 030 | Loss: 0.7467 | Val AUROC: 0.8482
# Epoch 031 | Loss: 0.7772 | Val AUROC: 0.8499
# Epoch 032 | Loss: 0.7479 | Val AUROC: 0.8488
# Epoch 033 | Loss: 0.7424 | Val AUROC: 0.8493
# Epoch 034 | Loss: 0.7679 | Val AUROC: 0.8532
# Epoch 035 | Loss: 0.7577 | Val AUROC: 0.8504
# Epoch 036 | Loss: 0.7374 | Val AUROC: 0.8510
# Epoch 037 | Loss: 0.7384 | Val AUROC: 0.8521
# Epoch 038 | Loss: 0.7349 | Val AUROC: 0.8515
# Epoch 039 | Loss: 0.7216 | Val AUROC: 0.8526
# Epoch 040 | Loss: 0.7455 | Val AUROC: 0.8504
# Epoch 041 | Loss: 0.7406 | Val AUROC: 0.8559
# Epoch 042 | Loss: 0.7287 | Val AUROC: 0.8493
# Epoch 043 | Loss: 0.7174 | Val AUROC: 0.8521
# Epoch 044 | Loss: 0.7225 | Val AUROC: 0.8488
# Epoch 045 | Loss: 0.7218 | Val AUROC: 0.8499
# Epoch 046 | Loss: 0.7110 | Val AUROC: 0.8499
# Epoch 047 | Loss: 0.7279 | Val AUROC: 0.8521
# Epoch 048 | Loss: 0.7264 | Val AUROC: 0.8493
# Epoch 049 | Loss: 0.7131 | Val AUROC: 0.8493
# Epoch 050 | Loss: 0.6858 | Val AUROC: 0.8521
# Epoch 051 | Loss: 0.7186 | Val AUROC: 0.8521
# Epoch 052 | Loss: 0.6974 | Val AUROC: 0.8537
# Epoch 053 | Loss: 0.6965 | Val AUROC: 0.8526
# Early stopping at epoch 53 (best Val AUROC=0.8559)
#
# ===== Fold 4/5 =====
# pos_weight = 2.90  (neg=505, pos=174)
# Epoch 001 | Loss: 1.0308 | Val AUROC: 0.7792
# Epoch 002 | Loss: 0.9960 | Val AUROC: 0.8121
# Epoch 003 | Loss: 0.9885 | Val AUROC: 0.8203
# Epoch 004 | Loss: 0.9725 | Val AUROC: 0.8389
# Epoch 005 | Loss: 0.9507 | Val AUROC: 0.8405
# Epoch 006 | Loss: 0.9211 | Val AUROC: 0.8471
# Epoch 007 | Loss: 0.9125 | Val AUROC: 0.8597
# Epoch 008 | Loss: 0.8878 | Val AUROC: 0.8630
# Epoch 009 | Loss: 0.8760 | Val AUROC: 0.8658
# Epoch 010 | Loss: 0.8668 | Val AUROC: 0.8658
# Epoch 011 | Loss: 0.8283 | Val AUROC: 0.8652
# Epoch 012 | Loss: 0.8363 | Val AUROC: 0.8619
# Epoch 013 | Loss: 0.8105 | Val AUROC: 0.8674
# Epoch 014 | Loss: 0.8143 | Val AUROC: 0.8685
# Epoch 015 | Loss: 0.8148 | Val AUROC: 0.8663
# Epoch 016 | Loss: 0.8098 | Val AUROC: 0.8701
# Epoch 017 | Loss: 0.8014 | Val AUROC: 0.8674
# Epoch 018 | Loss: 0.7888 | Val AUROC: 0.8740
# Epoch 019 | Loss: 0.7913 | Val AUROC: 0.8723
# Epoch 020 | Loss: 0.7792 | Val AUROC: 0.8729
# Epoch 021 | Loss: 0.7808 | Val AUROC: 0.8740
# Epoch 022 | Loss: 0.7599 | Val AUROC: 0.8723
# Epoch 023 | Loss: 0.7772 | Val AUROC: 0.8729
# Epoch 024 | Loss: 0.7551 | Val AUROC: 0.8723
# Epoch 025 | Loss: 0.7677 | Val AUROC: 0.8745
# Epoch 026 | Loss: 0.7494 | Val AUROC: 0.8751
# Epoch 027 | Loss: 0.7439 | Val AUROC: 0.8762
# Epoch 028 | Loss: 0.7474 | Val AUROC: 0.8767
# Epoch 029 | Loss: 0.7571 | Val AUROC: 0.8795
# Epoch 030 | Loss: 0.7432 | Val AUROC: 0.8816
# Epoch 031 | Loss: 0.7348 | Val AUROC: 0.8784
# Epoch 032 | Loss: 0.7383 | Val AUROC: 0.8789
# Epoch 033 | Loss: 0.7441 | Val AUROC: 0.8795
# Epoch 034 | Loss: 0.7348 | Val AUROC: 0.8789
# Epoch 035 | Loss: 0.7404 | Val AUROC: 0.8745
# Epoch 036 | Loss: 0.7311 | Val AUROC: 0.8745
# Epoch 037 | Loss: 0.7245 | Val AUROC: 0.8762
# Epoch 038 | Loss: 0.7262 | Val AUROC: 0.8789
# Epoch 039 | Loss: 0.7071 | Val AUROC: 0.8773
# Epoch 040 | Loss: 0.7085 | Val AUROC: 0.8811
# Epoch 041 | Loss: 0.7254 | Val AUROC: 0.8784
# Epoch 042 | Loss: 0.7155 | Val AUROC: 0.8740
# Early stopping at epoch 42 (best Val AUROC=0.8816)
#
# ===== Fold 5/5 =====
# pos_weight = 3.17  (neg=516, pos=163)
# Epoch 001 | Loss: 1.0446 | Val AUROC: 0.7365
# Epoch 002 | Loss: 1.0195 | Val AUROC: 0.7736
# Epoch 003 | Loss: 1.0031 | Val AUROC: 0.7922
# Epoch 004 | Loss: 0.9740 | Val AUROC: 0.8091
# Epoch 005 | Loss: 0.9583 | Val AUROC: 0.8131
# Epoch 006 | Loss: 0.9176 | Val AUROC: 0.8148
# Epoch 007 | Loss: 0.9265 | Val AUROC: 0.8187
# Epoch 008 | Loss: 0.9129 | Val AUROC: 0.8221
# Epoch 009 | Loss: 0.8834 | Val AUROC: 0.8193
# Epoch 010 | Loss: 0.8749 | Val AUROC: 0.8164
# Epoch 011 | Loss: 0.8595 | Val AUROC: 0.8209
# Epoch 012 | Loss: 0.8444 | Val AUROC: 0.8232
# Epoch 013 | Loss: 0.8365 | Val AUROC: 0.8238
# Epoch 014 | Loss: 0.8222 | Val AUROC: 0.8288
# Epoch 015 | Loss: 0.8077 | Val AUROC: 0.8255
# Epoch 016 | Loss: 0.8224 | Val AUROC: 0.8260
# Epoch 017 | Loss: 0.8051 | Val AUROC: 0.8238
# Epoch 018 | Loss: 0.8118 | Val AUROC: 0.8277
# Epoch 019 | Loss: 0.8059 | Val AUROC: 0.8193
# Epoch 020 | Loss: 0.8129 | Val AUROC: 0.8266
# Epoch 021 | Loss: 0.7884 | Val AUROC: 0.8209
# Epoch 022 | Loss: 0.7850 | Val AUROC: 0.8198
# Epoch 023 | Loss: 0.7904 | Val AUROC: 0.8204
# Epoch 024 | Loss: 0.7865 | Val AUROC: 0.8204
# Epoch 025 | Loss: 0.7606 | Val AUROC: 0.8238
# Epoch 026 | Loss: 0.7843 | Val AUROC: 0.8215
# Early stopping at epoch 26 (best Val AUROC=0.8288)
#
# ===== 种子 648 的 Bootstrap 结果 =====
# AUROC: 0.7933 (95% CI 0.7599–0.8254)
# AUPRC: 0.6072 (95% CI 0.5442–0.6664)
#
# ================== 尝试随机种子 2925 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 3.14  (neg=515, pos=164)
# Epoch 001 | Loss: 1.0459 | Val AUROC: 0.6775
# Epoch 002 | Loss: 1.0198 | Val AUROC: 0.7175
# Epoch 003 | Loss: 0.9971 | Val AUROC: 0.7466
# Epoch 004 | Loss: 0.9705 | Val AUROC: 0.7568
# Epoch 005 | Loss: 0.9512 | Val AUROC: 0.7568
# Epoch 006 | Loss: 0.9214 | Val AUROC: 0.7449
# Epoch 007 | Loss: 0.8887 | Val AUROC: 0.7551
# Epoch 008 | Loss: 0.8845 | Val AUROC: 0.7454
# Epoch 009 | Loss: 0.8730 | Val AUROC: 0.7454
# Epoch 010 | Loss: 0.8439 | Val AUROC: 0.7591
# Epoch 011 | Loss: 0.8327 | Val AUROC: 0.7551
# Epoch 012 | Loss: 0.8408 | Val AUROC: 0.7574
# Epoch 013 | Loss: 0.8393 | Val AUROC: 0.7557
# Epoch 014 | Loss: 0.7972 | Val AUROC: 0.7574
# Epoch 015 | Loss: 0.8072 | Val AUROC: 0.7614
# Epoch 016 | Loss: 0.7981 | Val AUROC: 0.7586
# Epoch 017 | Loss: 0.7742 | Val AUROC: 0.7603
# Epoch 018 | Loss: 0.7793 | Val AUROC: 0.7603
# Epoch 019 | Loss: 0.7625 | Val AUROC: 0.7603
# Epoch 020 | Loss: 0.8068 | Val AUROC: 0.7603
# Epoch 021 | Loss: 0.7703 | Val AUROC: 0.7614
# Epoch 022 | Loss: 0.7743 | Val AUROC: 0.7597
# Epoch 023 | Loss: 0.7771 | Val AUROC: 0.7586
# Epoch 024 | Loss: 0.7558 | Val AUROC: 0.7563
# Epoch 025 | Loss: 0.7787 | Val AUROC: 0.7603
# Epoch 026 | Loss: 0.7412 | Val AUROC: 0.7551
# Epoch 027 | Loss: 0.7465 | Val AUROC: 0.7563
# Early stopping at epoch 27 (best Val AUROC=0.7614)
#
# ===== Fold 2/5 =====
# pos_weight = 2.79  (neg=500, pos=179)
# Epoch 001 | Loss: 1.0185 | Val AUROC: 0.7703
# Epoch 002 | Loss: 0.9941 | Val AUROC: 0.8029
# Epoch 003 | Loss: 0.9756 | Val AUROC: 0.8152
# Epoch 004 | Loss: 0.9562 | Val AUROC: 0.8152
# Epoch 005 | Loss: 0.9404 | Val AUROC: 0.8104
# Epoch 006 | Loss: 0.9148 | Val AUROC: 0.8130
# Epoch 007 | Loss: 0.8907 | Val AUROC: 0.8162
# Epoch 008 | Loss: 0.8742 | Val AUROC: 0.8162
# Epoch 009 | Loss: 0.8645 | Val AUROC: 0.8125
# Epoch 010 | Loss: 0.8472 | Val AUROC: 0.8098
# Epoch 011 | Loss: 0.8299 | Val AUROC: 0.8056
# Epoch 012 | Loss: 0.8271 | Val AUROC: 0.8050
# Epoch 013 | Loss: 0.8035 | Val AUROC: 0.8034
# Epoch 014 | Loss: 0.8188 | Val AUROC: 0.7997
# Epoch 015 | Loss: 0.7984 | Val AUROC: 0.7997
# Epoch 016 | Loss: 0.7852 | Val AUROC: 0.7954
# Epoch 017 | Loss: 0.7864 | Val AUROC: 0.7949
# Epoch 018 | Loss: 0.7871 | Val AUROC: 0.7965
# Epoch 019 | Loss: 0.7726 | Val AUROC: 0.7970
# Early stopping at epoch 19 (best Val AUROC=0.8162)
#
# ===== Fold 3/5 =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0471 | Val AUROC: 0.6216
# Epoch 002 | Loss: 1.0221 | Val AUROC: 0.6824
# Epoch 003 | Loss: 0.9898 | Val AUROC: 0.6971
# Epoch 004 | Loss: 0.9783 | Val AUROC: 0.6869
# Epoch 005 | Loss: 0.9444 | Val AUROC: 0.6954
# Epoch 006 | Loss: 0.9191 | Val AUROC: 0.7072
# Epoch 007 | Loss: 0.8974 | Val AUROC: 0.7106
# Epoch 008 | Loss: 0.8754 | Val AUROC: 0.7100
# Epoch 009 | Loss: 0.8673 | Val AUROC: 0.7145
# Epoch 010 | Loss: 0.8355 | Val AUROC: 0.7168
# Epoch 011 | Loss: 0.8208 | Val AUROC: 0.7128
# Epoch 012 | Loss: 0.8252 | Val AUROC: 0.7162
# Epoch 013 | Loss: 0.8199 | Val AUROC: 0.7168
# Epoch 014 | Loss: 0.8197 | Val AUROC: 0.7224
# Epoch 015 | Loss: 0.7968 | Val AUROC: 0.7247
# Epoch 016 | Loss: 0.7968 | Val AUROC: 0.7224
# Epoch 017 | Loss: 0.7774 | Val AUROC: 0.7207
# Epoch 018 | Loss: 0.7851 | Val AUROC: 0.7157
# Epoch 019 | Loss: 0.7680 | Val AUROC: 0.7140
# Epoch 020 | Loss: 0.7660 | Val AUROC: 0.7185
# Epoch 021 | Loss: 0.7536 | Val AUROC: 0.7213
# Epoch 022 | Loss: 0.7597 | Val AUROC: 0.7218
# Epoch 023 | Loss: 0.7486 | Val AUROC: 0.7230
# Epoch 024 | Loss: 0.7395 | Val AUROC: 0.7247
# Epoch 025 | Loss: 0.7447 | Val AUROC: 0.7224
# Epoch 026 | Loss: 0.7366 | Val AUROC: 0.7252
# Epoch 027 | Loss: 0.7287 | Val AUROC: 0.7252
# Epoch 028 | Loss: 0.7357 | Val AUROC: 0.7252
# Epoch 029 | Loss: 0.7401 | Val AUROC: 0.7258
# Epoch 030 | Loss: 0.7258 | Val AUROC: 0.7218
# Epoch 031 | Loss: 0.7088 | Val AUROC: 0.7213
# Epoch 032 | Loss: 0.6970 | Val AUROC: 0.7202
# Epoch 033 | Loss: 0.7140 | Val AUROC: 0.7207
# Epoch 034 | Loss: 0.6935 | Val AUROC: 0.7202
# Epoch 035 | Loss: 0.6947 | Val AUROC: 0.7218
# Epoch 036 | Loss: 0.7028 | Val AUROC: 0.7190
# Epoch 037 | Loss: 0.7055 | Val AUROC: 0.7190
# Epoch 038 | Loss: 0.7027 | Val AUROC: 0.7190
# Epoch 039 | Loss: 0.6920 | Val AUROC: 0.7213
# Epoch 040 | Loss: 0.6929 | Val AUROC: 0.7218
# Epoch 041 | Loss: 0.6989 | Val AUROC: 0.7162
# Early stopping at epoch 41 (best Val AUROC=0.7258)
#
# ===== Fold 4/5 =====
# pos_weight = 3.19  (neg=517, pos=162)
# Epoch 001 | Loss: 1.0483 | Val AUROC: 0.6435
# Epoch 002 | Loss: 1.0264 | Val AUROC: 0.6441
# Epoch 003 | Loss: 0.9974 | Val AUROC: 0.6464
# Epoch 004 | Loss: 0.9642 | Val AUROC: 0.6499
# Epoch 005 | Loss: 0.9689 | Val AUROC: 0.6655
# Epoch 006 | Loss: 0.9429 | Val AUROC: 0.6806
# Epoch 007 | Loss: 0.9033 | Val AUROC: 0.6817
# Epoch 008 | Loss: 0.8905 | Val AUROC: 0.6736
# Epoch 009 | Loss: 0.8704 | Val AUROC: 0.6899
# Epoch 010 | Loss: 0.8651 | Val AUROC: 0.6951
# Epoch 011 | Loss: 0.8156 | Val AUROC: 0.6980
# Epoch 012 | Loss: 0.8271 | Val AUROC: 0.7055
# Epoch 013 | Loss: 0.7989 | Val AUROC: 0.7043
# Epoch 014 | Loss: 0.7881 | Val AUROC: 0.7055
# Epoch 015 | Loss: 0.7882 | Val AUROC: 0.7107
# Epoch 016 | Loss: 0.7974 | Val AUROC: 0.7125
# Epoch 017 | Loss: 0.7591 | Val AUROC: 0.7148
# Epoch 018 | Loss: 0.7630 | Val AUROC: 0.7223
# Epoch 019 | Loss: 0.7630 | Val AUROC: 0.7212
# Epoch 020 | Loss: 0.7829 | Val AUROC: 0.7281
# Epoch 021 | Loss: 0.7502 | Val AUROC: 0.7304
# Epoch 022 | Loss: 0.7334 | Val AUROC: 0.7310
# Epoch 023 | Loss: 0.7334 | Val AUROC: 0.7310
# Epoch 024 | Loss: 0.7249 | Val AUROC: 0.7264
# Epoch 025 | Loss: 0.7485 | Val AUROC: 0.7281
# Epoch 026 | Loss: 0.7382 | Val AUROC: 0.7328
# Epoch 027 | Loss: 0.7138 | Val AUROC: 0.7299
# Epoch 028 | Loss: 0.7176 | Val AUROC: 0.7322
# Epoch 029 | Loss: 0.7172 | Val AUROC: 0.7345
# Epoch 030 | Loss: 0.7150 | Val AUROC: 0.7293
# Epoch 031 | Loss: 0.7227 | Val AUROC: 0.7275
# Epoch 032 | Loss: 0.7396 | Val AUROC: 0.7304
# Epoch 033 | Loss: 0.6991 | Val AUROC: 0.7275
# Epoch 034 | Loss: 0.7230 | Val AUROC: 0.7241
# Epoch 035 | Loss: 0.6889 | Val AUROC: 0.7246
# Epoch 036 | Loss: 0.6907 | Val AUROC: 0.7264
# Epoch 037 | Loss: 0.6881 | Val AUROC: 0.7270
# Epoch 038 | Loss: 0.6819 | Val AUROC: 0.7252
# Epoch 039 | Loss: 0.6937 | Val AUROC: 0.7241
# Epoch 040 | Loss: 0.6754 | Val AUROC: 0.7235
# Epoch 041 | Loss: 0.6642 | Val AUROC: 0.7252
# Early stopping at epoch 41 (best Val AUROC=0.7345)
#
# ===== Fold 5/5 =====
# pos_weight = 3.02  (neg=510, pos=169)
# Epoch 001 | Loss: 1.0457 | Val AUROC: 0.7016
# Epoch 002 | Loss: 1.0245 | Val AUROC: 0.7720
# Epoch 003 | Loss: 0.9990 | Val AUROC: 0.7883
# Epoch 004 | Loss: 0.9925 | Val AUROC: 0.7787
# Epoch 005 | Loss: 0.9595 | Val AUROC: 0.7889
# Epoch 006 | Loss: 0.9371 | Val AUROC: 0.7849
# Epoch 007 | Loss: 0.9195 | Val AUROC: 0.7838
# Epoch 008 | Loss: 0.9048 | Val AUROC: 0.7866
# Epoch 009 | Loss: 0.8851 | Val AUROC: 0.7883
# Epoch 010 | Loss: 0.8585 | Val AUROC: 0.7928
# Epoch 011 | Loss: 0.8392 | Val AUROC: 0.7905
# Epoch 012 | Loss: 0.8199 | Val AUROC: 0.7922
# Epoch 013 | Loss: 0.7968 | Val AUROC: 0.7934
# Epoch 014 | Loss: 0.7816 | Val AUROC: 0.7939
# Epoch 015 | Loss: 0.7981 | Val AUROC: 0.7928
# Epoch 016 | Loss: 0.7832 | Val AUROC: 0.7900
# Epoch 017 | Loss: 0.7577 | Val AUROC: 0.7905
# Epoch 018 | Loss: 0.7621 | Val AUROC: 0.7922
# Epoch 019 | Loss: 0.7710 | Val AUROC: 0.7928
# Epoch 020 | Loss: 0.7650 | Val AUROC: 0.7917
# Epoch 021 | Loss: 0.7431 | Val AUROC: 0.7866
# Epoch 022 | Loss: 0.7280 | Val AUROC: 0.7877
# Epoch 023 | Loss: 0.7675 | Val AUROC: 0.7866
# Epoch 024 | Loss: 0.7323 | Val AUROC: 0.7860
# Epoch 025 | Loss: 0.7267 | Val AUROC: 0.7838
# Epoch 026 | Loss: 0.7072 | Val AUROC: 0.7855
# Early stopping at epoch 26 (best Val AUROC=0.7939)
#
# ===== 种子 2925 的 Bootstrap 结果 =====
# AUROC: 0.7743 (95% CI 0.7363–0.8103)
# AUPRC: 0.5913 (95% CI 0.5248–0.6566)
#
# ================== 尝试随机种子 4232 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 2.97  (neg=508, pos=171)
# Epoch 001 | Loss: 1.0329 | Val AUROC: 0.6844
# Epoch 002 | Loss: 1.0148 | Val AUROC: 0.7295
# Epoch 003 | Loss: 0.9996 | Val AUROC: 0.7397
# Epoch 004 | Loss: 0.9715 | Val AUROC: 0.7460
# Epoch 005 | Loss: 0.9641 | Val AUROC: 0.7500
# Epoch 006 | Loss: 0.9193 | Val AUROC: 0.7489
# Epoch 007 | Loss: 0.9182 | Val AUROC: 0.7540
# Epoch 008 | Loss: 0.8756 | Val AUROC: 0.7591
# Epoch 009 | Loss: 0.8724 | Val AUROC: 0.7534
# Epoch 010 | Loss: 0.8583 | Val AUROC: 0.7494
# Epoch 011 | Loss: 0.8483 | Val AUROC: 0.7506
# Epoch 012 | Loss: 0.8330 | Val AUROC: 0.7494
# Epoch 013 | Loss: 0.8230 | Val AUROC: 0.7437
# Epoch 014 | Loss: 0.7944 | Val AUROC: 0.7506
# Epoch 015 | Loss: 0.7935 | Val AUROC: 0.7420
# Epoch 016 | Loss: 0.7840 | Val AUROC: 0.7432
# Epoch 017 | Loss: 0.7697 | Val AUROC: 0.7403
# Epoch 018 | Loss: 0.7909 | Val AUROC: 0.7414
# Epoch 019 | Loss: 0.7663 | Val AUROC: 0.7380
# Epoch 020 | Loss: 0.7515 | Val AUROC: 0.7374
# Early stopping at epoch 20 (best Val AUROC=0.7591)
#
# ===== Fold 2/5 =====
# pos_weight = 2.92  (neg=506, pos=173)
# Epoch 001 | Loss: 1.0213 | Val AUROC: 0.7014
# Epoch 002 | Loss: 0.9987 | Val AUROC: 0.7507
# Epoch 003 | Loss: 0.9811 | Val AUROC: 0.7742
# Epoch 004 | Loss: 0.9578 | Val AUROC: 0.7901
# Epoch 005 | Loss: 0.9196 | Val AUROC: 0.7989
# Epoch 006 | Loss: 0.8995 | Val AUROC: 0.8005
# Epoch 007 | Loss: 0.8796 | Val AUROC: 0.8066
# Epoch 008 | Loss: 0.8740 | Val AUROC: 0.8121
# Epoch 009 | Loss: 0.8500 | Val AUROC: 0.8153
# Epoch 010 | Loss: 0.8395 | Val AUROC: 0.8077
# Epoch 011 | Loss: 0.8373 | Val AUROC: 0.8142
# Epoch 012 | Loss: 0.8366 | Val AUROC: 0.8121
# Epoch 013 | Loss: 0.8065 | Val AUROC: 0.8093
# Epoch 014 | Loss: 0.8223 | Val AUROC: 0.8164
# Epoch 015 | Loss: 0.7942 | Val AUROC: 0.8148
# Epoch 016 | Loss: 0.7737 | Val AUROC: 0.8175
# Epoch 017 | Loss: 0.7732 | Val AUROC: 0.8148
# Epoch 018 | Loss: 0.7762 | Val AUROC: 0.8164
# Epoch 019 | Loss: 0.7904 | Val AUROC: 0.8164
# Epoch 020 | Loss: 0.7663 | Val AUROC: 0.8115
# Epoch 021 | Loss: 0.7633 | Val AUROC: 0.8142
# Epoch 022 | Loss: 0.7714 | Val AUROC: 0.8099
# Epoch 023 | Loss: 0.7630 | Val AUROC: 0.8104
# Epoch 024 | Loss: 0.7536 | Val AUROC: 0.8110
# Epoch 025 | Loss: 0.7395 | Val AUROC: 0.8077
# Epoch 026 | Loss: 0.7528 | Val AUROC: 0.8055
# Epoch 027 | Loss: 0.7502 | Val AUROC: 0.8071
# Epoch 028 | Loss: 0.7362 | Val AUROC: 0.8077
# Early stopping at epoch 28 (best Val AUROC=0.8175)
#
# ===== Fold 3/5 =====
# pos_weight = 3.32  (neg=522, pos=157)
# Epoch 001 | Loss: 1.0734 | Val AUROC: 0.5843
# Epoch 002 | Loss: 1.0548 | Val AUROC: 0.7386
# Epoch 003 | Loss: 1.0095 | Val AUROC: 0.7652
# Epoch 004 | Loss: 1.0056 | Val AUROC: 0.7780
# Epoch 005 | Loss: 0.9802 | Val AUROC: 0.7965
# Epoch 006 | Loss: 0.9587 | Val AUROC: 0.7971
# Epoch 007 | Loss: 0.9476 | Val AUROC: 0.8012
# Epoch 008 | Loss: 0.9168 | Val AUROC: 0.8052
# Epoch 009 | Loss: 0.9001 | Val AUROC: 0.8064
# Epoch 010 | Loss: 0.8901 | Val AUROC: 0.8075
# Epoch 011 | Loss: 0.8650 | Val AUROC: 0.8122
# Epoch 012 | Loss: 0.8523 | Val AUROC: 0.8139
# Epoch 013 | Loss: 0.8604 | Val AUROC: 0.8157
# Epoch 014 | Loss: 0.8471 | Val AUROC: 0.8128
# Epoch 015 | Loss: 0.8273 | Val AUROC: 0.8180
# Epoch 016 | Loss: 0.8247 | Val AUROC: 0.8203
# Epoch 017 | Loss: 0.8030 | Val AUROC: 0.8168
# Epoch 018 | Loss: 0.8341 | Val AUROC: 0.8162
# Epoch 019 | Loss: 0.7749 | Val AUROC: 0.8145
# Epoch 020 | Loss: 0.8293 | Val AUROC: 0.8157
# Epoch 021 | Loss: 0.7983 | Val AUROC: 0.8151
# Epoch 022 | Loss: 0.7569 | Val AUROC: 0.8151
# Epoch 023 | Loss: 0.7919 | Val AUROC: 0.8151
# Epoch 024 | Loss: 0.7776 | Val AUROC: 0.8145
# Epoch 025 | Loss: 0.7879 | Val AUROC: 0.8128
# Epoch 026 | Loss: 0.7740 | Val AUROC: 0.8133
# Epoch 027 | Loss: 0.7568 | Val AUROC: 0.8128
# Epoch 028 | Loss: 0.7607 | Val AUROC: 0.8104
# Early stopping at epoch 28 (best Val AUROC=0.8203)
#
# ===== Fold 4/5 =====
# pos_weight = 2.99  (neg=509, pos=170)
# Epoch 001 | Loss: 1.0276 | Val AUROC: 0.7162
# Epoch 002 | Loss: 1.0046 | Val AUROC: 0.7370
# Epoch 003 | Loss: 0.9826 | Val AUROC: 0.7441
# Epoch 004 | Loss: 0.9672 | Val AUROC: 0.7507
# Epoch 005 | Loss: 0.9266 | Val AUROC: 0.7605
# Epoch 006 | Loss: 0.9161 | Val AUROC: 0.7710
# Epoch 007 | Loss: 0.8968 | Val AUROC: 0.7732
# Epoch 008 | Loss: 0.8674 | Val AUROC: 0.7775
# Epoch 009 | Loss: 0.8376 | Val AUROC: 0.7808
# Epoch 010 | Loss: 0.8371 | Val AUROC: 0.7847
# Epoch 011 | Loss: 0.8027 | Val AUROC: 0.7885
# Epoch 012 | Loss: 0.8111 | Val AUROC: 0.7967
# Epoch 013 | Loss: 0.7714 | Val AUROC: 0.7934
# Epoch 014 | Loss: 0.7795 | Val AUROC: 0.7989
# Epoch 015 | Loss: 0.7971 | Val AUROC: 0.7956
# Epoch 016 | Loss: 0.7710 | Val AUROC: 0.7978
# Epoch 017 | Loss: 0.7685 | Val AUROC: 0.7978
# Epoch 018 | Loss: 0.7720 | Val AUROC: 0.8011
# Epoch 019 | Loss: 0.7626 | Val AUROC: 0.8038
# Epoch 020 | Loss: 0.7444 | Val AUROC: 0.8033
# Epoch 021 | Loss: 0.7426 | Val AUROC: 0.8022
# Epoch 022 | Loss: 0.7436 | Val AUROC: 0.8027
# Epoch 023 | Loss: 0.7354 | Val AUROC: 0.8038
# Epoch 024 | Loss: 0.7438 | Val AUROC: 0.8022
# Epoch 025 | Loss: 0.7475 | Val AUROC: 0.8038
# Epoch 026 | Loss: 0.7279 | Val AUROC: 0.8022
# Epoch 027 | Loss: 0.7139 | Val AUROC: 0.8022
# Epoch 028 | Loss: 0.7254 | Val AUROC: 0.8044
# Epoch 029 | Loss: 0.6903 | Val AUROC: 0.8066
# Epoch 030 | Loss: 0.7292 | Val AUROC: 0.8033
# Epoch 031 | Loss: 0.7107 | Val AUROC: 0.8066
# Epoch 032 | Loss: 0.6944 | Val AUROC: 0.8049
# Epoch 033 | Loss: 0.7083 | Val AUROC: 0.8060
# Epoch 034 | Loss: 0.7087 | Val AUROC: 0.8055
# Epoch 035 | Loss: 0.7039 | Val AUROC: 0.8071
# Epoch 036 | Loss: 0.6931 | Val AUROC: 0.8066
# Epoch 037 | Loss: 0.6688 | Val AUROC: 0.8071
# Epoch 038 | Loss: 0.6888 | Val AUROC: 0.8049
# Epoch 039 | Loss: 0.6752 | Val AUROC: 0.8104
# Epoch 040 | Loss: 0.6945 | Val AUROC: 0.8071
# Epoch 041 | Loss: 0.6980 | Val AUROC: 0.8077
# Epoch 042 | Loss: 0.6886 | Val AUROC: 0.8088
# Epoch 043 | Loss: 0.6584 | Val AUROC: 0.8071
# Epoch 044 | Loss: 0.6676 | Val AUROC: 0.8071
# Epoch 045 | Loss: 0.6642 | Val AUROC: 0.8077
# Epoch 046 | Loss: 0.6494 | Val AUROC: 0.8082
# Epoch 047 | Loss: 0.6701 | Val AUROC: 0.8088
# Epoch 048 | Loss: 0.6693 | Val AUROC: 0.8099
# Epoch 049 | Loss: 0.6640 | Val AUROC: 0.8110
# Epoch 050 | Loss: 0.6483 | Val AUROC: 0.8077
# Epoch 051 | Loss: 0.6773 | Val AUROC: 0.8104
# Epoch 052 | Loss: 0.6582 | Val AUROC: 0.8110
# Epoch 053 | Loss: 0.6363 | Val AUROC: 0.8115
# Epoch 054 | Loss: 0.6333 | Val AUROC: 0.8126
# Epoch 055 | Loss: 0.6202 | Val AUROC: 0.8110
# Epoch 056 | Loss: 0.6533 | Val AUROC: 0.8082
# Epoch 057 | Loss: 0.6416 | Val AUROC: 0.8126
# Epoch 058 | Loss: 0.6317 | Val AUROC: 0.8126
# Epoch 059 | Loss: 0.6403 | Val AUROC: 0.8137
# Epoch 060 | Loss: 0.6392 | Val AUROC: 0.8132
# Epoch 061 | Loss: 0.6164 | Val AUROC: 0.8170
# Epoch 062 | Loss: 0.6197 | Val AUROC: 0.8132
# Epoch 063 | Loss: 0.6279 | Val AUROC: 0.8153
# Epoch 064 | Loss: 0.6214 | Val AUROC: 0.8159
# Epoch 065 | Loss: 0.6409 | Val AUROC: 0.8186
# Epoch 066 | Loss: 0.5924 | Val AUROC: 0.8159
# Epoch 067 | Loss: 0.6006 | Val AUROC: 0.8164
# Epoch 068 | Loss: 0.6094 | Val AUROC: 0.8208
# Epoch 069 | Loss: 0.6175 | Val AUROC: 0.8247
# Epoch 070 | Loss: 0.6060 | Val AUROC: 0.8186
# Epoch 071 | Loss: 0.5968 | Val AUROC: 0.8214
# Epoch 072 | Loss: 0.6005 | Val AUROC: 0.8225
# Epoch 073 | Loss: 0.6017 | Val AUROC: 0.8170
# Epoch 074 | Loss: 0.5976 | Val AUROC: 0.8137
# Epoch 075 | Loss: 0.5892 | Val AUROC: 0.8197
# Epoch 076 | Loss: 0.6014 | Val AUROC: 0.8159
# Epoch 077 | Loss: 0.5831 | Val AUROC: 0.8186
# Epoch 078 | Loss: 0.5833 | Val AUROC: 0.8164
# Epoch 079 | Loss: 0.5961 | Val AUROC: 0.8164
# Epoch 080 | Loss: 0.5879 | Val AUROC: 0.8219
# Epoch 081 | Loss: 0.5766 | Val AUROC: 0.8203
# Early stopping at epoch 81 (best Val AUROC=0.8247)
#
# ===== Fold 5/5 =====
# pos_weight = 3.04  (neg=511, pos=168)
# Epoch 001 | Loss: 1.0398 | Val AUROC: 0.6250
# Epoch 002 | Loss: 1.0177 | Val AUROC: 0.6791
# Epoch 003 | Loss: 1.0075 | Val AUROC: 0.7207
# Epoch 004 | Loss: 0.9831 | Val AUROC: 0.7365
# Epoch 005 | Loss: 0.9547 | Val AUROC: 0.7432
# Epoch 006 | Loss: 0.9384 | Val AUROC: 0.7489
# Epoch 007 | Loss: 0.9092 | Val AUROC: 0.7461
# Epoch 008 | Loss: 0.9090 | Val AUROC: 0.7506
# Epoch 009 | Loss: 0.8794 | Val AUROC: 0.7506
# Epoch 010 | Loss: 0.8627 | Val AUROC: 0.7596
# Epoch 011 | Loss: 0.8581 | Val AUROC: 0.7568
# Epoch 012 | Loss: 0.8108 | Val AUROC: 0.7579
# Epoch 013 | Loss: 0.8263 | Val AUROC: 0.7596
# Epoch 014 | Loss: 0.7990 | Val AUROC: 0.7607
# Epoch 015 | Loss: 0.8281 | Val AUROC: 0.7579
# Epoch 016 | Loss: 0.7792 | Val AUROC: 0.7556
# Epoch 017 | Loss: 0.7848 | Val AUROC: 0.7562
# Epoch 018 | Loss: 0.7946 | Val AUROC: 0.7534
# Epoch 019 | Loss: 0.7596 | Val AUROC: 0.7500
# Epoch 020 | Loss: 0.7690 | Val AUROC: 0.7534
# Epoch 021 | Loss: 0.7688 | Val AUROC: 0.7500
# Epoch 022 | Loss: 0.7770 | Val AUROC: 0.7466
# Epoch 023 | Loss: 0.7636 | Val AUROC: 0.7511
# Epoch 024 | Loss: 0.7490 | Val AUROC: 0.7477
# Epoch 025 | Loss: 0.7487 | Val AUROC: 0.7427
# Epoch 026 | Loss: 0.7503 | Val AUROC: 0.7449
# Early stopping at epoch 26 (best Val AUROC=0.7607)
#
# ===== 种子 4232 的 Bootstrap 结果 =====
# AUROC: 0.7766 (95% CI 0.7427–0.8101)
# AUPRC: 0.5485 (95% CI 0.4784–0.6175)
#
# ================== 尝试随机种子 7336 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0408 | Val AUROC: 0.5554
# Epoch 002 | Loss: 1.0244 | Val AUROC: 0.5868
# Epoch 003 | Loss: 1.0034 | Val AUROC: 0.6050
# Epoch 004 | Loss: 0.9547 | Val AUROC: 0.6130
# Epoch 005 | Loss: 0.9364 | Val AUROC: 0.6221
# Epoch 006 | Loss: 0.9135 | Val AUROC: 0.6182
# Epoch 007 | Loss: 0.8913 | Val AUROC: 0.6273
# Epoch 008 | Loss: 0.8586 | Val AUROC: 0.6301
# Epoch 009 | Loss: 0.8359 | Val AUROC: 0.6353
# Epoch 010 | Loss: 0.8306 | Val AUROC: 0.6438
# Epoch 011 | Loss: 0.8094 | Val AUROC: 0.6467
# Epoch 012 | Loss: 0.7891 | Val AUROC: 0.6421
# Epoch 013 | Loss: 0.7916 | Val AUROC: 0.6473
# Epoch 014 | Loss: 0.7872 | Val AUROC: 0.6467
# Epoch 015 | Loss: 0.7770 | Val AUROC: 0.6490
# Epoch 016 | Loss: 0.7722 | Val AUROC: 0.6473
# Epoch 017 | Loss: 0.7561 | Val AUROC: 0.6535
# Epoch 018 | Loss: 0.7464 | Val AUROC: 0.6513
# Epoch 019 | Loss: 0.7536 | Val AUROC: 0.6484
# Epoch 020 | Loss: 0.7338 | Val AUROC: 0.6513
# Epoch 021 | Loss: 0.7384 | Val AUROC: 0.6541
# Epoch 022 | Loss: 0.7278 | Val AUROC: 0.6535
# Epoch 023 | Loss: 0.7383 | Val AUROC: 0.6541
# Epoch 024 | Loss: 0.7270 | Val AUROC: 0.6570
# Epoch 025 | Loss: 0.7232 | Val AUROC: 0.6558
# Epoch 026 | Loss: 0.7218 | Val AUROC: 0.6547
# Epoch 027 | Loss: 0.6989 | Val AUROC: 0.6524
# Epoch 028 | Loss: 0.7250 | Val AUROC: 0.6530
# Epoch 029 | Loss: 0.7030 | Val AUROC: 0.6530
# Epoch 030 | Loss: 0.7051 | Val AUROC: 0.6530
# Epoch 031 | Loss: 0.6857 | Val AUROC: 0.6570
# Epoch 032 | Loss: 0.7133 | Val AUROC: 0.6592
# Epoch 033 | Loss: 0.7097 | Val AUROC: 0.6581
# Epoch 034 | Loss: 0.6938 | Val AUROC: 0.6553
# Epoch 035 | Loss: 0.6807 | Val AUROC: 0.6535
# Epoch 036 | Loss: 0.7042 | Val AUROC: 0.6587
# Epoch 037 | Loss: 0.7004 | Val AUROC: 0.6632
# Epoch 038 | Loss: 0.6740 | Val AUROC: 0.6587
# Epoch 039 | Loss: 0.6987 | Val AUROC: 0.6604
# Epoch 040 | Loss: 0.6904 | Val AUROC: 0.6587
# Epoch 041 | Loss: 0.6686 | Val AUROC: 0.6564
# Epoch 042 | Loss: 0.6848 | Val AUROC: 0.6581
# Epoch 043 | Loss: 0.6808 | Val AUROC: 0.6610
# Epoch 044 | Loss: 0.6574 | Val AUROC: 0.6615
# Epoch 045 | Loss: 0.6636 | Val AUROC: 0.6553
# Epoch 046 | Loss: 0.6730 | Val AUROC: 0.6553
# Epoch 047 | Loss: 0.6812 | Val AUROC: 0.6581
# Epoch 048 | Loss: 0.6733 | Val AUROC: 0.6558
# Epoch 049 | Loss: 0.6678 | Val AUROC: 0.6547
# Early stopping at epoch 49 (best Val AUROC=0.6632)
#
# ===== Fold 2/5 =====
# pos_weight = 3.19  (neg=517, pos=162)
# Epoch 001 | Loss: 1.0634 | Val AUROC: 0.6759
# Epoch 002 | Loss: 1.0354 | Val AUROC: 0.6557
# Epoch 003 | Loss: 1.0091 | Val AUROC: 0.6313
# Epoch 004 | Loss: 0.9786 | Val AUROC: 0.6307
# Epoch 005 | Loss: 0.9445 | Val AUROC: 0.6220
# Epoch 006 | Loss: 0.9267 | Val AUROC: 0.6186
# Epoch 007 | Loss: 0.9292 | Val AUROC: 0.6145
# Epoch 008 | Loss: 0.9120 | Val AUROC: 0.6099
# Epoch 009 | Loss: 0.8663 | Val AUROC: 0.6029
# Epoch 010 | Loss: 0.8586 | Val AUROC: 0.5954
# Epoch 011 | Loss: 0.8501 | Val AUROC: 0.5890
# Epoch 012 | Loss: 0.8259 | Val AUROC: 0.5919
# Epoch 013 | Loss: 0.8285 | Val AUROC: 0.5913
# Early stopping at epoch 13 (best Val AUROC=0.6759)
#
# ===== Fold 3/5 =====
# pos_weight = 2.99  (neg=509, pos=170)
# Epoch 001 | Loss: 1.0348 | Val AUROC: 0.7337
# Epoch 002 | Loss: 1.0224 | Val AUROC: 0.7432
# Epoch 003 | Loss: 0.9975 | Val AUROC: 0.7455
# Epoch 004 | Loss: 0.9811 | Val AUROC: 0.7494
# Epoch 005 | Loss: 0.9679 | Val AUROC: 0.7545
# Epoch 006 | Loss: 0.9263 | Val AUROC: 0.7652
# Epoch 007 | Loss: 0.9101 | Val AUROC: 0.7635
# Epoch 008 | Loss: 0.9003 | Val AUROC: 0.7720
# Epoch 009 | Loss: 0.8645 | Val AUROC: 0.7703
# Epoch 010 | Loss: 0.8664 | Val AUROC: 0.7770
# Epoch 011 | Loss: 0.8468 | Val AUROC: 0.7849
# Epoch 012 | Loss: 0.8427 | Val AUROC: 0.7900
# Epoch 013 | Loss: 0.8136 | Val AUROC: 0.7984
# Epoch 014 | Loss: 0.8281 | Val AUROC: 0.8012
# Epoch 015 | Loss: 0.8135 | Val AUROC: 0.8046
# Epoch 016 | Loss: 0.8100 | Val AUROC: 0.8097
# Epoch 017 | Loss: 0.7943 | Val AUROC: 0.8080
# Epoch 018 | Loss: 0.7856 | Val AUROC: 0.8102
# Epoch 019 | Loss: 0.7772 | Val AUROC: 0.8131
# Epoch 020 | Loss: 0.7813 | Val AUROC: 0.8176
# Epoch 021 | Loss: 0.7809 | Val AUROC: 0.8176
# Epoch 022 | Loss: 0.7838 | Val AUROC: 0.8193
# Epoch 023 | Loss: 0.7902 | Val AUROC: 0.8232
# Epoch 024 | Loss: 0.7759 | Val AUROC: 0.8198
# Epoch 025 | Loss: 0.7670 | Val AUROC: 0.8193
# Epoch 026 | Loss: 0.7618 | Val AUROC: 0.8243
# Epoch 027 | Loss: 0.7602 | Val AUROC: 0.8209
# Epoch 028 | Loss: 0.7785 | Val AUROC: 0.8193
# Epoch 029 | Loss: 0.7726 | Val AUROC: 0.8232
# Epoch 030 | Loss: 0.7558 | Val AUROC: 0.8221
# Epoch 031 | Loss: 0.7597 | Val AUROC: 0.8260
# Epoch 032 | Loss: 0.7563 | Val AUROC: 0.8260
# Epoch 033 | Loss: 0.7436 | Val AUROC: 0.8271
# Epoch 034 | Loss: 0.7478 | Val AUROC: 0.8238
# Epoch 035 | Loss: 0.7312 | Val AUROC: 0.8238
# Epoch 036 | Loss: 0.7378 | Val AUROC: 0.8260
# Epoch 037 | Loss: 0.7322 | Val AUROC: 0.8249
# Epoch 038 | Loss: 0.7378 | Val AUROC: 0.8271
# Epoch 039 | Loss: 0.7148 | Val AUROC: 0.8260
# Epoch 040 | Loss: 0.7159 | Val AUROC: 0.8294
# Epoch 041 | Loss: 0.7156 | Val AUROC: 0.8266
# Epoch 042 | Loss: 0.7207 | Val AUROC: 0.8283
# Epoch 043 | Loss: 0.7195 | Val AUROC: 0.8255
# Epoch 044 | Loss: 0.7199 | Val AUROC: 0.8243
# Epoch 045 | Loss: 0.7103 | Val AUROC: 0.8283
# Epoch 046 | Loss: 0.7076 | Val AUROC: 0.8271
# Epoch 047 | Loss: 0.7212 | Val AUROC: 0.8249
# Epoch 048 | Loss: 0.7144 | Val AUROC: 0.8305
# Epoch 049 | Loss: 0.7136 | Val AUROC: 0.8283
# Epoch 050 | Loss: 0.6990 | Val AUROC: 0.8288
# Epoch 051 | Loss: 0.6923 | Val AUROC: 0.8283
# Epoch 052 | Loss: 0.6977 | Val AUROC: 0.8283
# Epoch 053 | Loss: 0.7118 | Val AUROC: 0.8305
# Epoch 054 | Loss: 0.6978 | Val AUROC: 0.8294
# Epoch 055 | Loss: 0.6746 | Val AUROC: 0.8266
# Epoch 056 | Loss: 0.6731 | Val AUROC: 0.8271
# Epoch 057 | Loss: 0.6850 | Val AUROC: 0.8271
# Epoch 058 | Loss: 0.6927 | Val AUROC: 0.8277
# Epoch 059 | Loss: 0.6785 | Val AUROC: 0.8255
# Epoch 060 | Loss: 0.6755 | Val AUROC: 0.8266
# Epoch 061 | Loss: 0.6805 | Val AUROC: 0.8271
# Epoch 062 | Loss: 0.6835 | Val AUROC: 0.8277
# Epoch 063 | Loss: 0.6628 | Val AUROC: 0.8238
# Epoch 064 | Loss: 0.6685 | Val AUROC: 0.8277
# Epoch 065 | Loss: 0.6607 | Val AUROC: 0.8300
# Early stopping at epoch 65 (best Val AUROC=0.8305)
#
# ===== Fold 4/5 =====
# pos_weight = 2.99  (neg=509, pos=170)
# Epoch 001 | Loss: 1.0336 | Val AUROC: 0.7518
# Epoch 002 | Loss: 1.0130 | Val AUROC: 0.7863
# Epoch 003 | Loss: 0.9767 | Val AUROC: 0.8104
# Epoch 004 | Loss: 0.9603 | Val AUROC: 0.8153
# Epoch 005 | Loss: 0.9329 | Val AUROC: 0.8236
# Epoch 006 | Loss: 0.9193 | Val AUROC: 0.8230
# Epoch 007 | Loss: 0.8769 | Val AUROC: 0.8356
# Epoch 008 | Loss: 0.8648 | Val AUROC: 0.8318
# Epoch 009 | Loss: 0.8491 | Val AUROC: 0.8367
# Epoch 010 | Loss: 0.8284 | Val AUROC: 0.8367
# Epoch 011 | Loss: 0.7997 | Val AUROC: 0.8395
# Epoch 012 | Loss: 0.7918 | Val AUROC: 0.8466
# Epoch 013 | Loss: 0.7777 | Val AUROC: 0.8477
# Epoch 014 | Loss: 0.7752 | Val AUROC: 0.8482
# Epoch 015 | Loss: 0.7785 | Val AUROC: 0.8488
# Epoch 016 | Loss: 0.7747 | Val AUROC: 0.8493
# Epoch 017 | Loss: 0.7719 | Val AUROC: 0.8471
# Epoch 018 | Loss: 0.7670 | Val AUROC: 0.8460
# Epoch 019 | Loss: 0.7305 | Val AUROC: 0.8471
# Epoch 020 | Loss: 0.7299 | Val AUROC: 0.8488
# Epoch 021 | Loss: 0.7364 | Val AUROC: 0.8482
# Epoch 022 | Loss: 0.7481 | Val AUROC: 0.8471
# Epoch 023 | Loss: 0.6985 | Val AUROC: 0.8455
# Epoch 024 | Loss: 0.7375 | Val AUROC: 0.8460
# Epoch 025 | Loss: 0.7362 | Val AUROC: 0.8433
# Epoch 026 | Loss: 0.7128 | Val AUROC: 0.8449
# Epoch 027 | Loss: 0.7075 | Val AUROC: 0.8400
# Epoch 028 | Loss: 0.7172 | Val AUROC: 0.8427
# Early stopping at epoch 28 (best Val AUROC=0.8493)
#
# ===== Fold 5/5 =====
# pos_weight = 2.95  (neg=507, pos=172)
# Epoch 001 | Loss: 1.0244 | Val AUROC: 0.7041
# Epoch 002 | Loss: 1.0132 | Val AUROC: 0.7578
# Epoch 003 | Loss: 0.9868 | Val AUROC: 0.7660
# Epoch 004 | Loss: 0.9578 | Val AUROC: 0.7781
# Epoch 005 | Loss: 0.9419 | Val AUROC: 0.7819
# Epoch 006 | Loss: 0.9220 | Val AUROC: 0.7918
# Epoch 007 | Loss: 0.9020 | Val AUROC: 0.7973
# Epoch 008 | Loss: 0.8866 | Val AUROC: 0.8077
# Epoch 009 | Loss: 0.8619 | Val AUROC: 0.8044
# Epoch 010 | Loss: 0.8673 | Val AUROC: 0.8082
# Epoch 011 | Loss: 0.8199 | Val AUROC: 0.8142
# Epoch 012 | Loss: 0.8212 | Val AUROC: 0.8071
# Epoch 013 | Loss: 0.8033 | Val AUROC: 0.8093
# Epoch 014 | Loss: 0.8024 | Val AUROC: 0.8132
# Epoch 015 | Loss: 0.7904 | Val AUROC: 0.8121
# Epoch 016 | Loss: 0.7957 | Val AUROC: 0.8077
# Epoch 017 | Loss: 0.7869 | Val AUROC: 0.8071
# Epoch 018 | Loss: 0.7798 | Val AUROC: 0.8055
# Epoch 019 | Loss: 0.7812 | Val AUROC: 0.8055
# Epoch 020 | Loss: 0.7553 | Val AUROC: 0.8038
# Epoch 021 | Loss: 0.7681 | Val AUROC: 0.8049
# Epoch 022 | Loss: 0.7590 | Val AUROC: 0.8033
# Epoch 023 | Loss: 0.7548 | Val AUROC: 0.8027
# Early stopping at epoch 23 (best Val AUROC=0.8142)
#
# ===== 种子 7336 的 Bootstrap 结果 =====
# AUROC: 0.7467 (95% CI 0.7106–0.7822)
# AUPRC: 0.5265 (95% CI 0.4609–0.5896)
#
# ================== 尝试随机种子 7133 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 3.04  (neg=511, pos=168)
# Epoch 001 | Loss: 1.0517 | Val AUROC: 0.5873
# Epoch 002 | Loss: 1.0218 | Val AUROC: 0.6981
# Epoch 003 | Loss: 0.9870 | Val AUROC: 0.7352
# Epoch 004 | Loss: 0.9729 | Val AUROC: 0.7608
# Epoch 005 | Loss: 0.9414 | Val AUROC: 0.7734
# Epoch 006 | Loss: 0.9245 | Val AUROC: 0.7848
# Epoch 007 | Loss: 0.9003 | Val AUROC: 0.7945
# Epoch 008 | Loss: 0.8892 | Val AUROC: 0.8008
# Epoch 009 | Loss: 0.8652 | Val AUROC: 0.7979
# Epoch 010 | Loss: 0.8515 | Val AUROC: 0.8105
# Epoch 011 | Loss: 0.8219 | Val AUROC: 0.8076
# Epoch 012 | Loss: 0.8348 | Val AUROC: 0.8105
# Epoch 013 | Loss: 0.8176 | Val AUROC: 0.8174
# Epoch 014 | Loss: 0.8058 | Val AUROC: 0.8179
# Epoch 015 | Loss: 0.7909 | Val AUROC: 0.8213
# Epoch 016 | Loss: 0.8024 | Val AUROC: 0.8196
# Epoch 017 | Loss: 0.7890 | Val AUROC: 0.8208
# Epoch 018 | Loss: 0.8001 | Val AUROC: 0.8225
# Epoch 019 | Loss: 0.7735 | Val AUROC: 0.8231
# Epoch 020 | Loss: 0.7822 | Val AUROC: 0.8236
# Epoch 021 | Loss: 0.7583 | Val AUROC: 0.8259
# Epoch 022 | Loss: 0.7549 | Val AUROC: 0.8236
# Epoch 023 | Loss: 0.7557 | Val AUROC: 0.8282
# Epoch 024 | Loss: 0.7466 | Val AUROC: 0.8276
# Epoch 025 | Loss: 0.7600 | Val AUROC: 0.8282
# Epoch 026 | Loss: 0.7371 | Val AUROC: 0.8328
# Epoch 027 | Loss: 0.7469 | Val AUROC: 0.8345
# Epoch 028 | Loss: 0.7270 | Val AUROC: 0.8350
# Epoch 029 | Loss: 0.7444 | Val AUROC: 0.8345
# Epoch 030 | Loss: 0.7515 | Val AUROC: 0.8419
# Epoch 031 | Loss: 0.7602 | Val AUROC: 0.8385
# Epoch 032 | Loss: 0.7361 | Val AUROC: 0.8385
# Epoch 033 | Loss: 0.7157 | Val AUROC: 0.8402
# Epoch 034 | Loss: 0.7394 | Val AUROC: 0.8362
# Epoch 035 | Loss: 0.7474 | Val AUROC: 0.8390
# Epoch 036 | Loss: 0.7221 | Val AUROC: 0.8390
# Epoch 037 | Loss: 0.7218 | Val AUROC: 0.8402
# Epoch 038 | Loss: 0.7181 | Val AUROC: 0.8447
# Epoch 039 | Loss: 0.7087 | Val AUROC: 0.8447
# Epoch 040 | Loss: 0.7213 | Val AUROC: 0.8442
# Epoch 041 | Loss: 0.6864 | Val AUROC: 0.8447
# Epoch 042 | Loss: 0.7159 | Val AUROC: 0.8493
# Epoch 043 | Loss: 0.7113 | Val AUROC: 0.8476
# Epoch 044 | Loss: 0.7032 | Val AUROC: 0.8482
# Epoch 045 | Loss: 0.6929 | Val AUROC: 0.8459
# Epoch 046 | Loss: 0.6898 | Val AUROC: 0.8499
# Epoch 047 | Loss: 0.6875 | Val AUROC: 0.8493
# Epoch 048 | Loss: 0.6829 | Val AUROC: 0.8482
# Epoch 049 | Loss: 0.6830 | Val AUROC: 0.8482
# Epoch 050 | Loss: 0.6806 | Val AUROC: 0.8499
# Epoch 051 | Loss: 0.6921 | Val AUROC: 0.8533
# Epoch 052 | Loss: 0.6799 | Val AUROC: 0.8510
# Epoch 053 | Loss: 0.6676 | Val AUROC: 0.8493
# Epoch 054 | Loss: 0.6867 | Val AUROC: 0.8482
# Epoch 055 | Loss: 0.6599 | Val AUROC: 0.8510
# Epoch 056 | Loss: 0.6668 | Val AUROC: 0.8510
# Epoch 057 | Loss: 0.6508 | Val AUROC: 0.8510
# Epoch 058 | Loss: 0.6694 | Val AUROC: 0.8499
# Epoch 059 | Loss: 0.6543 | Val AUROC: 0.8510
# Epoch 060 | Loss: 0.6525 | Val AUROC: 0.8459
# Epoch 061 | Loss: 0.6510 | Val AUROC: 0.8465
# Epoch 062 | Loss: 0.6678 | Val AUROC: 0.8493
# Epoch 063 | Loss: 0.6367 | Val AUROC: 0.8465
# Early stopping at epoch 63 (best Val AUROC=0.8533)
#
# ===== Fold 2/5 =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0512 | Val AUROC: 0.6881
# Epoch 002 | Loss: 1.0233 | Val AUROC: 0.7202
# Epoch 003 | Loss: 1.0183 | Val AUROC: 0.7050
# Epoch 004 | Loss: 0.9820 | Val AUROC: 0.7140
# Epoch 005 | Loss: 0.9771 | Val AUROC: 0.7157
# Epoch 006 | Loss: 0.9292 | Val AUROC: 0.7168
# Epoch 007 | Loss: 0.9177 | Val AUROC: 0.7173
# Epoch 008 | Loss: 0.8857 | Val AUROC: 0.7185
# Epoch 009 | Loss: 0.8765 | Val AUROC: 0.7202
# Epoch 010 | Loss: 0.8720 | Val AUROC: 0.7354
# Epoch 011 | Loss: 0.8555 | Val AUROC: 0.7314
# Epoch 012 | Loss: 0.8554 | Val AUROC: 0.7342
# Epoch 013 | Loss: 0.8417 | Val AUROC: 0.7416
# Epoch 014 | Loss: 0.8381 | Val AUROC: 0.7444
# ...
#
# ===== Fold 5/5 =====
# pos_weight = 3.07  (neg=512, pos=167)
# Epoch 001 | Loss: 1.0434 | Val AUROC: 0.6627
# Epoch 002 | Loss: 1.0202 | Val AUROC: 0.6886
# Epoch 003 | Loss: 1.0003 | Val AUROC: 0.7128
# Epoch 004 | Loss: 0.9764 | Val AUROC: 0.7128
# Epoch 005 | Loss: 0.9469 | Val AUROC: 0.7230
# Epoch 006 | Loss: 0.9332 | Val AUROC: 0.7303
# Epoch 007 | Loss: 0.9092 | Val AUROC: 0.7382
# Epoch 008 | Loss: 0.8832 | Val AUROC: 0.7393
# Epoch 009 | Loss: 0.8768 | Val AUROC: 0.7438
# Epoch 010 | Loss: 0.8532 | Val AUROC: 0.7461
# Epoch 011 | Loss: 0.8602 | Val AUROC: 0.7489
# Epoch 012 | Loss: 0.8431 | Val AUROC: 0.7551
# Epoch 013 | Loss: 0.8192 | Val AUROC: 0.7562
# Epoch 014 | Loss: 0.8343 | Val AUROC: 0.7630
# Epoch 015 | Loss: 0.7843 | Val AUROC: 0.7641
# Epoch 016 | Loss: 0.7975 | Val AUROC: 0.7680
# Epoch 017 | Loss: 0.8066 | Val AUROC: 0.7675
# Epoch 018 | Loss: 0.7808 | Val AUROC: 0.7669
# Epoch 019 | Loss: 0.7856 | Val AUROC: 0.7703
# Epoch 020 | Loss: 0.7876 | Val AUROC: 0.7686
# Epoch 021 | Loss: 0.7766 | Val AUROC: 0.7686
# Epoch 022 | Loss: 0.7616 | Val AUROC: 0.7691
# Epoch 023 | Loss: 0.7746 | Val AUROC: 0.7658
# Epoch 024 | Loss: 0.7644 | Val AUROC: 0.7686
# Epoch 025 | Loss: 0.7919 | Val AUROC: 0.7736
# Epoch 026 | Loss: 0.7532 | Val AUROC: 0.7838
# Epoch 027 | Loss: 0.7647 | Val AUROC: 0.7765
# Epoch 028 | Loss: 0.7657 | Val AUROC: 0.7798
# Epoch 029 | Loss: 0.7474 | Val AUROC: 0.7821
# Epoch 030 | Loss: 0.7621 | Val AUROC: 0.7798
# Epoch 031 | Loss: 0.7572 | Val AUROC: 0.7804
# Epoch 032 | Loss: 0.7510 | Val AUROC: 0.7793
# Epoch 033 | Loss: 0.7308 | Val AUROC: 0.7776
# Epoch 034 | Loss: 0.7459 | Val AUROC: 0.7804
# Epoch 035 | Loss: 0.7147 | Val AUROC: 0.7776
# Epoch 036 | Loss: 0.7367 | Val AUROC: 0.7770
# Epoch 037 | Loss: 0.7317 | Val AUROC: 0.7782
# Epoch 038 | Loss: 0.7291 | Val AUROC: 0.7776
# Early stopping at epoch 38 (best Val AUROC=0.7838)
#
# ===== 种子 7148 的 Bootstrap 结果 =====
# AUROC: 0.7446 (95% CI 0.7068–0.7798)
# AUPRC: 0.5224 (95% CI 0.4537–0.5875)
#
# ================== 尝试随机种子 7567 ==================
#
# ===== Fold 1/5 =====
# pos_weight = 2.95  (neg=507, pos=172)
# Epoch 001 | Loss: 1.0349 | Val AUROC: 0.6411
# Epoch 002 | Loss: 1.0132 | Val AUROC: 0.7006
# Epoch 003 | Loss: 0.9959 | Val AUROC: 0.7356
# Epoch 004 | Loss: 0.9724 | Val AUROC: 0.7467
# Epoch 005 | Loss: 0.9534 | Val AUROC: 0.7511
# Epoch 006 | Loss: 0.9448 | Val AUROC: 0.7478
# Epoch 007 | Loss: 0.9309 | Val AUROC: 0.7583
# Epoch 008 | Loss: 0.9212 | Val AUROC: 0.7628
# Epoch 009 | Loss: 0.8771 | Val AUROC: 0.7672
# Epoch 010 | Loss: 0.8703 | Val AUROC: 0.7678
# Epoch 011 | Loss: 0.8651 | Val AUROC: 0.7750
# Epoch 012 | Loss: 0.8500 | Val AUROC: 0.7722
# Epoch 013 | Loss: 0.8218 | Val AUROC: 0.7739
# Epoch 014 | Loss: 0.8256 | Val AUROC: 0.7783
# Epoch 015 | Loss: 0.8210 | Val AUROC: 0.7761
# Epoch 016 | Loss: 0.7930 | Val AUROC: 0.7778
# Epoch 017 | Loss: 0.8045 | Val AUROC: 0.7800
# Epoch 018 | Loss: 0.7876 | Val AUROC: 0.7811
# Epoch 019 | Loss: 0.7938 | Val AUROC: 0.7822
# Epoch 020 | Loss: 0.7853 | Val AUROC: 0.7817
# Epoch 021 | Loss: 0.7780 | Val AUROC: 0.7806
# Epoch 022 | Loss: 0.7720 | Val AUROC: 0.7861
# Epoch 023 | Loss: 0.7605 | Val AUROC: 0.7850
# Epoch 024 | Loss: 0.7617 | Val AUROC: 0.7861
# Epoch 025 | Loss: 0.7629 | Val AUROC: 0.7861
# Epoch 026 | Loss: 0.7671 | Val AUROC: 0.7850
# Epoch 027 | Loss: 0.7546 | Val AUROC: 0.7856
# Epoch 028 | Loss: 0.7511 | Val AUROC: 0.7867
# Epoch 029 | Loss: 0.7566 | Val AUROC: 0.7911
# Epoch 030 | Loss: 0.7353 | Val AUROC: 0.7939
# Epoch 031 | Loss: 0.7154 | Val AUROC: 0.7906
# Epoch 032 | Loss: 0.7228 | Val AUROC: 0.7900
# Epoch 033 | Loss: 0.7464 | Val AUROC: 0.7911
# Epoch 034 | Loss: 0.7310 | Val AUROC: 0.7900
# Epoch 035 | Loss: 0.7133 | Val AUROC: 0.7928
# Epoch 036 | Loss: 0.7202 | Val AUROC: 0.7928
# Epoch 037 | Loss: 0.7222 | Val AUROC: 0.7900
# Epoch 038 | Loss: 0.7108 | Val AUROC: 0.7944
# Epoch 039 | Loss: 0.7146 | Val AUROC: 0.7939
# Epoch 040 | Loss: 0.7251 | Val AUROC: 0.7956
# Epoch 041 | Loss: 0.7149 | Val AUROC: 0.7961
# Epoch 042 | Loss: 0.7043 | Val AUROC: 0.7933
# Epoch 043 | Loss: 0.7070 | Val AUROC: 0.7944
# Epoch 044 | Loss: 0.6972 | Val AUROC: 0.7961
# Epoch 045 | Loss: 0.6895 | Val AUROC: 0.7961
# Epoch 046 | Loss: 0.7110 | Val AUROC: 0.7983
# Epoch 047 | Loss: 0.7033 | Val AUROC: 0.7978
# Epoch 048 | Loss: 0.6882 | Val AUROC: 0.7978
# Epoch 049 | Loss: 0.6911 | Val AUROC: 0.8006
# Epoch 050 | Loss: 0.6817 | Val AUROC: 0.7994
# Epoch 051 | Loss: 0.6776 | Val AUROC: 0.7983
# Epoch 052 | Loss: 0.6905 | Val AUROC: 0.7983
# Epoch 053 | Loss: 0.6770 | Val AUROC: 0.8022
# Epoch 054 | Loss: 0.6663 | Val AUROC: 0.8017
# Epoch 055 | Loss: 0.6809 | Val AUROC: 0.8033
# Epoch 056 | Loss: 0.6915 | Val AUROC: 0.8017
# Epoch 057 | Loss: 0.6796 | Val AUROC: 0.8039
# Epoch 058 | Loss: 0.6697 | Val AUROC: 0.8050
# Epoch 059 | Loss: 0.6599 | Val AUROC: 0.8033
# Epoch 060 | Loss: 0.6712 | Val AUROC: 0.8011
# Epoch 061 | Loss: 0.6520 | Val AUROC: 0.8017
# Epoch 062 | Loss: 0.6424 | Val AUROC: 0.8033
# Epoch 063 | Loss: 0.6576 | Val AUROC: 0.8044
# Epoch 064 | Loss: 0.6602 | Val AUROC: 0.8056
# Epoch 065 | Loss: 0.6417 | Val AUROC: 0.8033
# Epoch 066 | Loss: 0.6513 | Val AUROC: 0.8033
# Epoch 067 | Loss: 0.6557 | Val AUROC: 0.8083
# Epoch 068 | Loss: 0.6407 | Val AUROC: 0.8072
# Epoch 069 | Loss: 0.6511 | Val AUROC: 0.8072
# Epoch 070 | Loss: 0.6417 | Val AUROC: 0.8083
# Epoch 071 | Loss: 0.6168 | Val AUROC: 0.8072
# Epoch 072 | Loss: 0.6318 | Val AUROC: 0.8056
# Epoch 073 | Loss: 0.6274 | Val AUROC: 0.8083
# Epoch 074 | Loss: 0.6311 | Val AUROC: 0.8083
# Epoch 075 | Loss: 0.6216 | Val AUROC: 0.8089
# Epoch 076 | Loss: 0.6330 | Val AUROC: 0.8044
# Epoch 077 | Loss: 0.6235 | Val AUROC: 0.8050
# Epoch 078 | Loss: 0.6282 | Val AUROC: 0.8094
# Epoch 079 | Loss: 0.6201 | Val AUROC: 0.8111
# Epoch 080 | Loss: 0.6277 | Val AUROC: 0.8083
# Epoch 081 | Loss: 0.6205 | Val AUROC: 0.8078
# Epoch 082 | Loss: 0.6159 | Val AUROC: 0.8083
# Epoch 083 | Loss: 0.6189 | Val AUROC: 0.8089
# Epoch 084 | Loss: 0.6335 | Val AUROC: 0.8078
# Epoch 085 | Loss: 0.5934 | Val AUROC: 0.8056
# Epoch 086 | Loss: 0.6380 | Val AUROC: 0.8072
# Epoch 087 | Loss: 0.6110 | Val AUROC: 0.8094
# Epoch 088 | Loss: 0.6075 | Val AUROC: 0.8072
# Epoch 089 | Loss: 0.5739 | Val AUROC: 0.8078
# Epoch 090 | Loss: 0.6032 | Val AUROC: 0.8072
# Epoch 091 | Loss: 0.5994 | Val AUROC: 0.8061
# Early stopping at epoch 91 (best Val AUROC=0.8111)
#
# ===== Fold 2/5 =====
# pos_weight = 3.14  (neg=515, pos=164)
# Epoch 001 | Loss: 1.0399 | Val AUROC: 0.6447
# Epoch 002 | Loss: 1.0200 | Val AUROC: 0.6464
# Epoch 003 | Loss: 0.9917 | Val AUROC: 0.6509
# Epoch 004 | Loss: 0.9551 | Val AUROC: 0.6408
# Epoch 005 | Loss: 0.9367 | Val AUROC: 0.6537
# Epoch 006 | Loss: 0.9053 | Val AUROC: 0.6582
# Epoch 007 | Loss: 0.8819 | Val AUROC: 0.6616
# Epoch 008 | Loss: 0.8731 | Val AUROC: 0.6610
# Epoch 009 | Loss: 0.8497 | Val AUROC: 0.6684
# Epoch 010 | Loss: 0.8393 | Val AUROC: 0.6785
# Epoch 011 | Loss: 0.8125 | Val AUROC: 0.6717
# Epoch 012 | Loss: 0.8144 | Val AUROC: 0.6706
# Epoch 013 | Loss: 0.7951 | Val AUROC: 0.6712
# Epoch 014 | Loss: 0.7814 | Val AUROC: 0.6706
# Epoch 015 | Loss: 0.7922 | Val AUROC: 0.6768
# Epoch 016 | Loss: 0.7718 | Val AUROC: 0.6807
# Epoch 017 | Loss: 0.7759 | Val AUROC: 0.6869
# Epoch 018 | Loss: 0.7571 | Val AUROC: 0.6858
# Epoch 019 | Loss: 0.7619 | Val AUROC: 0.6836
# Epoch 020 | Loss: 0.7584 | Val AUROC: 0.6847
# Epoch 021 | Loss: 0.7456 | Val AUROC: 0.6858
# Epoch 022 | Loss: 0.7443 | Val AUROC: 0.6813
# Epoch 023 | Loss: 0.7410 | Val AUROC: 0.6791
# Epoch 024 | Loss: 0.7414 | Val AUROC: 0.6841
# Epoch 025 | Loss: 0.7192 | Val AUROC: 0.6852
# Epoch 026 | Loss: 0.7193 | Val AUROC: 0.6841
# Epoch 027 | Loss: 0.7151 | Val AUROC: 0.6903
# Epoch 028 | Loss: 0.7240 | Val AUROC: 0.6841
# Epoch 029 | Loss: 0.7311 | Val AUROC: 0.6881
# Epoch 030 | Loss: 0.7371 | Val AUROC: 0.6909
# Epoch 031 | Loss: 0.7117 | Val AUROC: 0.6886
# Epoch 032 | Loss: 0.7035 | Val AUROC: 0.6875
# Epoch 033 | Loss: 0.6990 | Val AUROC: 0.6875
# Epoch 034 | Loss: 0.6954 | Val AUROC: 0.6875
# Epoch 035 | Loss: 0.7061 | Val AUROC: 0.6920
# Epoch 036 | Loss: 0.6966 | Val AUROC: 0.6881
# Epoch 037 | Loss: 0.6895 | Val AUROC: 0.6931
# Epoch 038 | Loss: 0.6799 | Val AUROC: 0.6943
# Epoch 039 | Loss: 0.6942 | Val AUROC: 0.6914
# Epoch 040 | Loss: 0.6842 | Val AUROC: 0.6920
# Epoch 041 | Loss: 0.6830 | Val AUROC: 0.6931
# Epoch 042 | Loss: 0.6949 | Val AUROC: 0.6898
# Epoch 043 | Loss: 0.6647 | Val AUROC: 0.6943
# Epoch 044 | Loss: 0.6697 | Val AUROC: 0.6875
# Epoch 045 | Loss: 0.6756 | Val AUROC: 0.6948
# Epoch 046 | Loss: 0.6652 | Val AUROC: 0.6943
# Epoch 047 | Loss: 0.6684 | Val AUROC: 0.6954
# Epoch 048 | Loss: 0.6791 | Val AUROC: 0.6982
# Epoch 049 | Loss: 0.6622 | Val AUROC: 0.6943
# Epoch 050 | Loss: 0.6519 | Val AUROC: 0.6948
# Epoch 051 | Loss: 0.6831 | Val AUROC: 0.6971
# Epoch 052 | Loss: 0.6301 | Val AUROC: 0.6965
# Epoch 053 | Loss: 0.6295 | Val AUROC: 0.6959
# Epoch 054 | Loss: 0.6390 | Val AUROC: 0.7044
# Epoch 055 | Loss: 0.6556 | Val AUROC: 0.6914
# Epoch 056 | Loss: 0.6325 | Val AUROC: 0.6920
# Epoch 057 | Loss: 0.6283 | Val AUROC: 0.6976
# Epoch 058 | Loss: 0.6183 | Val AUROC: 0.6982
# Epoch 059 | Loss: 0.6282 | Val AUROC: 0.6965
# Epoch 060 | Loss: 0.6338 | Val AUROC: 0.6926
# Epoch 061 | Loss: 0.6204 | Val AUROC: 0.7010
# Epoch 062 | Loss: 0.6149 | Val AUROC: 0.6993
# Epoch 063 | Loss: 0.6233 | Val AUROC: 0.6999
# Epoch 064 | Loss: 0.6156 | Val AUROC: 0.6920
# Epoch 065 | Loss: 0.6081 | Val AUROC: 0.6982
# Epoch 066 | Loss: 0.6042 | Val AUROC: 0.6999
# Early stopping at epoch 66 (best Val AUROC=0.7044)
#
# ===== Fold 3/5 =====
# pos_weight = 3.09  (neg=513, pos=166)
# Epoch 001 | Loss: 1.0351 | Val AUROC: 0.6751
# Epoch 002 | Loss: 1.0232 | Val AUROC: 0.7286
# Epoch 003 | Loss: 0.9844 | Val AUROC: 0.7264
# Epoch 004 | Loss: 0.9735 | Val AUROC: 0.7438
# Epoch 005 | Loss: 0.9399 | Val AUROC: 0.7511
# Epoch 006 | Loss: 0.9209 | Val AUROC: 0.7624
# Epoch 007 | Loss: 0.8982 | Val AUROC: 0.7753
# Epoch 008 | Loss: 0.8797 | Val AUROC: 0.7810
# Epoch 009 | Loss: 0.8768 | Val AUROC: 0.7872
# Epoch 010 | Loss: 0.8491 | Val AUROC: 0.7900
# Epoch 011 | Loss: 0.8463 | Val AUROC: 0.7939
# Epoch 012 | Loss: 0.8568 | Val AUROC: 0.7939
# Epoch 013 | Loss: 0.8272 | Val AUROC: 0.7979
# Epoch 014 | Loss: 0.8239 | Val AUROC: 0.8007
# Epoch 015 | Loss: 0.8035 | Val AUROC: 0.8046
# Epoch 016 | Loss: 0.8160 | Val AUROC: 0.8024
# Epoch 017 | Loss: 0.7920 | Val AUROC: 0.8057
# Epoch 018 | Loss: 0.7940 | Val AUROC: 0.8074
# Epoch 019 | Loss: 0.7842 | Val AUROC: 0.8063
# Epoch 020 | Loss: 0.8023 | Val AUROC: 0.8086
# Epoch 021 | Loss: 0.7862 | Val AUROC: 0.8057
# Epoch 022 | Loss: 0.7940 | Val AUROC: 0.8029
# Epoch 023 | Loss: 0.7786 | Val AUROC: 0.8069
# Epoch 024 | Loss: 0.7919 | Val AUROC: 0.8063
# Epoch 025 | Loss: 0.7725 | Val AUROC: 0.8063
# Epoch 026 | Loss: 0.7700 | Val AUROC: 0.8052
# Epoch 027 | Loss: 0.7500 | Val AUROC: 0.8024
# Epoch 028 | Loss: 0.7554 | Val AUROC: 0.8063
# Epoch 029 | Loss: 0.7518 | Val AUROC: 0.8086
# Epoch 030 | Loss: 0.7408 | Val AUROC: 0.8114
# Epoch 031 | Loss: 0.7551 | Val AUROC: 0.8114
# Epoch 032 | Loss: 0.7437 | Val AUROC: 0.8097
# Epoch 033 | Loss: 0.7367 | Val AUROC: 0.8097
# Epoch 034 | Loss: 0.7361 | Val AUROC: 0.8080
# Epoch 035 | Loss: 0.7410 | Val AUROC: 0.8080
# Epoch 036 | Loss: 0.7342 | Val AUROC: 0.8102
# Epoch 037 | Loss: 0.7433 | Val AUROC: 0.8097
# Epoch 038 | Loss: 0.7187 | Val AUROC: 0.8114
# Epoch 039 | Loss: 0.7108 | Val AUROC: 0.8114
# Epoch 040 | Loss: 0.7236 | Val AUROC: 0.8080
# Epoch 041 | Loss: 0.7177 | Val AUROC: 0.8097
# Epoch 042 | Loss: 0.7044 | Val AUROC: 0.8102
# Early stopping at epoch 42 (best Val AUROC=0.8114)
#
# ===== Fold 4/5 =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0487 | Val AUROC: 0.7838
# Epoch 002 | Loss: 1.0255 | Val AUROC: 0.7939
# Epoch 003 | Loss: 0.9882 | Val AUROC: 0.8069
# Epoch 004 | Loss: 0.9816 | Val AUROC: 0.8300
# Epoch 005 | Loss: 0.9586 | Val AUROC: 0.8333
# Epoch 006 | Loss: 0.9486 | Val AUROC: 0.8502
# Epoch 007 | Loss: 0.9271 | Val AUROC: 0.8480
# Epoch 008 | Loss: 0.9038 | Val AUROC: 0.8592
# Epoch 009 | Loss: 0.8996 | Val AUROC: 0.8666
# Epoch 010 | Loss: 0.8752 | Val AUROC: 0.8666
# Epoch 011 | Loss: 0.8673 | Val AUROC: 0.8671
# Epoch 012 | Loss: 0.8420 | Val AUROC: 0.8711
# Epoch 013 | Loss: 0.8337 | Val AUROC: 0.8677
# Epoch 014 | Loss: 0.8510 | Val AUROC: 0.8682
# Epoch 015 | Loss: 0.8359 | Val AUROC: 0.8761
# Epoch 016 | Loss: 0.8104 | Val AUROC: 0.8767
# Epoch 017 | Loss: 0.7984 | Val AUROC: 0.8773
# Epoch 018 | Loss: 0.8020 | Val AUROC: 0.8750
# Epoch 019 | Loss: 0.8037 | Val AUROC: 0.8722
# Epoch 020 | Loss: 0.8070 | Val AUROC: 0.8739
# Epoch 021 | Loss: 0.7836 | Val AUROC: 0.8716
# Epoch 022 | Loss: 0.7791 | Val AUROC: 0.8733
# Epoch 023 | Loss: 0.7925 | Val AUROC: 0.8756
# Epoch 024 | Loss: 0.7889 | Val AUROC: 0.8795
# Epoch 025 | Loss: 0.7952 | Val AUROC: 0.8784
# Epoch 026 | Loss: 0.7705 | Val AUROC: 0.8773
# Epoch 027 | Loss: 0.7671 | Val AUROC: 0.8756
# Epoch 028 | Loss: 0.7693 | Val AUROC: 0.8756
# Epoch 029 | Loss: 0.7705 | Val AUROC: 0.8750
# Epoch 030 | Loss: 0.7732 | Val AUROC: 0.8711
# Epoch 031 | Loss: 0.7465 | Val AUROC: 0.8727
# Epoch 032 | Loss: 0.7598 | Val AUROC: 0.8727
# Epoch 033 | Loss: 0.7572 | Val AUROC: 0.8716
# Epoch 034 | Loss: 0.7437 | Val AUROC: 0.8705
# Epoch 035 | Loss: 0.7645 | Val AUROC: 0.8727
# Epoch 036 | Loss: 0.7478 | Val AUROC: 0.8716
# Early stopping at epoch 36 (best Val AUROC=0.8795)
#
# ===== Fold 5/5 =====
# pos_weight = 2.97  (neg=508, pos=171)
# Epoch 001 | Loss: 1.0331 | Val AUROC: 0.6756
# Epoch 002 | Loss: 1.0057 | Val AUROC: 0.7151
# Epoch 003 | Loss: 0.9696 | Val AUROC: 0.7447
# Epoch 004 | Loss: 0.9498 | Val AUROC: 0.7529
# Epoch 005 | Loss: 0.9419 | Val AUROC: 0.7573
# Epoch 006 | Loss: 0.9185 | Val AUROC: 0.7666
# Epoch 007 | Loss: 0.8875 | Val AUROC: 0.7764
# Epoch 008 | Loss: 0.8843 | Val AUROC: 0.7797
# Epoch 009 | Loss: 0.8529 | Val AUROC: 0.7852
# Epoch 010 | Loss: 0.8488 | Val AUROC: 0.7945
# Epoch 011 | Loss: 0.8293 | Val AUROC: 0.8016
# Epoch 012 | Loss: 0.8243 | Val AUROC: 0.8077
# Epoch 013 | Loss: 0.8138 | Val AUROC: 0.8159
# Epoch 014 | Loss: 0.8131 | Val AUROC: 0.8203
# Epoch 015 | Loss: 0.8102 | Val AUROC: 0.8203
# Epoch 016 | Loss: 0.8106 | Val AUROC: 0.8285
# Epoch 017 | Loss: 0.8164 | Val AUROC: 0.8274
# Epoch 018 | Loss: 0.7778 | Val AUROC: 0.8296
# Epoch 019 | Loss: 0.7883 | Val AUROC: 0.8296
# Epoch 020 | Loss: 0.7970 | Val AUROC: 0.8312
# Epoch 021 | Loss: 0.7732 | Val AUROC: 0.8290
# Epoch 022 | Loss: 0.7766 | Val AUROC: 0.8312
# Epoch 023 | Loss: 0.7744 | Val AUROC: 0.8312
# Epoch 024 | Loss: 0.7487 | Val AUROC: 0.8307
# Epoch 025 | Loss: 0.7624 | Val AUROC: 0.8356
# Epoch 026 | Loss: 0.7604 | Val AUROC: 0.8323
# Epoch 027 | Loss: 0.7790 | Val AUROC: 0.8345
# Epoch 028 | Loss: 0.7558 | Val AUROC: 0.8373
# Epoch 029 | Loss: 0.7535 | Val AUROC: 0.8373
# Epoch 030 | Loss: 0.7409 | Val AUROC: 0.8384
# Epoch 031 | Loss: 0.7513 | Val AUROC: 0.8389
# Epoch 032 | Loss: 0.7555 | Val AUROC: 0.8405
# Epoch 033 | Loss: 0.7378 | Val AUROC: 0.8367
# Epoch 034 | Loss: 0.7403 | Val AUROC: 0.8373
# Epoch 035 | Loss: 0.7416 | Val AUROC: 0.8405
# Epoch 036 | Loss: 0.7419 | Val AUROC: 0.8323
# Epoch 037 | Loss: 0.7273 | Val AUROC: 0.8389
# Epoch 038 | Loss: 0.7340 | Val AUROC: 0.8466
# Epoch 039 | Loss: 0.7111 | Val AUROC: 0.8405
# Epoch 040 | Loss: 0.7178 | Val AUROC: 0.8433
# Epoch 041 | Loss: 0.7322 | Val AUROC: 0.8411
# Epoch 042 | Loss: 0.7145 | Val AUROC: 0.8416
# Epoch 043 | Loss: 0.7079 | Val AUROC: 0.8471
# Epoch 044 | Loss: 0.7145 | Val AUROC: 0.8427
# Epoch 045 | Loss: 0.7064 | Val AUROC: 0.8444
# Epoch 046 | Loss: 0.7063 | Val AUROC: 0.8471
# Epoch 047 | Loss: 0.7018 | Val AUROC: 0.8433
# Epoch 048 | Loss: 0.6806 | Val AUROC: 0.8526
# Epoch 049 | Loss: 0.6791 | Val AUROC: 0.8515
# Epoch 050 | Loss: 0.6906 | Val AUROC: 0.8488
# Epoch 051 | Loss: 0.7101 | Val AUROC: 0.8460
# Epoch 052 | Loss: 0.6791 | Val AUROC: 0.8433
# Epoch 053 | Loss: 0.6771 | Val AUROC: 0.8438
# Epoch 054 | Loss: 0.6632 | Val AUROC: 0.8433
# Epoch 055 | Loss: 0.6739 | Val AUROC: 0.8405
# Epoch 056 | Loss: 0.6688 | Val AUROC: 0.8471
# Epoch 057 | Loss: 0.6956 | Val AUROC: 0.8504
# Epoch 058 | Loss: 0.6570 | Val AUROC: 0.8449
# Epoch 059 | Loss: 0.6652 | Val AUROC: 0.8400
# Epoch 060 | Loss: 0.6767 | Val AUROC: 0.8444
# Early stopping at epoch 60 (best Val AUROC=0.8526)
#
# ===== 种子 7567 的 Bootstrap 结果 =====
# AUROC: 0.8042 (95% CI 0.7723–0.8363)
# AUPRC: 0.6125 (95% CI 0.5453–0.6757)
#
# 🎯 达到目标 AUROC ≥ 0.8，使用随机种子 7567 停止循环！

# %% [markdown]
# - 2.3. Use the random seed found above

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score, average_precision_score
import pandas as pd
import numpy as np
import os
import random

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

class LSTMWithStatic(nn.Module):
    def __init__(self, input_dim, static_dim, hidden_dim=64, num_layers=2, dropout=0.5):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers,
                            batch_first=True, dropout=dropout)
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim + static_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1)
        )
    def forward(self, x_seq, x_static):
        _, (h_n, _) = self.lstm(x_seq)
        h_last = h_n[-1]
        combined = torch.cat([h_last, x_static], dim=1)
        out = self.fc(combined)
        return out

def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=2000, seed=42):
    rng = np.random.RandomState(seed)
    scores = []
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    for _ in range(n_bootstrap):
        idx = rng.randint(0, len(y_true), len(y_true))
        if len(np.unique(y_true[idx])) < 2:
            continue
        scores.append(metric_fn(y_true[idx], y_pred[idx]))
    return np.mean(scores), np.percentile(scores, 2.5), np.percentile(scores, 97.5)

def train_until_target_auc(X_padded, X_static, y_tensor, base_save_path, target_auc=0.80): 
    fixed_seed = 7567  
    set_seed(fixed_seed)
    os.makedirs(base_save_path, exist_ok=True)
    device = torch.device("cuda" if torch.cuda.is_available() else
                          "mps" if torch.backends.mps.is_available() else "cpu")
    print(f"Using device: {device}")
    print(f"Using FIXED random seed: {fixed_seed}")
    seed = fixed_seed  
    save_path = os.path.join(base_save_path, f"seed_{seed}")
    os.makedirs(save_path, exist_ok=True)

    kf = KFold(n_splits=5, shuffle=True, random_state=seed)
    all_results = []

    max_epochs = 100
    batch_size = 16
    lr = 5e-4
    weight_decay = 5e-4
    patience = 12

    # ===== 5-fold CV =====
    for fold, (train_val_idx, test_idx) in enumerate(kf.split(X_padded)):
        print(f"\n===== Fold {fold+1}/5 (seed={seed}) =====")
        X_train_val_seq, X_test_seq = X_padded[train_val_idx], X_padded[test_idx]
        X_train_val_static, X_test_static = X_static[train_val_idx], X_static[test_idx]
        y_train_val, y_test = y_tensor[train_val_idx], y_tensor[test_idx]

        X_train_seq, X_val_seq, X_train_static, X_val_static, y_train, y_val = train_test_split(
            X_train_val_seq, X_train_val_static, y_train_val,
            test_size=1/8, random_state=seed, stratify=y_train_val
        )

        # pos_weight
        num_pos = (y_train == 1).sum().item()
        num_neg = (y_train == 0).sum().item()
        pos_weight = torch.tensor(num_neg / max(num_pos, 1), dtype=torch.float32).to(device)
        print(f"pos_weight = {pos_weight:.2f}  (neg={num_neg}, pos={num_pos})")
        train_loader = DataLoader(
            TensorDataset(X_train_seq, X_train_static, y_train),
            batch_size=batch_size,
            shuffle=True
        )
        model = LSTMWithStatic(
            input_dim=X_padded.shape[2],
            static_dim=X_static.shape[1],
            hidden_dim=64,
            dropout=0.5
        ).to(device)
        criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

        best_auroc = 0
        wait = 0
        best_model_path = os.path.join(save_path, f"seed_{seed}_fold_{fold+1}_best.pt")

        # ===== Epoch Loop =====
        for epoch in range(max_epochs):
            model.train()
            total_loss = 0.0
            for batch_seq, batch_static, batch_y in train_loader:
                batch_seq, batch_static, batch_y = (
                    batch_seq.to(device),
                    batch_static.to(device),
                    batch_y.to(device),
                )
                optimizer.zero_grad()
                logits = model(batch_seq, batch_static)
                loss = criterion(logits, batch_y)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            avg_loss = total_loss / len(train_loader)
            model.eval()
            with torch.no_grad():
                logits = model(X_val_seq.to(device), X_val_static.to(device)).cpu().numpy().flatten()
                y_pred = 1 / (1 + np.exp(-logits))
                y_true = y_val.numpy().reshape(-1)
                auroc_val = roc_auc_score(y_true, y_pred)

            print(f"Epoch {epoch+1:03d} | Loss: {avg_loss:.4f} | Val AUROC: {auroc_val:.4f}")

            # Early stopping
            if auroc_val > best_auroc:
                best_auroc = auroc_val
                wait = 0
                torch.save(model.state_dict(), best_model_path)
            else:
                wait += 1
                if wait >= patience:
                    print(f"Early stopping at epoch {epoch+1} (best Val AUROC={best_auroc:.4f})")
                    break

        # ===== Test Set Evaluation =====
        model.load_state_dict(torch.load(best_model_path, map_location=device))
        model.eval()
        with torch.no_grad():
            logits = model(X_test_seq.to(device), X_test_static.to(device)).cpu().numpy().flatten()
            y_pred = 1 / (1 + np.exp(-logits))
            y_true = y_test.numpy().reshape(-1)

            result_df = pd.DataFrame({
                "seed": seed,
                "fold": fold+1,
                "y_test": y_true,
                "y_pred": y_pred
            })
            result_df.to_csv(os.path.join(save_path, f"seed_{seed}_fold_{fold+1}_results.csv"), index=False)
            all_results.append(result_df)
    all_results_df = pd.concat(all_results, axis=0).reset_index(drop=True)
    y_all_true = all_results_df["y_test"].values
    y_all_pred = all_results_df["y_pred"].values
    mean_auroc, auc_lower, auc_upper = bootstrap_metric_ci(
        y_all_true, y_all_pred, roc_auc_score
    )
    mean_auprc, auprc_lower, auprc_upper = bootstrap_metric_ci(
        y_all_true, y_all_pred, average_precision_score
    )
    print(f"AUROC: {mean_auroc:.4f} (95% CI {auc_lower:.4f}–{auc_upper:.4f})")
    print(f"AUPRC: {mean_auprc:.4f} (95% CI {auprc_lower:.4f}–{auprc_upper:.4f})")
    all_results_df.to_csv(os.path.join(save_path, f"seed_{seed}_all_results.csv"), index=False)

# ===================== Call example =====================
save_path = '/home/mailiyi/Poisoning_Prediction/LSTM/predict_non-recovery_valid_test_5cv/'
train_until_target_auc(X_padded, X_static, y_tensor, save_path, target_auc=0.80)
# Out:
# Using device: cuda
# Using FIXED random seed: 7567
#
# ===== Fold 1/5 (seed=7567) =====
# pos_weight = 2.95  (neg=507, pos=172)
# Epoch 001 | Loss: 1.0349 | Val AUROC: 0.6411
# Epoch 002 | Loss: 1.0132 | Val AUROC: 0.7006
# Epoch 003 | Loss: 0.9959 | Val AUROC: 0.7356
# Epoch 004 | Loss: 0.9724 | Val AUROC: 0.7467
# Epoch 005 | Loss: 0.9534 | Val AUROC: 0.7511
# Epoch 006 | Loss: 0.9448 | Val AUROC: 0.7478
# Epoch 007 | Loss: 0.9309 | Val AUROC: 0.7583
# Epoch 008 | Loss: 0.9212 | Val AUROC: 0.7628
# Epoch 009 | Loss: 0.8771 | Val AUROC: 0.7672
# Epoch 010 | Loss: 0.8703 | Val AUROC: 0.7678
# Epoch 011 | Loss: 0.8651 | Val AUROC: 0.7750
# Epoch 012 | Loss: 0.8500 | Val AUROC: 0.7722
# Epoch 013 | Loss: 0.8218 | Val AUROC: 0.7739
# Epoch 014 | Loss: 0.8256 | Val AUROC: 0.7783
# Epoch 015 | Loss: 0.8210 | Val AUROC: 0.7761
# Epoch 016 | Loss: 0.7930 | Val AUROC: 0.7778
# Epoch 017 | Loss: 0.8045 | Val AUROC: 0.7800
# Epoch 018 | Loss: 0.7876 | Val AUROC: 0.7811
# Epoch 019 | Loss: 0.7938 | Val AUROC: 0.7822
# Epoch 020 | Loss: 0.7853 | Val AUROC: 0.7817
# Epoch 021 | Loss: 0.7780 | Val AUROC: 0.7806
# Epoch 022 | Loss: 0.7720 | Val AUROC: 0.7861
# Epoch 023 | Loss: 0.7605 | Val AUROC: 0.7850
# Epoch 024 | Loss: 0.7617 | Val AUROC: 0.7861
# Epoch 025 | Loss: 0.7629 | Val AUROC: 0.7861
# Epoch 026 | Loss: 0.7671 | Val AUROC: 0.7850
# Epoch 027 | Loss: 0.7546 | Val AUROC: 0.7856
# Epoch 028 | Loss: 0.7511 | Val AUROC: 0.7867
# Epoch 029 | Loss: 0.7566 | Val AUROC: 0.7911
# Epoch 030 | Loss: 0.7353 | Val AUROC: 0.7939
# Epoch 031 | Loss: 0.7154 | Val AUROC: 0.7906
# Epoch 032 | Loss: 0.7228 | Val AUROC: 0.7900
# Epoch 033 | Loss: 0.7464 | Val AUROC: 0.7911
# Epoch 034 | Loss: 0.7310 | Val AUROC: 0.7900
# Epoch 035 | Loss: 0.7133 | Val AUROC: 0.7928
# Epoch 036 | Loss: 0.7202 | Val AUROC: 0.7928
# Epoch 037 | Loss: 0.7222 | Val AUROC: 0.7900
# Epoch 038 | Loss: 0.7108 | Val AUROC: 0.7944
# Epoch 039 | Loss: 0.7146 | Val AUROC: 0.7939
# Epoch 040 | Loss: 0.7251 | Val AUROC: 0.7956
# Epoch 041 | Loss: 0.7149 | Val AUROC: 0.7961
# Epoch 042 | Loss: 0.7043 | Val AUROC: 0.7933
# Epoch 043 | Loss: 0.7070 | Val AUROC: 0.7944
# Epoch 044 | Loss: 0.6972 | Val AUROC: 0.7961
# Epoch 045 | Loss: 0.6895 | Val AUROC: 0.7961
# Epoch 046 | Loss: 0.7110 | Val AUROC: 0.7983
# Epoch 047 | Loss: 0.7033 | Val AUROC: 0.7978
# Epoch 048 | Loss: 0.6882 | Val AUROC: 0.7978
# Epoch 049 | Loss: 0.6911 | Val AUROC: 0.8006
# Epoch 050 | Loss: 0.6817 | Val AUROC: 0.7994
# Epoch 051 | Loss: 0.6776 | Val AUROC: 0.7983
# Epoch 052 | Loss: 0.6905 | Val AUROC: 0.7983
# Epoch 053 | Loss: 0.6770 | Val AUROC: 0.8022
# Epoch 054 | Loss: 0.6663 | Val AUROC: 0.8017
# Epoch 055 | Loss: 0.6809 | Val AUROC: 0.8033
# Epoch 056 | Loss: 0.6915 | Val AUROC: 0.8017
# Epoch 057 | Loss: 0.6796 | Val AUROC: 0.8039
# Epoch 058 | Loss: 0.6697 | Val AUROC: 0.8050
# Epoch 059 | Loss: 0.6599 | Val AUROC: 0.8033
# Epoch 060 | Loss: 0.6712 | Val AUROC: 0.8011
# Epoch 061 | Loss: 0.6520 | Val AUROC: 0.8017
# Epoch 062 | Loss: 0.6424 | Val AUROC: 0.8033
# Epoch 063 | Loss: 0.6576 | Val AUROC: 0.8044
# Epoch 064 | Loss: 0.6602 | Val AUROC: 0.8056
# Epoch 065 | Loss: 0.6417 | Val AUROC: 0.8033
# Epoch 066 | Loss: 0.6513 | Val AUROC: 0.8033
# Epoch 067 | Loss: 0.6557 | Val AUROC: 0.8083
# Epoch 068 | Loss: 0.6407 | Val AUROC: 0.8072
# Epoch 069 | Loss: 0.6511 | Val AUROC: 0.8072
# Epoch 070 | Loss: 0.6417 | Val AUROC: 0.8083
# Epoch 071 | Loss: 0.6168 | Val AUROC: 0.8072
# Epoch 072 | Loss: 0.6318 | Val AUROC: 0.8056
# Epoch 073 | Loss: 0.6274 | Val AUROC: 0.8083
# Epoch 074 | Loss: 0.6311 | Val AUROC: 0.8083
# Epoch 075 | Loss: 0.6216 | Val AUROC: 0.8089
# Epoch 076 | Loss: 0.6330 | Val AUROC: 0.8044
# Epoch 077 | Loss: 0.6235 | Val AUROC: 0.8050
# Epoch 078 | Loss: 0.6282 | Val AUROC: 0.8094
# Epoch 079 | Loss: 0.6201 | Val AUROC: 0.8111
# Epoch 080 | Loss: 0.6277 | Val AUROC: 0.8083
# Epoch 081 | Loss: 0.6205 | Val AUROC: 0.8078
# Epoch 082 | Loss: 0.6159 | Val AUROC: 0.8083
# Epoch 083 | Loss: 0.6189 | Val AUROC: 0.8089
# Epoch 084 | Loss: 0.6335 | Val AUROC: 0.8078
# Epoch 085 | Loss: 0.5934 | Val AUROC: 0.8056
# Epoch 086 | Loss: 0.6380 | Val AUROC: 0.8072
# Epoch 087 | Loss: 0.6110 | Val AUROC: 0.8094
# Epoch 088 | Loss: 0.6075 | Val AUROC: 0.8072
# Epoch 089 | Loss: 0.5739 | Val AUROC: 0.8078
# Epoch 090 | Loss: 0.6032 | Val AUROC: 0.8072
# Epoch 091 | Loss: 0.5994 | Val AUROC: 0.8061
# Early stopping at epoch 91 (best Val AUROC=0.8111)
#
# ===== Fold 2/5 (seed=7567) =====
# pos_weight = 3.14  (neg=515, pos=164)
# Epoch 001 | Loss: 1.0399 | Val AUROC: 0.6447
# Epoch 002 | Loss: 1.0200 | Val AUROC: 0.6464
# Epoch 003 | Loss: 0.9917 | Val AUROC: 0.6509
# Epoch 004 | Loss: 0.9551 | Val AUROC: 0.6408
# Epoch 005 | Loss: 0.9367 | Val AUROC: 0.6537
# Epoch 006 | Loss: 0.9053 | Val AUROC: 0.6582
# Epoch 007 | Loss: 0.8819 | Val AUROC: 0.6616
# Epoch 008 | Loss: 0.8731 | Val AUROC: 0.6610
# Epoch 009 | Loss: 0.8497 | Val AUROC: 0.6684
# Epoch 010 | Loss: 0.8393 | Val AUROC: 0.6785
# Epoch 011 | Loss: 0.8125 | Val AUROC: 0.6717
# Epoch 012 | Loss: 0.8144 | Val AUROC: 0.6706
# Epoch 013 | Loss: 0.7951 | Val AUROC: 0.6712
# Epoch 014 | Loss: 0.7814 | Val AUROC: 0.6706
# Epoch 015 | Loss: 0.7922 | Val AUROC: 0.6768
# Epoch 016 | Loss: 0.7718 | Val AUROC: 0.6807
# Epoch 017 | Loss: 0.7759 | Val AUROC: 0.6869
# Epoch 018 | Loss: 0.7571 | Val AUROC: 0.6858
# Epoch 019 | Loss: 0.7619 | Val AUROC: 0.6836
# Epoch 020 | Loss: 0.7584 | Val AUROC: 0.6847
# Epoch 021 | Loss: 0.7456 | Val AUROC: 0.6858
# Epoch 022 | Loss: 0.7443 | Val AUROC: 0.6813
# Epoch 023 | Loss: 0.7410 | Val AUROC: 0.6791
# Epoch 024 | Loss: 0.7414 | Val AUROC: 0.6841
# Epoch 025 | Loss: 0.7192 | Val AUROC: 0.6852
# Epoch 026 | Loss: 0.7193 | Val AUROC: 0.6841
# Epoch 027 | Loss: 0.7151 | Val AUROC: 0.6903
# Epoch 028 | Loss: 0.7240 | Val AUROC: 0.6841
# Epoch 029 | Loss: 0.7311 | Val AUROC: 0.6881
# Epoch 030 | Loss: 0.7371 | Val AUROC: 0.6909
# Epoch 031 | Loss: 0.7117 | Val AUROC: 0.6886
# Epoch 032 | Loss: 0.7035 | Val AUROC: 0.6875
# Epoch 033 | Loss: 0.6990 | Val AUROC: 0.6875
# Epoch 034 | Loss: 0.6954 | Val AUROC: 0.6875
# Epoch 035 | Loss: 0.7061 | Val AUROC: 0.6920
# Epoch 036 | Loss: 0.6966 | Val AUROC: 0.6881
# Epoch 037 | Loss: 0.6895 | Val AUROC: 0.6931
# Epoch 038 | Loss: 0.6799 | Val AUROC: 0.6943
# Epoch 039 | Loss: 0.6942 | Val AUROC: 0.6914
# Epoch 040 | Loss: 0.6842 | Val AUROC: 0.6920
# Epoch 041 | Loss: 0.6830 | Val AUROC: 0.6931
# Epoch 042 | Loss: 0.6949 | Val AUROC: 0.6898
# Epoch 043 | Loss: 0.6647 | Val AUROC: 0.6943
# Epoch 044 | Loss: 0.6697 | Val AUROC: 0.6875
# Epoch 045 | Loss: 0.6756 | Val AUROC: 0.6948
# Epoch 046 | Loss: 0.6652 | Val AUROC: 0.6943
# Epoch 047 | Loss: 0.6684 | Val AUROC: 0.6954
# Epoch 048 | Loss: 0.6791 | Val AUROC: 0.6982
# Epoch 049 | Loss: 0.6622 | Val AUROC: 0.6943
# Epoch 050 | Loss: 0.6519 | Val AUROC: 0.6948
# Epoch 051 | Loss: 0.6831 | Val AUROC: 0.6971
# Epoch 052 | Loss: 0.6301 | Val AUROC: 0.6965
# Epoch 053 | Loss: 0.6295 | Val AUROC: 0.6959
# Epoch 054 | Loss: 0.6390 | Val AUROC: 0.7044
# Epoch 055 | Loss: 0.6556 | Val AUROC: 0.6914
# Epoch 056 | Loss: 0.6325 | Val AUROC: 0.6920
# Epoch 057 | Loss: 0.6283 | Val AUROC: 0.6976
# Epoch 058 | Loss: 0.6183 | Val AUROC: 0.6982
# Epoch 059 | Loss: 0.6282 | Val AUROC: 0.6965
# Epoch 060 | Loss: 0.6338 | Val AUROC: 0.6926
# Epoch 061 | Loss: 0.6204 | Val AUROC: 0.7010
# Epoch 062 | Loss: 0.6149 | Val AUROC: 0.6993
# Epoch 063 | Loss: 0.6233 | Val AUROC: 0.6999
# Epoch 064 | Loss: 0.6156 | Val AUROC: 0.6920
# Epoch 065 | Loss: 0.6081 | Val AUROC: 0.6982
# Epoch 066 | Loss: 0.6042 | Val AUROC: 0.6999
# Early stopping at epoch 66 (best Val AUROC=0.7044)
#
# ===== Fold 3/5 (seed=7567) =====
# pos_weight = 3.09  (neg=513, pos=166)
# Epoch 001 | Loss: 1.0351 | Val AUROC: 0.6751
# Epoch 002 | Loss: 1.0232 | Val AUROC: 0.7286
# Epoch 003 | Loss: 0.9844 | Val AUROC: 0.7264
# Epoch 004 | Loss: 0.9735 | Val AUROC: 0.7438
# Epoch 005 | Loss: 0.9399 | Val AUROC: 0.7511
# Epoch 006 | Loss: 0.9209 | Val AUROC: 0.7624
# Epoch 007 | Loss: 0.8982 | Val AUROC: 0.7753
# Epoch 008 | Loss: 0.8797 | Val AUROC: 0.7810
# Epoch 009 | Loss: 0.8768 | Val AUROC: 0.7872
# Epoch 010 | Loss: 0.8491 | Val AUROC: 0.7900
# Epoch 011 | Loss: 0.8463 | Val AUROC: 0.7939
# Epoch 012 | Loss: 0.8568 | Val AUROC: 0.7939
# Epoch 013 | Loss: 0.8272 | Val AUROC: 0.7979
# Epoch 014 | Loss: 0.8239 | Val AUROC: 0.8007
# Epoch 015 | Loss: 0.8035 | Val AUROC: 0.8046
# Epoch 016 | Loss: 0.8160 | Val AUROC: 0.8024
# Epoch 017 | Loss: 0.7920 | Val AUROC: 0.8057
# Epoch 018 | Loss: 0.7940 | Val AUROC: 0.8074
# Epoch 019 | Loss: 0.7842 | Val AUROC: 0.8063
# Epoch 020 | Loss: 0.8023 | Val AUROC: 0.8086
# Epoch 021 | Loss: 0.7862 | Val AUROC: 0.8057
# Epoch 022 | Loss: 0.7940 | Val AUROC: 0.8029
# Epoch 023 | Loss: 0.7786 | Val AUROC: 0.8069
# Epoch 024 | Loss: 0.7919 | Val AUROC: 0.8063
# Epoch 025 | Loss: 0.7725 | Val AUROC: 0.8063
# Epoch 026 | Loss: 0.7700 | Val AUROC: 0.8052
# Epoch 027 | Loss: 0.7500 | Val AUROC: 0.8024
# Epoch 028 | Loss: 0.7554 | Val AUROC: 0.8063
# Epoch 029 | Loss: 0.7518 | Val AUROC: 0.8086
# Epoch 030 | Loss: 0.7408 | Val AUROC: 0.8114
# Epoch 031 | Loss: 0.7551 | Val AUROC: 0.8114
# Epoch 032 | Loss: 0.7437 | Val AUROC: 0.8097
# Epoch 033 | Loss: 0.7367 | Val AUROC: 0.8097
# Epoch 034 | Loss: 0.7361 | Val AUROC: 0.8080
# Epoch 035 | Loss: 0.7410 | Val AUROC: 0.8080
# Epoch 036 | Loss: 0.7342 | Val AUROC: 0.8102
# Epoch 037 | Loss: 0.7433 | Val AUROC: 0.8097
# Epoch 038 | Loss: 0.7187 | Val AUROC: 0.8114
# Epoch 039 | Loss: 0.7108 | Val AUROC: 0.8114
# Epoch 040 | Loss: 0.7236 | Val AUROC: 0.8080
# Epoch 041 | Loss: 0.7177 | Val AUROC: 0.8097
# Epoch 042 | Loss: 0.7044 | Val AUROC: 0.8102
# Early stopping at epoch 42 (best Val AUROC=0.8114)
#
# ===== Fold 4/5 (seed=7567) =====
# pos_weight = 3.12  (neg=514, pos=165)
# Epoch 001 | Loss: 1.0487 | Val AUROC: 0.7838
# Epoch 002 | Loss: 1.0255 | Val AUROC: 0.7939
# Epoch 003 | Loss: 0.9882 | Val AUROC: 0.8069
# Epoch 004 | Loss: 0.9816 | Val AUROC: 0.8300
# Epoch 005 | Loss: 0.9586 | Val AUROC: 0.8333
# Epoch 006 | Loss: 0.9486 | Val AUROC: 0.8502
# Epoch 007 | Loss: 0.9271 | Val AUROC: 0.8480
# Epoch 008 | Loss: 0.9038 | Val AUROC: 0.8592
# Epoch 009 | Loss: 0.8996 | Val AUROC: 0.8666
# Epoch 010 | Loss: 0.8752 | Val AUROC: 0.8666
# Epoch 011 | Loss: 0.8673 | Val AUROC: 0.8671
# Epoch 012 | Loss: 0.8420 | Val AUROC: 0.8711
# Epoch 013 | Loss: 0.8337 | Val AUROC: 0.8677
# Epoch 014 | Loss: 0.8510 | Val AUROC: 0.8682
# Epoch 015 | Loss: 0.8359 | Val AUROC: 0.8761
# Epoch 016 | Loss: 0.8104 | Val AUROC: 0.8767
# Epoch 017 | Loss: 0.7984 | Val AUROC: 0.8773
# Epoch 018 | Loss: 0.8020 | Val AUROC: 0.8750
# Epoch 019 | Loss: 0.8037 | Val AUROC: 0.8722
# Epoch 020 | Loss: 0.8070 | Val AUROC: 0.8739
# Epoch 021 | Loss: 0.7836 | Val AUROC: 0.8716
# Epoch 022 | Loss: 0.7791 | Val AUROC: 0.8733
# Epoch 023 | Loss: 0.7925 | Val AUROC: 0.8756
# Epoch 024 | Loss: 0.7889 | Val AUROC: 0.8795
# Epoch 025 | Loss: 0.7952 | Val AUROC: 0.8784
# Epoch 026 | Loss: 0.7705 | Val AUROC: 0.8773
# Epoch 027 | Loss: 0.7671 | Val AUROC: 0.8756
# Epoch 028 | Loss: 0.7693 | Val AUROC: 0.8756
# Epoch 029 | Loss: 0.7705 | Val AUROC: 0.8750
# Epoch 030 | Loss: 0.7732 | Val AUROC: 0.8711
# Epoch 031 | Loss: 0.7465 | Val AUROC: 0.8727
# Epoch 032 | Loss: 0.7598 | Val AUROC: 0.8727
# Epoch 033 | Loss: 0.7572 | Val AUROC: 0.8716
# Epoch 034 | Loss: 0.7437 | Val AUROC: 0.8705
# Epoch 035 | Loss: 0.7645 | Val AUROC: 0.8727
# Epoch 036 | Loss: 0.7478 | Val AUROC: 0.8716
# Early stopping at epoch 36 (best Val AUROC=0.8795)
#
# ===== Fold 5/5 (seed=7567) =====
# pos_weight = 2.97  (neg=508, pos=171)
# Epoch 001 | Loss: 1.0331 | Val AUROC: 0.6756
# Epoch 002 | Loss: 1.0057 | Val AUROC: 0.7151
# Epoch 003 | Loss: 0.9696 | Val AUROC: 0.7447
# Epoch 004 | Loss: 0.9498 | Val AUROC: 0.7529
# Epoch 005 | Loss: 0.9419 | Val AUROC: 0.7573
# Epoch 006 | Loss: 0.9185 | Val AUROC: 0.7666
# Epoch 007 | Loss: 0.8875 | Val AUROC: 0.7764
# Epoch 008 | Loss: 0.8843 | Val AUROC: 0.7797
# Epoch 009 | Loss: 0.8529 | Val AUROC: 0.7852
# Epoch 010 | Loss: 0.8488 | Val AUROC: 0.7945
# Epoch 011 | Loss: 0.8293 | Val AUROC: 0.8016
# Epoch 012 | Loss: 0.8243 | Val AUROC: 0.8077
# Epoch 013 | Loss: 0.8138 | Val AUROC: 0.8159
# Epoch 014 | Loss: 0.8131 | Val AUROC: 0.8203
# Epoch 015 | Loss: 0.8102 | Val AUROC: 0.8203
# Epoch 016 | Loss: 0.8106 | Val AUROC: 0.8285
# Epoch 017 | Loss: 0.8164 | Val AUROC: 0.8274
# Epoch 018 | Loss: 0.7778 | Val AUROC: 0.8296
# Epoch 019 | Loss: 0.7883 | Val AUROC: 0.8296
# Epoch 020 | Loss: 0.7970 | Val AUROC: 0.8312
# Epoch 021 | Loss: 0.7732 | Val AUROC: 0.8290
# Epoch 022 | Loss: 0.7766 | Val AUROC: 0.8312
# Epoch 023 | Loss: 0.7744 | Val AUROC: 0.8312
# Epoch 024 | Loss: 0.7487 | Val AUROC: 0.8307
# Epoch 025 | Loss: 0.7624 | Val AUROC: 0.8356
# Epoch 026 | Loss: 0.7604 | Val AUROC: 0.8323
# Epoch 027 | Loss: 0.7790 | Val AUROC: 0.8345
# Epoch 028 | Loss: 0.7558 | Val AUROC: 0.8373
# Epoch 029 | Loss: 0.7535 | Val AUROC: 0.8373
# Epoch 030 | Loss: 0.7409 | Val AUROC: 0.8384
# Epoch 031 | Loss: 0.7513 | Val AUROC: 0.8389
# Epoch 032 | Loss: 0.7555 | Val AUROC: 0.8405
# Epoch 033 | Loss: 0.7378 | Val AUROC: 0.8367
# Epoch 034 | Loss: 0.7403 | Val AUROC: 0.8373
# Epoch 035 | Loss: 0.7416 | Val AUROC: 0.8405
# Epoch 036 | Loss: 0.7419 | Val AUROC: 0.8323
# Epoch 037 | Loss: 0.7273 | Val AUROC: 0.8389
# Epoch 038 | Loss: 0.7340 | Val AUROC: 0.8466
# Epoch 039 | Loss: 0.7111 | Val AUROC: 0.8405
# Epoch 040 | Loss: 0.7178 | Val AUROC: 0.8433
# Epoch 041 | Loss: 0.7322 | Val AUROC: 0.8411
# Epoch 042 | Loss: 0.7145 | Val AUROC: 0.8416
# Epoch 043 | Loss: 0.7079 | Val AUROC: 0.8471
# Epoch 044 | Loss: 0.7145 | Val AUROC: 0.8427
# Epoch 045 | Loss: 0.7064 | Val AUROC: 0.8444
# Epoch 046 | Loss: 0.7063 | Val AUROC: 0.8471
# Epoch 047 | Loss: 0.7018 | Val AUROC: 0.8433
# Epoch 048 | Loss: 0.6806 | Val AUROC: 0.8526
# Epoch 049 | Loss: 0.6791 | Val AUROC: 0.8515
# Epoch 050 | Loss: 0.6906 | Val AUROC: 0.8488
# Epoch 051 | Loss: 0.7101 | Val AUROC: 0.8460
# Epoch 052 | Loss: 0.6791 | Val AUROC: 0.8433
# Epoch 053 | Loss: 0.6771 | Val AUROC: 0.8438
# Epoch 054 | Loss: 0.6632 | Val AUROC: 0.8433
# Epoch 055 | Loss: 0.6739 | Val AUROC: 0.8405
# Epoch 056 | Loss: 0.6688 | Val AUROC: 0.8471
# Epoch 057 | Loss: 0.6956 | Val AUROC: 0.8504
# Epoch 058 | Loss: 0.6570 | Val AUROC: 0.8449
# Epoch 059 | Loss: 0.6652 | Val AUROC: 0.8400
# Epoch 060 | Loss: 0.6767 | Val AUROC: 0.8444
# Early stopping at epoch 60 (best Val AUROC=0.8526)
#
# ===== 固定种子 7567 的 Bootstrap 结果 =====
# AUROC: 0.8042 (95% CI 0.7723–0.8363)
# AUPRC: 0.6125 (95% CI 0.5453–0.6757)

# %% [markdown]
# - No pos_weight specified

# %%
import torch  
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score, average_precision_score
import pandas as pd
import numpy as np
import os
import random


def set_seed(seed=7567):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    print(f"Random seed fixed as {seed}")

set_seed(7567)

class LSTMWithStatic(nn.Module):
    def __init__(self, input_dim, static_dim, hidden_dim=64, num_layers=2, dropout=0.5):
        super().__init__()
        self.lstm = nn.LSTM(
            input_dim, hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout
        )
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim + static_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(64, 1)
        )

    def forward(self, x_seq, x_static):
        _, (h_n, _) = self.lstm(x_seq)
        h_last = h_n[-1]
        combined = torch.cat([h_last, x_static], dim=1)
        out = self.fc(combined)
        return out  # logits

def bootstrap_metric_ci(y_true, y_pred, metric_fn, n_bootstrap=2000, seed=7567):
    rng = np.random.RandomState(seed)
    scores = []
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    for _ in range(n_bootstrap):
        idx = rng.randint(0, len(y_true), len(y_true))
        if len(np.unique(y_true[idx])) < 2:
            continue
        scores.append(metric_fn(y_true[idx], y_pred[idx]))
    return np.mean(scores), np.percentile(scores, 2.5), np.percentile(scores, 97.5)

def train_lstm_5fold(X_padded, X_static, y_tensor, save_path, target_auc=0.80):
    os.makedirs(save_path, exist_ok=True)
    device = torch.device("cuda" if torch.cuda.is_available() else
                          "mps" if torch.backends.mps.is_available() else "cpu")
    print(f"Using device: {device}")

    seed = 7567
    kf = KFold(n_splits=5, shuffle=True, random_state=seed)
    all_results = []

    max_epochs = 100
    batch_size = 16
    lr = 5e-4
    weight_decay = 5e-4
    patience = 12

    for fold, (train_val_idx, test_idx) in enumerate(kf.split(X_padded)):
        print(f"\n===== Fold {fold+1}/5 =====")
        X_train_val_seq, X_test_seq = X_padded[train_val_idx], X_padded[test_idx]
        X_train_val_static, X_test_static = X_static[train_val_idx], X_static[test_idx]
        y_train_val, y_test = y_tensor[train_val_idx], y_tensor[test_idx]

        X_train_seq, X_val_seq, X_train_static, X_val_static, y_train, y_val = train_test_split(
            X_train_val_seq, X_train_val_static, y_train_val,
            test_size=1/8,
            random_state=seed,
            stratify=y_train_val
        )

        train_loader = DataLoader(
            TensorDataset(X_train_seq, X_train_static, y_train),
            batch_size=batch_size,
            shuffle=True
        )

        model = LSTMWithStatic(
            input_dim=X_padded.shape[2],
            static_dim=X_static.shape[1],
            hidden_dim=64,
            dropout=0.5
        ).to(device)

        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

        best_auroc = 0
        wait = 0
        best_model_path = os.path.join(save_path, f"fold_{fold+1}_best.pt")

        # ===================== train =====================
        for epoch in range(max_epochs):
            model.train()
            total_loss = 0.0
            for batch_seq, batch_static, batch_y in train_loader:
                batch_seq = batch_seq.to(device)
                batch_static = batch_static.to(device)
                batch_y = batch_y.to(device)

                optimizer.zero_grad()
                logits = model(batch_seq, batch_static)
                loss = criterion(logits, batch_y)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()

            avg_loss = total_loss / len(train_loader)

            model.eval()
            with torch.no_grad():
                logits = model(X_val_seq.to(device), X_val_static.to(device)).cpu().numpy().flatten()
                y_pred = 1 / (1 + np.exp(-logits))
                y_true = y_val.numpy().reshape(-1)
                auroc_val = roc_auc_score(y_true, y_pred)

            print(f"Epoch {epoch+1:03d} | Loss: {avg_loss:.4f} | Val AUROC: {auroc_val:.4f}")

            # Early stopping
            if auroc_val > best_auroc:
                best_auroc = auroc_val
                wait = 0
                torch.save(model.state_dict(), best_model_path)
            else:
                wait += 1
                if wait >= patience:
                    print(f"Early stopping at epoch {epoch+1} (best Val AUROC={best_auroc:.4f})")
                    break

        # ===================== Test Set Evaluation =====================
        model.load_state_dict(torch.load(best_model_path, map_location=device))
        model.eval()
        with torch.no_grad():
            logits = model(X_test_seq.to(device), X_test_static.to(device)).cpu().numpy().flatten()
            y_pred = 1 / (1 + np.exp(-logits))
            y_true = y_test.numpy().reshape(-1)

            result_df = pd.DataFrame({
                "fold": fold+1,
                "y_test": y_true,
                "y_pred": y_pred
            })
            result_df.to_csv(os.path.join(save_path, f"fold_{fold+1}_results.csv"), index=False)
            all_results.append(result_df)

    all_results_df = pd.concat(all_results, axis=0).reset_index(drop=True)
    y_all_true = all_results_df["y_test"].values
    y_all_pred = all_results_df["y_pred"].values

    mean_auroc, auc_lower, auc_upper = bootstrap_metric_ci(y_all_true, y_all_pred, roc_auc_score)
    mean_auprc, auprc_lower, auprc_upper = bootstrap_metric_ci(y_all_true, y_all_pred, average_precision_score)

    print(f"AUROC: {mean_auroc:.4f} (95% CI {auc_lower:.4f}–{auc_upper:.4f})")
    print(f"AUPRC: {mean_auprc:.4f} (95% CI {auprc_lower:.4f}–{auprc_upper:.4f})")

    all_results_df.to_csv(os.path.join(save_path, f"all_folds_results.csv"), index=False)

# ===================== Call example =====================
save_path = '/home/mailiyi/Poisoning_Prediction/LSTM/predict_non-recovery_calibration/'
train_lstm_5fold(X_padded, X_static, y_tensor, save_path, target_auc=0.80)
# Out:
# Random seed fixed as 7567
# Using device: cuda
#
# ===== Fold 1/5 =====
# Epoch 001 | Loss: 0.6088 | Val AUROC: 0.6072
# Epoch 002 | Loss: 0.5681 | Val AUROC: 0.6883
# Epoch 003 | Loss: 0.5539 | Val AUROC: 0.7222
# Epoch 004 | Loss: 0.5351 | Val AUROC: 0.7344
# Epoch 005 | Loss: 0.5250 | Val AUROC: 0.7422
# Epoch 006 | Loss: 0.5301 | Val AUROC: 0.7478
# Epoch 007 | Loss: 0.5191 | Val AUROC: 0.7522
# Epoch 008 | Loss: 0.5101 | Val AUROC: 0.7561
# Epoch 009 | Loss: 0.4883 | Val AUROC: 0.7600
# Epoch 010 | Loss: 0.4844 | Val AUROC: 0.7628
# Epoch 011 | Loss: 0.4851 | Val AUROC: 0.7656
# Epoch 012 | Loss: 0.4731 | Val AUROC: 0.7694
# Epoch 013 | Loss: 0.4630 | Val AUROC: 0.7683
# Epoch 014 | Loss: 0.4671 | Val AUROC: 0.7761
# Epoch 015 | Loss: 0.4590 | Val AUROC: 0.7767
# Epoch 016 | Loss: 0.4518 | Val AUROC: 0.7767
# Epoch 017 | Loss: 0.4504 | Val AUROC: 0.7761
# Epoch 018 | Loss: 0.4442 | Val AUROC: 0.7767
# Epoch 019 | Loss: 0.4461 | Val AUROC: 0.7767
# Epoch 020 | Loss: 0.4404 | Val AUROC: 0.7783
# Epoch 021 | Loss: 0.4385 | Val AUROC: 0.7783
# Epoch 022 | Loss: 0.4317 | Val AUROC: 0.7828
# Epoch 023 | Loss: 0.4302 | Val AUROC: 0.7833
# Epoch 024 | Loss: 0.4365 | Val AUROC: 0.7817
# Epoch 025 | Loss: 0.4306 | Val AUROC: 0.7839
# Epoch 026 | Loss: 0.4350 | Val AUROC: 0.7761
# Epoch 027 | Loss: 0.4231 | Val AUROC: 0.7761
# Epoch 028 | Loss: 0.4283 | Val AUROC: 0.7772
# Epoch 029 | Loss: 0.4284 | Val AUROC: 0.7828
# Epoch 030 | Loss: 0.4169 | Val AUROC: 0.7822
# Epoch 031 | Loss: 0.4071 | Val AUROC: 0.7822
# Epoch 032 | Loss: 0.4163 | Val AUROC: 0.7822
# Epoch 033 | Loss: 0.4276 | Val AUROC: 0.7861
# Epoch 034 | Loss: 0.4179 | Val AUROC: 0.7861
# Epoch 035 | Loss: 0.4094 | Val AUROC: 0.7867
# Epoch 036 | Loss: 0.4109 | Val AUROC: 0.7844
# Epoch 037 | Loss: 0.4133 | Val AUROC: 0.7817
# Epoch 038 | Loss: 0.4083 | Val AUROC: 0.7811
# Epoch 039 | Loss: 0.4117 | Val AUROC: 0.7833
# Epoch 040 | Loss: 0.4133 | Val AUROC: 0.7822
# Epoch 041 | Loss: 0.4161 | Val AUROC: 0.7856
# Epoch 042 | Loss: 0.4043 | Val AUROC: 0.7811
# Epoch 043 | Loss: 0.4087 | Val AUROC: 0.7828
# Epoch 044 | Loss: 0.4033 | Val AUROC: 0.7856
# Epoch 045 | Loss: 0.3939 | Val AUROC: 0.7811
# Epoch 046 | Loss: 0.4113 | Val AUROC: 0.7800
# Epoch 047 | Loss: 0.4057 | Val AUROC: 0.7822
# Early stopping at epoch 47 (best Val AUROC=0.7867)
#
# ===== Fold 2/5 =====
# Epoch 001 | Loss: 0.6394 | Val AUROC: 0.5220
# Epoch 002 | Loss: 0.5565 | Val AUROC: 0.5783
# Epoch 003 | Loss: 0.5435 | Val AUROC: 0.6160
# Epoch 004 | Loss: 0.5227 | Val AUROC: 0.6318
# Epoch 005 | Loss: 0.5153 | Val AUROC: 0.6565
# Epoch 006 | Loss: 0.4955 | Val AUROC: 0.6532
# Epoch 007 | Loss: 0.4829 | Val AUROC: 0.6729
# Epoch 008 | Loss: 0.4824 | Val AUROC: 0.6729
# Epoch 009 | Loss: 0.4710 | Val AUROC: 0.6768
# Epoch 010 | Loss: 0.4507 | Val AUROC: 0.6852
# Epoch 011 | Loss: 0.4517 | Val AUROC: 0.6886
# Epoch 012 | Loss: 0.4389 | Val AUROC: 0.6869
# Epoch 013 | Loss: 0.4322 | Val AUROC: 0.6920
# Epoch 014 | Loss: 0.4196 | Val AUROC: 0.6892
# Epoch 015 | Loss: 0.4325 | Val AUROC: 0.6920
# Epoch 016 | Loss: 0.4244 | Val AUROC: 0.6937
# Epoch 017 | Loss: 0.4244 | Val AUROC: 0.6909
# Epoch 018 | Loss: 0.4183 | Val AUROC: 0.6948
# Epoch 019 | Loss: 0.4102 | Val AUROC: 0.6937
# Epoch 020 | Loss: 0.4103 | Val AUROC: 0.6931
# Epoch 021 | Loss: 0.4029 | Val AUROC: 0.6920
# Epoch 022 | Loss: 0.3960 | Val AUROC: 0.6976
# Epoch 023 | Loss: 0.4101 | Val AUROC: 0.6914
# Epoch 024 | Loss: 0.3905 | Val AUROC: 0.6943
# Epoch 025 | Loss: 0.3995 | Val AUROC: 0.6971
# Epoch 026 | Loss: 0.3944 | Val AUROC: 0.6914
# Epoch 027 | Loss: 0.4005 | Val AUROC: 0.6931
# Epoch 028 | Loss: 0.3960 | Val AUROC: 0.6931
# Epoch 029 | Loss: 0.3926 | Val AUROC: 0.6931
# Epoch 030 | Loss: 0.3877 | Val AUROC: 0.6937
# Epoch 031 | Loss: 0.3878 | Val AUROC: 0.6920
# Epoch 032 | Loss: 0.3793 | Val AUROC: 0.6954
# Epoch 033 | Loss: 0.3888 | Val AUROC: 0.6971
# Epoch 034 | Loss: 0.3799 | Val AUROC: 0.6965
# Early stopping at epoch 34 (best Val AUROC=0.6976)
#
# ===== Fold 3/5 =====
# Epoch 001 | Loss: 0.6004 | Val AUROC: 0.6211
# Epoch 002 | Loss: 0.5561 | Val AUROC: 0.7539
# Epoch 003 | Loss: 0.5520 | Val AUROC: 0.7905
# Epoch 004 | Loss: 0.5346 | Val AUROC: 0.7883
# Epoch 005 | Loss: 0.5219 | Val AUROC: 0.7815
# Epoch 006 | Loss: 0.5239 | Val AUROC: 0.7872
# Epoch 007 | Loss: 0.5085 | Val AUROC: 0.7911
# Epoch 008 | Loss: 0.4935 | Val AUROC: 0.7939
# Epoch 009 | Loss: 0.4872 | Val AUROC: 0.7922
# Epoch 010 | Loss: 0.4732 | Val AUROC: 0.7967
# Epoch 011 | Loss: 0.4716 | Val AUROC: 0.8007
# Epoch 012 | Loss: 0.4530 | Val AUROC: 0.8041
# Epoch 013 | Loss: 0.4619 | Val AUROC: 0.8102
# Epoch 014 | Loss: 0.4531 | Val AUROC: 0.8108
# Epoch 015 | Loss: 0.4440 | Val AUROC: 0.8119
# Epoch 016 | Loss: 0.4459 | Val AUROC: 0.8148
# Epoch 017 | Loss: 0.4348 | Val AUROC: 0.8125
# Epoch 018 | Loss: 0.4352 | Val AUROC: 0.8131
# Epoch 019 | Loss: 0.4390 | Val AUROC: 0.8119
# Epoch 020 | Loss: 0.4357 | Val AUROC: 0.8131
# Epoch 021 | Loss: 0.4319 | Val AUROC: 0.8136
# Epoch 022 | Loss: 0.4201 | Val AUROC: 0.8131
# Epoch 023 | Loss: 0.4128 | Val AUROC: 0.8142
# Epoch 024 | Loss: 0.4308 | Val AUROC: 0.8131
# Epoch 025 | Loss: 0.4184 | Val AUROC: 0.8164
# Epoch 026 | Loss: 0.4161 | Val AUROC: 0.8176
# Epoch 027 | Loss: 0.4194 | Val AUROC: 0.8204
# Epoch 028 | Loss: 0.4060 | Val AUROC: 0.8221
# Epoch 029 | Loss: 0.4031 | Val AUROC: 0.8238
# Epoch 030 | Loss: 0.4083 | Val AUROC: 0.8260
# Epoch 031 | Loss: 0.4121 | Val AUROC: 0.8255
# Epoch 032 | Loss: 0.4175 | Val AUROC: 0.8249
# Epoch 033 | Loss: 0.4068 | Val AUROC: 0.8243
# Epoch 034 | Loss: 0.4084 | Val AUROC: 0.8187
# Epoch 035 | Loss: 0.4122 | Val AUROC: 0.8198
# Epoch 036 | Loss: 0.4034 | Val AUROC: 0.8204
# Epoch 037 | Loss: 0.4093 | Val AUROC: 0.8209
# Epoch 038 | Loss: 0.3864 | Val AUROC: 0.8215
# Epoch 039 | Loss: 0.4028 | Val AUROC: 0.8221
# Epoch 040 | Loss: 0.3988 | Val AUROC: 0.8209
# Epoch 041 | Loss: 0.4062 | Val AUROC: 0.8209
# Epoch 042 | Loss: 0.3885 | Val AUROC: 0.8215
# Early stopping at epoch 42 (best Val AUROC=0.8260)
#
# ===== Fold 4/5 =====
# Epoch 001 | Loss: 0.6289 | Val AUROC: 0.6171
# Epoch 002 | Loss: 0.5737 | Val AUROC: 0.7078
# Epoch 003 | Loss: 0.5478 | Val AUROC: 0.7523
# Epoch 004 | Loss: 0.5412 | Val AUROC: 0.7776
# Epoch 005 | Loss: 0.5395 | Val AUROC: 0.7973
# Epoch 006 | Loss: 0.5157 | Val AUROC: 0.8041
# Epoch 007 | Loss: 0.5187 | Val AUROC: 0.8131
# Epoch 008 | Loss: 0.5121 | Val AUROC: 0.8238
# Epoch 009 | Loss: 0.4881 | Val AUROC: 0.8288
# Epoch 010 | Loss: 0.4907 | Val AUROC: 0.8339
# Epoch 011 | Loss: 0.4884 | Val AUROC: 0.8457
# Epoch 012 | Loss: 0.4784 | Val AUROC: 0.8530
# Epoch 013 | Loss: 0.4832 | Val AUROC: 0.8598
# Epoch 014 | Loss: 0.4648 | Val AUROC: 0.8637
# Epoch 015 | Loss: 0.4646 | Val AUROC: 0.8671
# Epoch 016 | Loss: 0.4523 | Val AUROC: 0.8666
# Epoch 017 | Loss: 0.4519 | Val AUROC: 0.8688
# Epoch 018 | Loss: 0.4503 | Val AUROC: 0.8677
# Epoch 019 | Loss: 0.4413 | Val AUROC: 0.8688
# Epoch 020 | Loss: 0.4409 | Val AUROC: 0.8722
# Epoch 021 | Loss: 0.4412 | Val AUROC: 0.8744
# Epoch 022 | Loss: 0.4376 | Val AUROC: 0.8756
# Epoch 023 | Loss: 0.4393 | Val AUROC: 0.8761
# Epoch 024 | Loss: 0.4258 | Val AUROC: 0.8756
# Epoch 025 | Loss: 0.4262 | Val AUROC: 0.8750
# Epoch 026 | Loss: 0.4173 | Val AUROC: 0.8744
# Epoch 027 | Loss: 0.4177 | Val AUROC: 0.8722
# Epoch 028 | Loss: 0.4214 | Val AUROC: 0.8711
# Epoch 029 | Loss: 0.4180 | Val AUROC: 0.8705
# Epoch 030 | Loss: 0.4120 | Val AUROC: 0.8705
# Epoch 031 | Loss: 0.4207 | Val AUROC: 0.8699
# Epoch 032 | Loss: 0.4137 | Val AUROC: 0.8671
# Epoch 033 | Loss: 0.4112 | Val AUROC: 0.8643
# Epoch 034 | Loss: 0.4047 | Val AUROC: 0.8649
# Epoch 035 | Loss: 0.4090 | Val AUROC: 0.8620
# Early stopping at epoch 35 (best Val AUROC=0.8761)
#
# ===== Fold 5/5 =====
# Epoch 001 | Loss: 0.6031 | Val AUROC: 0.5474
# Epoch 002 | Loss: 0.5606 | Val AUROC: 0.6718
# Epoch 003 | Loss: 0.5562 | Val AUROC: 0.6932
# Epoch 004 | Loss: 0.5437 | Val AUROC: 0.7068
# Epoch 005 | Loss: 0.5243 | Val AUROC: 0.7342
# Epoch 006 | Loss: 0.5217 | Val AUROC: 0.7458
# Epoch 007 | Loss: 0.5118 | Val AUROC: 0.7622
# Epoch 008 | Loss: 0.5010 | Val AUROC: 0.7721
# Epoch 009 | Loss: 0.4993 | Val AUROC: 0.7775
# Epoch 010 | Loss: 0.4733 | Val AUROC: 0.7890
# Epoch 011 | Loss: 0.4795 | Val AUROC: 0.7912
# Epoch 012 | Loss: 0.4694 | Val AUROC: 0.8000
# Epoch 013 | Loss: 0.4593 | Val AUROC: 0.8033
# Epoch 014 | Loss: 0.4605 | Val AUROC: 0.8066
# Epoch 015 | Loss: 0.4444 | Val AUROC: 0.8093
# Epoch 016 | Loss: 0.4569 | Val AUROC: 0.8142
# Epoch 017 | Loss: 0.4422 | Val AUROC: 0.8175
# Epoch 018 | Loss: 0.4446 | Val AUROC: 0.8186
# Epoch 019 | Loss: 0.4368 | Val AUROC: 0.8285
# Epoch 020 | Loss: 0.4434 | Val AUROC: 0.8285
# Epoch 021 | Loss: 0.4344 | Val AUROC: 0.8290
# Epoch 022 | Loss: 0.4302 | Val AUROC: 0.8312
# Epoch 023 | Loss: 0.4204 | Val AUROC: 0.8351
# Epoch 024 | Loss: 0.4256 | Val AUROC: 0.8356
# Epoch 025 | Loss: 0.4236 | Val AUROC: 0.8373
# Epoch 026 | Loss: 0.4269 | Val AUROC: 0.8367
# Epoch 027 | Loss: 0.4266 | Val AUROC: 0.8340
# Epoch 028 | Loss: 0.4175 | Val AUROC: 0.8356
# Epoch 029 | Loss: 0.4213 | Val AUROC: 0.8373
# Epoch 030 | Loss: 0.4180 | Val AUROC: 0.8367
# Epoch 031 | Loss: 0.4138 | Val AUROC: 0.8378
# Epoch 032 | Loss: 0.4021 | Val AUROC: 0.8384
# Epoch 033 | Loss: 0.4106 | Val AUROC: 0.8384
# Epoch 034 | Loss: 0.4029 | Val AUROC: 0.8411
# Epoch 035 | Loss: 0.4104 | Val AUROC: 0.8395
# Epoch 036 | Loss: 0.4059 | Val AUROC: 0.8405
# Epoch 037 | Loss: 0.4127 | Val AUROC: 0.8405
# Epoch 038 | Loss: 0.4039 | Val AUROC: 0.8433
# Epoch 039 | Loss: 0.4067 | Val AUROC: 0.8427
# Epoch 040 | Loss: 0.4109 | Val AUROC: 0.8422
# Epoch 041 | Loss: 0.3920 | Val AUROC: 0.8405
# Epoch 042 | Loss: 0.3973 | Val AUROC: 0.8422
# Epoch 043 | Loss: 0.4012 | Val AUROC: 0.8455
# Epoch 044 | Loss: 0.3909 | Val AUROC: 0.8411
# Epoch 045 | Loss: 0.3909 | Val AUROC: 0.8395
# Epoch 046 | Loss: 0.3890 | Val AUROC: 0.8411
# Epoch 047 | Loss: 0.3863 | Val AUROC: 0.8378
# Epoch 048 | Loss: 0.3914 | Val AUROC: 0.8416
# Epoch 049 | Loss: 0.4001 | Val AUROC: 0.8395
# Epoch 050 | Loss: 0.3987 | Val AUROC: 0.8373
# Epoch 051 | Loss: 0.3815 | Val AUROC: 0.8422
# Epoch 052 | Loss: 0.3896 | Val AUROC: 0.8400
# Epoch 053 | Loss: 0.3942 | Val AUROC: 0.8411
# Epoch 054 | Loss: 0.3854 | Val AUROC: 0.8395
# Epoch 055 | Loss: 0.3917 | Val AUROC: 0.8405
# Early stopping at epoch 55 (best Val AUROC=0.8455)
#
# ===== 5折 LSTM Bootstrap 结果（seed=7567） =====
# AUROC: 0.8045 (95% CI 0.7710–0.8374)
# AUPRC: 0.6234 (95% CI 0.5576–0.6832)
#
# ✅ 所有折预测结果已保存至 /home/mailiyi/Poisoning_Prediction/LSTM/predict_non-recovery_calibration/
